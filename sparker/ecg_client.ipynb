# %%
import numpy as np
import socket
import sys, time
import matplotlib.pyplot as plt

# %%
def process_data(x):
    # xs is a string ~ timestep, label, peakloc, signal_len, signal
    xs = x.split(',')
    ts = int(xs[0])
    label = xs[1]
    peak = int(xs[2])
    slen = int(xs[3])
    sig = np.array(xs[4:-1]).astype(np.float32)
    plt.figure(figsize=(10,3))
    plt.title(xs[0:4])
    plt.plot(sig)
    plt.show()

# %%
HOST, PORT = "localhost", 9999
#data = " ".join(sys.argv[1:])
while True:
    time.sleep(1.5)
    # Create a socket (SOCK_STREAM means a TCP socket)
    with socket.socket(socket.AF_INET, socket.SOCK_STREAM) as sock:
        # Connect to server and send data
        sock.connect((HOST, PORT))
        #sock.sendall(bytes(data + "\n", "utf-8"))

        # Receive data from the server and shut down
        received = str(sock.recv(6000), "utf-8")

    #print("Sent:     {}".format(data))
    #print("Received: {}".format(received))
    process_data(received)
    
# # timestep, label, peakloc, signal_len, signal
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_6167/2581325584.py in <module>
#       2 #data = " ".join(sys.argv[1:])
#       3 while True:
# ----> 4     time.sleep(1.5)
#       5     # Create a socket (SOCK_STREAM means a TCP socket)
#       6     with socket.socket(socket.AF_INET, socket.SOCK_STREAM) as sock:
#
# KeyboardInterrupt:
