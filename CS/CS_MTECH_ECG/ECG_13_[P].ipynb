# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %% [markdown]
# snippet for duration reporting

# %%
timestamp_start = datetime.datetime.now()

timestamp_dur = datetime.datetime.now() - timestamp_start
print('Elapsed time = ' + str(timestamp_dur))

# %% [markdown]
# # [ IMPORTS ]

# %%
pip install keract
# Out:
# Collecting keract
#   Downloading https://files.pythonhosted.org/packages/bd/09/43bef4b23b5faa51c0c0b75cce03f5000cadacdc13a82dba79747768934d/keract-4.2.2-py3-none-any.whl
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.6/dist-packages (from keract) (1.18.5)
# Installing collected packages: keract
# Successfully installed keract-4.2.2

# %%
import datetime
import os
import random
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

import statistics as stats
import scipy.signal as scsig

import tensorflow as tf
import keras
from tensorflow.keras.layers import Dense, Input, LSTM, Conv1D, Conv2D, MaxPooling1D, Flatten, BatchNormalization, Reshape
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.utils import to_categorical


import keract

import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # [ GLOBAL ]

# %%
# Resample every signal to this rate for consistency
BASIC_SRATE = 128 #Hz
print('Basic sampling rate(Hz): '+str(BASIC_SRATE))


#=================================================
# working directories
#=================================================

# > _ base working directory
global_dir = '/content/drive/My Drive/Masters/workdir/ecg_data'
print('GLOBAL DIR :: '+global_dir)

# >> global MAT directory, contains signal data in matlab (.mat) format
global_matdir = os.path.join(global_dir, 'db_mat') 
print('GLOBAL MAT DIR :: '+global_matdir)

# >> global NPY directory, contains signal and meta data in numpy (.npy) format
global_npydir = os.path.join(global_dir, 'db_npy') 
print('GLOBAL NPY DIR :: '+global_npydir)

# >> global datasets directory, contains manually generated datasets
global_dsdir = os.path.join(global_dir, 'db_dataset') 
print('GLOBAL DATSET DIR :: '+global_dsdir)

# >> model directory, contains model weights and test results use load_weights(), save_weights() 
global_modeldir = os.path.join(global_dir, 'db_model')
print('GLOBAL MODEL DIR :: ' + global_modeldir)

#>>----------------------------------------------- 


#=================================================
# Annotations
#=================================================
# >> annotation directory, contains annotation mapping files to be used for experiments
global_antdir = os.path.join(global_dir, 'db_ant') 
print('GLOBAL ANNOTATION DIR :: ' + global_antdir)
#>>----------------------------------------------- 


#=================================================
# File Identifiers
#=================================================
# beat and non-beat annotations, signal data types to be used to save data in npy format
g_BA = 'BA'                     #<<--- beat annotations (@orignal Sampling rate)
g_NBA = 'NBA'                   #<<--- non-beat annotations (@orignal Sampling rate)
g_RAW2 = 'RAW2'                 #<<--- Raw lead2 signal from mat file
g_BLF2 = 'BLF2'                 #<<--- Baseline fitted signal
g_RES2 = 'RES2'                 #<<--- Resampled to BASIC_SRATE

g_SIG2 = 'SIG2'     #<<--- Removed manual gain
g_RPEAK = 'RRP'     #<<--- Resampled R-peaks
#>>-----------------------------------------------
# Out:
# Basic sampling rate(Hz): 128
# GLOBAL DIR :: /content/drive/My Drive/Masters/workdir/ecg_data
# GLOBAL MAT DIR :: /content/drive/My Drive/Masters/workdir/ecg_data/db_mat
# GLOBAL NPY DIR :: /content/drive/My Drive/Masters/workdir/ecg_data/db_npy
# GLOBAL DATSET DIR :: /content/drive/My Drive/Masters/workdir/ecg_data/db_dataset
# GLOBAL MODEL DIR :: /content/drive/My Drive/Masters/workdir/ecg_data/db_model
# GLOBAL ANNOTATION DIR :: /content/drive/My Drive/Masters/workdir/ecg_data/db_ant

# %% [markdown]
# # [ CLASS DEFINITIONS ]

# %%
#---------------------------------------------------------------------------------------------------------------------------------------------
# CLASS ecg_db : represents one ECG database
#---------------------------------------------------------------------------------------------------------------------------------------------
class ecg_db:
    def __init__(self, dbname,  tag_recs):
        print('\nInitailze new ecg database ... ')
        self.name = dbname  #str
        self.dir_npy = os.path.join(global_npydir , dbname+'_npy') #str
        self.recs = set(np.loadtxt(os.path.join(self.dir_npy,'RECORDS'), dtype='str',delimiter="\n")) #set
        self.recs_tag = set(tag_recs)
        self.recs_dict = {} # initially empty, will be loaded on demand using function 'get_record'
        self.info()

    def info(self):
        print( 'DB NAME :: '+ self.name)
        print( 'DATA DIR :: ' + self.dir_npy )
        print( 'RECORDS :: [' +str(len(self.recs))+'] ' + str(self.recs) )
        print( 'TAG RECORDS :: [' +str(len(self.recs_tag))+'] ' + str(self.recs_tag))
        return 0

    def get_record(self,rec):
        if not (rec in self.recs_dict.keys()):
            self.recs_dict[rec] = ecg_record(self,rec)
        return self.recs_dict[rec]
    
    def get_random_record(self, recset):
        rec = random.choice(list(recset))
        if not (rec in self.recs_dict.keys()):
            self.recs_dict[rec] = ecg_record(self,rec)
        return self.recs_dict[rec]

#---------------------------------------------------------------------------------------------------------------------------------------------

#---------------------------------------------------------------------------------------------------------------------------------------------
# CLASS ecg_record : represents one ECG Record in any database
#---------------------------------------------------------------------------------------------------------------------------------------------
g_SUPRESS_DATA_WARNING=False
class ecg_record:

    def __init__(self, db, recname):
        self.db = db                                # class:{ecg_db}    object this record belongs to
        self.rec = recname                          # string            name of this record
        self.name = db.name + '_'+ recname          # string            full name including db.name
        if not recname in db.recs:
            print('WARNING:: Record "'+ recname +'" not found in database '+ db.name )
        self.data_npy = {}                          # dict dict of data file content used in self.read_data_npy('key')
        self.data_temp = {}                          # dict dict of data file content used in self.read_data_temp('key')
        self.binfo = None                           # class binfo       

##<------------------------------------------------- get instance of binfo class
    def read_binfo(self):
        if self.binfo == None:
            self.binfo = ecg_binfo(self)
        return self.binfo

    def refresh_binfo(self):
        self.binfo = ecg_binfo(self)
        return self.binfo

##<------------------------------------------------- data reading for npydir
    def load_data(self, data_type):
        ipath = os.path.join(self.db.dir_npy, self.rec + '_'+data_type+'.npy')
        try: # try to load this data
            self.data_npy[data_type] = np.load(ipath) # adds this to dictionary so next time it can read
            return self.data_npy[data_type] #= np.load(self.dirs[s])
        except:
            if g_SUPRESS_DATA_WARNING == False:
                print('WARNING:: Cant load "'+data_type+ '" file at '+ str(ipath) )
            return np.array([])
        
    def read_data(self, data_type):
        if data_type in self.data_npy.keys():
            return self.data_npy[data_type] #= np.load(self.dirs[s])
        else:
            return self.load_data(data_type)

##<------------------------------------------------- for tempdir
    def load_data_temp(self, data_type, dir_path):
        ipath = os.path.join(dir_path, self.rec + '_'+data_type+'.npy')
        try: # try to load this data
            self.data_temp[data_type] = np.load(ipath) # adds this to dictionary so next time it can read
            return self.data_temp[data_type] #= np.load(self.dirs[s])
        except:
            if g_SUPRESS_DATA_WARNING == False:
                print('WARNING:: Cant load "'+data_type+ '" file at '+ str(ipath) )
            return np.array([])
        
    def read_data_temp(self, data_type, dir_path):
        if data_type in self.data_temp.keys():
            return self.data_temp[data_type] #= np.load(self.dirs[s])
        else:
            return self.load_data_temp(data_type, dir_path)

    def save_data_temp(self, data_type, data_array, dir_path):
        ipath = os.path.join(dir_path, self.rec + '_'+data_type+'.npy')
        np.save(ipath, data_array)
        return ipath

    def del_data_temp(self, data_type, dir_path, vb):
        ipath = os.path.join(dir_path, self.rec + '_'+data_type+'.npy')
        if os.path.exists(ipath):
            if vb:
                print('Removing: '+str(ipath))
            os.remove(ipath)
            return 1
        else:
            return 0
#------------------------------------------------------------------------------------------------

#---------------------------------------------------------------------------------------------------------------------------------------------
# CLASS ecg_binfo : information about beats in a record
#---------------------------------------------------------------------------------------------------------------------------------------------
class ecg_binfo:
    def __init__(self, rec):
         
        # the record object
        self.rec = rec
        
        # read orignal annotations
        r_peaks_ants = rec.read_data(g_RPEAK)       # resampled ant file
        
        # calculate count of R peaks (excluding first and last)
        self.rp_count = len(r_peaks_ants) - 2
        
        # Extract Location and Labels of Peaks (exclude first and last beat)
        r_peaks_int = r_peaks_ants[:,0].astype('int')
        r_ants_str = r_peaks_ants[:,1]
        
        #self.rp_first = r_peaks_int_raw[0] # = self.rp_prev[0]
        #self.rp_last = r_peaks_int_raw[-1] # = self.rp_next[-1]
        
        # Location
        self.rp_curr = r_peaks_int[1:-1]    # current R peak
        self.rp_prev = r_peaks_int[0:-2]    # previous R peak (in samples)
        self.rp_next = r_peaks_int[2:]      # next R peak (in samples)
        
        # Label
        self.rl_curr = r_ants_str[1:-1]
        self.rl_prev = r_ants_str[0:-2]
        self.rl_next = r_ants_str[2:]

        # mapped Label
        self.rli_prev = []
        self.rli_curr = []
        self.rli_next = []

        # calculate temporal info
        self.rp_sec = self.rp_curr / BASIC_SRATE                 # peak location (in sec)
        self.rri_prev = (self.rp_curr - self.rp_prev) / BASIC_SRATE   # prev RRI (in sec) 
        self.rri_next = (self.rp_next - self.rp_curr) / BASIC_SRATE   # next RRI (in sec) 
        self.rri_delta = (self.rri_next - self.rri_prev)              # difference b/w prev and next RRI (in sec) 
        self.rri_dur = (self.rri_next + self.rri_prev)                # total duration from prev to next R-peak
        

    def get_signal_data_var(self, ith_peak): # data_type = g_SIG_II_POSTFIX
        # prev peak to next peak
        sel_sig = self.rec.read_data(g_SIG2) 
        ff = self.rp_prev[ith_peak]
        tt = self.rp_next[ith_peak]
        pp = self.rp_curr[ith_peak]
        sel_part = sel_sig[ff:tt+1]
        return sel_part, (pp-ff), (tt+1-ff) #<- also return position of peak
    
    def get_signal_data_fix(self, ith_peak, v_left_sec, v_right_sec): # data_type = g_SIG_II_POSTFIX
        return self.get_signal_data_fix_samples(ith_peak,int(v_left_sec*BASIC_SRATE),int(v_right_sec*BASIC_SRATE))

    def get_signal_data_fix_samples(self, ith_peak, v_left, v_right): # data_type = g_SIG_II_POSTFIX
        sel_sig = self.rec.read_data(g_SIG2) 
        ff = self.rp_curr[ith_peak]-v_left
        tt = self.rp_curr[ith_peak]+v_right
        pp = self.rp_curr[ith_peak]

        f_pad,t_pad=0,0
        if ff<0:
            f_pad=0-ff
            ff=0

        if tt>len(sel_sig):
            tpad=tt-len(sel_sig)
            tt=len(sel_sig)

        sel_part = np.hstack((
            np.zeros(f_pad),
            sel_sig[ff:tt],
            np.zeros(t_pad),
            ))

        pl = pp+f_pad
        return sel_part, pl #<- also return position of peak

    def get_local_hrT(self,local_window_start,local_window_end): # within a time duration
        lws = local_window_start*BASIC_SRATE # in samples        
        lwe = local_window_end*BASIC_SRATE # in samples        
        #ff and tt should be within signal limits
        # if not in limits then take shortest : means truncate lw duration
        ff = max( lws ,self.rp_prev[0])
        tt = min( lwe ,self.rp_next[-1])
        dd = (tt-ff)/BASIC_SRATE
        qq = np.where((self.rp_curr>=ff) & (self.rp_curr<=tt))[0] #  these many peaks in dd sec
        nq = len(qq)# qq must be at least 2 peaks
        # if qq peaks in dd secs then heart rate = (qq/dd) bps =  (qq/dd)*60 bpm
        if nq<2:  
             dd=0
             local_bps = 0
        else:
             ff = self.rp_curr[qq[0]]
             tt = self.rp_curr[qq[-1]]
             dd = (tt-ff)/BASIC_SRATE
             local_bps = (nq-1)/dd #bps
        
        return local_bps, dd
   
     
    def get_local_hr(self,ith_peak, local_window_left,local_window_right): # within local duration of ith peak
        lwl = local_window_left*BASIC_SRATE # in samples        
        lwr = local_window_right*BASIC_SRATE # in samples        
        #ff and tt should be within signal limits
        # if not in limits then take shortest : means truncate lw duration
        ff = max(self.rp_curr[ith_peak] - lwl ,self.rp_prev[0])
        tt = min(self.rp_curr[ith_peak] + lwr ,self.rp_next[-1])
        
        qq = np.where((self.rp_curr>=ff) & (self.rp_curr<=tt))[0] #  these many peaks in dd sec
        nq = len(qq)# qq must be at least 2 peaks
        if nq<2:  
             return 0, 0
        else:
             ff = self.rp_curr[qq[0]]
             tt = self.rp_curr[qq[-1]]
             dd = (tt-ff)/BASIC_SRATE
        # if nq peaks in dd secs then heart rate = (nq/dd) bps =  (nq/dd)*60 bpm
             local_bps = (nq-1)/dd #bps
             return local_bps, dd

    def get_local_hrA(self, local_window_left,local_window_right): # within local duration of all peaks
        lwl = local_window_left*BASIC_SRATE # in samples        
        lwr = local_window_right*BASIC_SRATE # in samples       
        #ff and tt should be within signal limits
        # if not in limits then take shortest : means truncate lw duration
        local_bps = np.zeros(self.rp_count,dtype='float')
        local_dd = np.zeros(self.rp_count,dtype='float')
        for ith_peak in range(0, self.rp_count):
             ff = max(self.rp_curr[ith_peak] - lwl ,self.rp_prev[0])
             tt = min(self.rp_curr[ith_peak] + lwr ,self.rp_next[-1])
             qq = np.where((self.rp_curr>=ff) & (self.rp_curr<=tt))[0] #  these many peaks in dd sec
             nq = len(qq) # qq must be at least 2 peaks
             if nq<2:  
                  local_bps[ith_peak] = 0 #bps
                  local_dd[ith_peak] = 0 #bps
             else:
                  ff = self.rp_curr[qq[0]]
                  tt = self.rp_curr[qq[-1]]
                  dd = (tt-ff)/BASIC_SRATE
                  local_bps[ith_peak] = (nq-1)/dd #bps
                  local_dd[ith_peak] = dd #bps
        return local_bps, local_dd
    
    def map_ants2int(self,map_dict):
        if len(self.rli_curr)!=self.rp_count:
            temp = np.zeros(self.rp_count+2,dtype='str')
            temp[0] =  map_dict[self.rl_prev[0]]
            for i in range(0, self.rp_count):
                temp[i+1] = map_dict[self.rl_curr[i]]
            temp[-1] =  map_dict[self.rl_next[-1]]
            self.rli_curr = temp[1:-1]
            self.rli_prev = temp[0:-2]
            self.rli_next = temp[2:]

    def map_NRB(self, N_Label, TS_delta_RR):
        self.n_mask = (self.rli_curr==N_Label)
        self.nnn_mask = (
                        ((self.rli_prev==N_Label) & (self.rli_next==N_Label)) &
                        (self.n_mask)
                        )
        self.ana_mask = (
                        ((self.rli_prev!=N_Label) | (self.rli_next!=N_Label)) &
                        (self.n_mask)
                        )                  
        self.n_list = np.where(self.n_mask)[0]
        self.nnn_list = np.where(self.nnn_mask)[0]
        self.ana_list = np.where(self.ana_mask)[0]

        self.NRB_TS_delta_RR = TS_delta_RR
        self.NRBi = np.where(
                        self.nnn_mask &
                        (np.absolute(self.rri_delta)<=TS_delta_RR)
                        )[0]
        self.NRBc = len(self.NRBi)

        if self.NRBc!=0:
            self.dNRB = self.rri_dur[self.NRBi]
            self.dLow, self.dHigh = np.min(self.dNRB), np.max(self.dNRB)
        else:
            self.dNRB = []
            self.dLow, self.dHigh = -1,-1


        return self.NRBc 
        
class data_params():
    def __init__ (self, vdim_sec, peak_ratio, pad_value, sLsamp, sRsamp):
        self.vdim = vdim_sec*BASIC_SRATE
        self.peak_ratio = peak_ratio
        self.fix_left = int(self.vdim*self.peak_ratio)
        self.fix_right = self.vdim-self.fix_left
        self.pad_value = pad_value
        self.supL,self.supR = sLsamp,sRsamp
        print('Vector Dimension:', self.vdim)
        print('Peak Ratio:', self.peak_ratio, '[',self.fix_left,',',self.fix_right,']')
        print('Padding Value:', self.pad_value)
        print('Suppress Peaks:', self.supL,self.supR )

# %% [markdown]
# ---

# %% [markdown]
# # [ MODEL ]

# %%
cb_esr = tf.keras.callbacks.EarlyStopping(
        monitor='accuracy', 
        min_delta=0.00001, 
        patience=2, 
        verbose=0, 
        mode='auto', 
        baseline=None, 
        restore_best_weights=False)
cb_listr=[cb_esr] 
cost = 'sparse_categorical_crossentropy'
opt = 'rmsprop'

def get_modelCNN_1D(print_summary, vdims, model_name):
    #itempo = Input( shape=(7,), name = "input_tempo" )
# NORM INPUT SIDE ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

    inorm = Input( shape=(vdims,2), name = "input_norm" )

    conv_inorm_1 =  Conv1D(64,                #filters, 
                          7,                  #kernel_size, 
                          strides=1, 
                          padding='valid', 
                          data_format='channels_last', 
                          dilation_rate=1, 
                          activation=tf.nn.leaky_relu, 
                          use_bias=True, 
                          kernel_initializer='glorot_uniform', 
                          bias_initializer='zeros', 
                          kernel_regularizer=None, 
                          bias_regularizer=None, 
                          activity_regularizer=None, 
                          kernel_constraint=None, 
                          bias_constraint=None,
                          name='conv_inorm_1') (inorm) 
    
    #maxpool_icompar_2 = MaxPooling1D(pool_size=2, 
    #                              strides=None, 
    #                              padding='valid', 
    #                              data_format='channels_last') (conv_icompar_1)
    
    conv_inorm_3 =  Conv1D(40,                #filters, 
                          3,                  #kernel_size, 
                          strides=1, 
                          padding='valid', 
                          data_format='channels_last', 
                          dilation_rate=1, 
                          activation=tf.nn.leaky_relu, 
                          use_bias=True, 
                          kernel_initializer='glorot_uniform', 
                          bias_initializer='zeros', 
                          kernel_regularizer=None, 
                          bias_regularizer=None, 
                          activity_regularizer=None, 
                          kernel_constraint=None, 
                          bias_constraint=None,
                          name='conv_inorm_3')(conv_inorm_1) #(maxpool_icompar_2)
    
    #maxpool_icompar_4 = MaxPooling1D(pool_size=2, 
    #                              strides=None, 
    #                              padding='valid', 
    #                              data_format='channels_last') (conv_icompar_3)
    conv_inorm_5 =  Conv1D(20,                #filters, 
                          3,                  #kernel_size, 
                          strides=1, 
                          padding='valid', 
                          data_format='channels_last', 
                          dilation_rate=1, 
                          activation=tf.nn.leaky_relu, 
                          use_bias=True, 
                          kernel_initializer='glorot_uniform', 
                          bias_initializer='zeros', 
                          kernel_regularizer=None, 
                          bias_regularizer=None, 
                          activity_regularizer=None, 
                          kernel_constraint=None, 
                          bias_constraint=None,
                          name='conv_inorm_5') (conv_inorm_3)#(maxpool_icompar_4)
    
    #maxpool_icompar_6 = MaxPooling1D(pool_size=2, 
    #                              strides=None, 
    #                              padding='valid', 
    #                              data_format='channels_last') (conv_icompar_5)
    
    flat_inorm_7 = Flatten(data_format=None,name='flat_inorm_7') (conv_inorm_5) #(maxpool_icompar_6)
    

# DENSE SIDE ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
    
    den_fc0 = Dense(40, activation=tf.nn.relu, name = "DENSE_FC0")(flat_inorm_7)
    
    den_fc1 = Dense(20, activation=tf.nn.relu, name = "DENSE_FC1")(den_fc0)

# OUTPUT SIDE ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
    den_out = Dense(2, activation=tf.nn.softmax, name = "OUTPUT_FC")(den_fc1)

# =========================================================================================
    model=Model(inputs=inorm, outputs=den_out, name=model_name)
    #-------------------------------------
    #model.get_layer(name="LSTM_50").trainable=is_trainable
    #-------------------------------------
    model.compile(loss=cost, optimizer=opt, metrics=['accuracy'])
    if print_summary:
        print(model.summary())
    return model

def get_modelCNN_2D(print_summary, vdims, model_name):
    #itempo = Input( shape=(7,), name = "input_tempo" )
# NORM INPUT SIDE ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

    inorm = Input( shape=(vdims,2), name = "input_norm" )
    reshp1 = Reshape((vdims,2,1), name='input_reshape')(inorm)
    conv_inorm_1 =  Conv2D(64,                #filters, 
                          (7,2),                  #kernel_size, 
                          strides=1, 
                          padding='valid', 
                          data_format='channels_last', 
                          dilation_rate=1, 
                          activation=tf.nn.leaky_relu, 
                          use_bias=True, 
                          kernel_initializer='glorot_uniform', 
                          bias_initializer='zeros', 
                          kernel_regularizer=None, 
                          bias_regularizer=None, 
                          activity_regularizer=None, 
                          kernel_constraint=None, 
                          bias_constraint=None,
                          name='conv_inorm_1') (reshp1) 
    
    #maxpool_icompar_2 = MaxPooling1D(pool_size=2, 
    #                              strides=None, 
    #                              padding='valid', 
    #                              data_format='channels_last') (conv_icompar_1)
    
    reshp2 = Reshape((vdims-(7-1),64), name='conv_reshape')(conv_inorm_1)

    conv_inorm_3 =  Conv1D(40,                #filters, 
                          3,                  #kernel_size, 
                          strides=1, 
                          padding='valid', 
                          data_format='channels_last', 
                          dilation_rate=1, 
                          activation=tf.nn.leaky_relu, 
                          use_bias=True, 
                          kernel_initializer='glorot_uniform', 
                          bias_initializer='zeros', 
                          kernel_regularizer=None, 
                          bias_regularizer=None, 
                          activity_regularizer=None, 
                          kernel_constraint=None, 
                          bias_constraint=None,
                          name='conv_inorm_3')(reshp2) #(maxpool_icompar_2)
    
    #maxpool_icompar_4 = MaxPooling1D(pool_size=2, 
    #                              strides=None, 
    #                              padding='valid', 
    #                              data_format='channels_last') (conv_icompar_3)
    conv_inorm_5 =  Conv1D(20,                #filters, 
                          3,                  #kernel_size, 
                          strides=1, 
                          padding='valid', 
                          data_format='channels_last', 
                          dilation_rate=1, 
                          activation=tf.nn.leaky_relu, 
                          use_bias=True, 
                          kernel_initializer='glorot_uniform', 
                          bias_initializer='zeros', 
                          kernel_regularizer=None, 
                          bias_regularizer=None, 
                          activity_regularizer=None, 
                          kernel_constraint=None, 
                          bias_constraint=None,
                          name='conv_inorm_5') (conv_inorm_3)#(maxpool_icompar_4)
    
    #maxpool_icompar_6 = MaxPooling1D(pool_size=2, 
    #                              strides=None, 
    #                              padding='valid', 
    #                              data_format='channels_last') (conv_icompar_5)
    
    flat_inorm_7 = Flatten(data_format=None,name='flat_inorm_7') (conv_inorm_5) #(maxpool_icompar_6)
    

# DENSE SIDE ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
    
    den_fc0 = Dense(40, activation=tf.nn.relu, name = "DENSE_FC0")(flat_inorm_7)
    
    den_fc1 = Dense(20, activation=tf.nn.relu, name = "DENSE_FC1")(den_fc0)

# OUTPUT SIDE ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
    den_out = Dense(2, activation=tf.nn.softmax, name = "OUTPUT_FC")(den_fc1)

# =========================================================================================
    model=Model(inputs=inorm, outputs=den_out, name=model_name)
    #-------------------------------------
    #model.get_layer(name="LSTM_50").trainable=is_trainable
    #-------------------------------------
    model.compile(loss=cost, optimizer=opt, metrics=['accuracy'])
    if print_summary:
        print(model.summary())
    return model

# %%
test1d = get_modelCNN_1D(True,3*BASIC_SRATE, "test_model_1D")
test2d = get_modelCNN_2D(True,3*BASIC_SRATE, "test_model_2D")
# Out:
# Model: "test_model_1D"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_norm (InputLayer)      [(None, 384, 2)]          0
# _________________________________________________________________
# conv_inorm_1 (Conv1D)        (None, 378, 64)           960
# _________________________________________________________________
# conv_inorm_3 (Conv1D)        (None, 376, 40)           7720
# _________________________________________________________________
# conv_inorm_5 (Conv1D)        (None, 374, 20)           2420
# _________________________________________________________________
# flat_inorm_7 (Flatten)       (None, 7480)              0
# _________________________________________________________________
# DENSE_FC0 (Dense)            (None, 40)                299240
# _________________________________________________________________
# DENSE_FC1 (Dense)            (None, 20)                820
# _________________________________________________________________
# OUTPUT_FC (Dense)            (None, 2)                 42
# =================================================================
# Total params: 311,202
# Trainable params: 311,202
# Non-trainable params: 0
# _________________________________________________________________
# None
# Model: "test_model_2D"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_norm (InputLayer)      [(None, 384, 2)]          0
# _________________________________________________________________
# reshape_4 (Reshape)          (None, 384, 2, 1)         0
# _________________________________________________________________
# conv_inorm_1 (Conv2D)        (None, 378, 1, 64)        960
# _________________________________________________________________
# reshape_5 (Reshape)          (None, 378, 64)           0
# _________________________________________________________________
# conv_inorm_3 (Conv1D)        (None, 376, 40)           7720
# _________________________________________________________________
# conv_inorm_5 (Conv1D)        (None, 374, 20)           2420
# _________________________________________________________________
# flat_inorm_7 (Flatten)       (None, 7480)              0
# _________________________________________________________________
# DENSE_FC0 (Dense)            (None, 40)                299240
# _________________________________________________________________
# DENSE_FC1 (Dense)            (None, 20)                820
# _________________________________________________________________
# OUTPUT_FC (Dense)            (None, 2)                 42
# =================================================================
# Total params: 311,202
# Trainable params: 311,202
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# # [ PERFORMANCE MEASURES ]

# %%
#=========================================================================================================================
#======================= NEURAL NETWORK PERFORMANCE MEASURES
#=========================================================================================================================
# 3.3 :: define performance evaluation functions

def get_performance(conf_matrix):
    #how many classes? = len of conf_matril
    nos_class = len(conf_matrix[0,:]) # len of 0th row
    res = np.zeros((0,8),dtype ='float64')
    for i in range(0,nos_class):
        # for each class calculate 4 performance measure - ACC, PRE, SEN, SPF, 
        # first compute TP, TN, FP, FN
        TP = conf_matrix[i,i]
        FP = np.sum(conf_matrix[:,i]) - TP
        FN = np.sum(conf_matrix[i,:]) - TP
        TN = np.sum(conf_matrix) - FN - FP - TP

        ACC = (TP+TN)   /   (TP+FP+FN+TN)
        PRE = (TP)      /   (TP+FP)
        SEN = (TP)      /   (TP+FN)
        SPF = (TN)      /   (TN+FP)

        res_i = np.array([TP, FN, FP, TN, ACC, PRE, SEN, SPF])
        res = np.vstack((res,res_i))
    return res


#------------------------------------------------------------------PRINTING

def print_lstr(class_labels):
    g_LSTR=''   # HEADER ROW for printing confusing matrix
    for i in range(0,len(class_labels)):
        g_LSTR+='\t'+str(class_labels[i])
    return  g_LSTR

def print_cf_row(cf_row,nos_labels):
    res = ''
    for j in range(0,nos_labels):
        res += '\t'+ str(cf_row[j])
    return res
def print_conf_matrix(conf_matrix, suffix, class_labels):
    res=(suffix+'A\\P' + print_lstr(class_labels)+'\n')
    nos_l=len(class_labels)
    for i in range(0,nos_l):
        res+=(suffix+str(class_labels[i]) + print_cf_row(conf_matrix[i],nos_l )+'\n')
    return res
def print_performance(perf_measures, class_labels):
    nos_class = len(perf_measures[:,0])
    print('Performance for '+str(nos_class)+' classes')
    print ('Class\tACC\tPRE\tSEN\tSPF')
    for i in range(0, nos_class):
        perf_i = np.round(perf_measures [i,:],2)
        #print('\tT.P : '+str(perf_i[0])+'\tF.N : '+str(perf_i[1]))
        #print('\tF.P : '+str(perf_i[2])+'\tT.N : '+str(perf_i[3]))
        print(str(class_labels[i])+'\t'+str(perf_i[4])+'\t'+str(perf_i[5])+'\t'+str(perf_i[6])+'\t'+str(perf_i[7]))
    return
#------------------------------------------------------------------
def print_All_Performance(conf_matrix, suffix, class_labels, perf_measures):
    res=(suffix+'A\\P' + print_lstr(class_labels)+'\tACC\tPRE\tSEN\tSPF\n')
    nos_l=len(class_labels)
    for i in range(0,nos_l):
        perf_i = np.round(perf_measures [i,:],2)
        res+=(suffix+str(class_labels[i]) + print_cf_row(conf_matrix[i],nos_l )+'\t'+str(perf_i[4])+'\t'+str(perf_i[5])+'\t'+str(perf_i[6])+'\t'+str(perf_i[7])+'\n')
    print(res)
    return
#------------------------------------------------------------------

def plot_ecg_segment(signal_info, signal_array, fsec, tsec, x_scale, y_scale, y_low, y_high, mticks_pos, show_rris, predx, datay,  a_color, a_marker, gain=1):
    # plot signal segments
    #<<---------------------------------------------Select ECG Segment
    dsec = tsec - fsec
    print(signal_info.rec.name)
    if len(signal_array)==0:
        print('WARNING::Signal was not loaded.')
        return 0
    else:
        ff = int(fsec * BASIC_SRATE)
        tt = int(tsec * BASIC_SRATE)
        dd = tt - ff

        bps = signal_array[ff:tt] * gain  # signal data * gain
        lim_query = np.where((signal_info.rp_sec >= fsec) & (signal_info.rp_sec < tsec))[0]
        
        dticks = signal_info.rp_curr[lim_query]-ff  # tick position
        nos_ticks = len(dticks)
        sc_zero = np.zeros(nos_ticks)

        dlabels = signal_info.rl_curr[lim_query]    # orignal labels
        dilabels = signal_info.rli_curr[lim_query]  # mapped labels
        dicolors = np.zeros(nos_ticks, dtype='U15') # get color repesentation of mapped labels
        for i in range(0,nos_ticks):
            dicolors[i]= g_STD_LABELS[dilabels[i]]
        print('Time Interval{'+str(dsec)+'s}:['+str(fsec)+':'+str(tsec)+']')
        if nos_ticks > 0:
            print('Beat Interval{'+str(nos_ticks)+'#}:['+str(lim_query[0])+':'+str(lim_query[-1])+']')
        else:
            print('Beat Interval{'+str(nos_ticks)+'#}')

        #<<---------------------------------------------Prepare Prediction
        #predx = [cmx2_localS,cmx2_localV,cmx2_localA]
        #predy = [datayS,datayV,datayA]
        diPredColL = []
        for i in range(0,len(a_color)):
            dpredx = predx[i][lim_query]
            diPredCol = np.zeros(nos_ticks, dtype='U15') 
            for j in range(0,nos_ticks):
                if dpredx[j]==0:
                    diPredCol[j]= 'tab:green'      
                else:
                    diPredCol[j]= a_color[i]
            diPredColL.append(diPredCol)

#============================================================================================ PLOT         
        plt.figure('ecg signal', figsize = (dsec*x_scale ,2 * (y_high-y_low) * y_scale) )
        plt.xlim(0, len(bps))
        plt.ylim(y_low,y_high + 1.5 )
        plt.yticks([])
        plt.xticks(dticks,dlabels)
        plt.grid(axis='x')
        plt.hlines(y_high,0,len(bps), linewidth=0.3)
        for i in range(0,len(a_color)):
            plt.scatter(dticks,sc_zero+y_high+0.1+(0.35*(i+1)),marker=a_marker[i],color=diPredColL[i])

        daty = datay[-1][lim_query]
        prx = predx[-1][lim_query]
        aNpA = dticks[np.where((daty==0)&(prx==1))[0]]
        aApN = dticks[np.where((daty==1)&(prx==0))[0]]


        # plot signal and baseline
        plt.plot(bps, linewidth=0.5, color='black')
        plt.hlines(0,0,len(bps), linewidth=0.3)
        # plot mapped labels
        plt.scatter(dticks,sc_zero+mticks_pos,marker='s',color=dicolors)
        plt.scatter(aNpA, np.zeros(len(aNpA))-mticks_pos, marker='x', color ='tab:purple' )
        plt.scatter(aApN, np.zeros(len(aApN))-mticks_pos, marker='x', color ='tab:orange' )
        #plt.scatter(dticks,sc_zero-mticks_pos,marker='o',color=diPredColL[-1])
        # finalize
        plt.tight_layout()
        plt.show()     
#============================================================================================ PLOT        
        
        if show_rris:
             ddur = signal_info.rri_dur[lim_query]       # duration
             ddel = np.absolute(signal_info.rri_delta[lim_query] )      # delta rri
             # prepare figure: rri,delta rri
             my_low, my_high = -0.1, 3.5
             plt.figure('ecg meta', figsize = (dsec*x_scale ,(my_high-my_low) * 1.5*y_scale) )
             plt.xlim(0, len(bps))
             plt.ylim(my_low,my_high)
             plt.yticks([])
             plt.xticks(dticks,dlabels)
             #x_grid = np.arange(0,tt-ff, 1*BASIC_SRATE)
             #plt.xticks(x_grid)
             plt.grid(axis='x')
     
             # plot grid and baseline
             plt.hlines(0,0,len(bps), linewidth=0.3,color='red')
             #for j in [0.5,1,1.5,2,2.5,3]:
             #    plt.hlines(j,0,len(bps), linewidth=0.3,color='black')
     
             # plot mapped labels
             plt.scatter(dticks,ddur,marker='s',color=dicolors)
             plt.scatter(dticks,ddel,marker='o',color='tab:purple')
             plt.plot(dticks,ddur,color='black',linewidth=0.5,linestyle='dotted')
             plt.plot(dticks,ddel,color='black',linewidth=0.5,linestyle='dotted')
             # finalize
             plt.tight_layout()
             plt.show()

        return bps,dticks,dlabels

# %% [markdown]
# # [ BUILD STANDARD DBs ]

# %%
print('Buidling standard databases')
#------------------------------------------------------------------------
std_mitdb = ecg_db('mitdb', [])
#------------------------------------------------------------------------
std_svdb = ecg_db('svdb', [])
#------------------------------------------------------------------------
std_incartdb= ecg_db('incartdb', [])
#------------------------------------------------------------------------
# Out:
# Buidling standard databases
#
# Initailze new ecg database ...
# DB NAME :: mitdb
# DATA DIR :: /content/drive/My Drive/Masters/workdir/ecg_data/db_npy/mitdb_npy
# RECORDS :: [48] {'207', '118', '233', '208', '201', '214', '220', '108', '205', '222', '105', '213', '209', '101', '104', '230', '228', '100', '106', '234', '115', '119', '231', '107', '210', '112', '221', '219', '117', '114', '121', '116', '122', '102', '223', '113', '124', '212', '232', '103', '203', '111', '109', '217', '200', '123', '202', '215'}
# TAG RECORDS :: [0] set()
#
# Initailze new ecg database ...
# DB NAME :: svdb
# DATA DIR :: /content/drive/My Drive/Masters/workdir/ecg_data/db_npy/svdb_npy
# RECORDS :: [78] {'893', '874', '824', '863', '843', '827', '801', '856', '872', '808', '847', '881', '887', '803', '825', '826', '861', '871', '802', '848', '882', '886', '894', '869', '879', '805', '807', '846', '844', '860', '880', '889', '851', '852', '804', '875', '868', '870', '888', '840', '811', '854', '867', '855', '884', '885', '892', '841', '850', '857', '878', '821', '891', '842', '845', '876', '800', '890', '864', '820', '823', '873', '877', '849', '859', '810', '858', '866', '809', '828', '862', '812', '829', '865', '883', '806', '822', '853'}
# TAG RECORDS :: [0] set()
#
# Initailze new ecg database ...
# DB NAME :: incartdb
# DATA DIR :: /content/drive/My Drive/Masters/workdir/ecg_data/db_npy/incartdb_npy
# RECORDS :: [75] {'I15', 'I37', 'I35', 'I36', 'I41', 'I70', 'I71', 'I72', 'I49', 'I25', 'I21', 'I42', 'I04', 'I51', 'I63', 'I74', 'I57', 'I40', 'I60', 'I08', 'I28', 'I07', 'I50', 'I59', 'I62', 'I10', 'I11', 'I45', 'I13', 'I17', 'I73', 'I26', 'I01', 'I43', 'I30', 'I22', 'I39', 'I27', 'I67', 'I47', 'I64', 'I02', 'I18', 'I14', 'I29', 'I05', 'I52', 'I54', 'I24', 'I34', 'I48', 'I23', 'I19', 'I16', 'I32', 'I33', 'I53', 'I68', 'I09', 'I06', 'I31', 'I44', 'I56', 'I61', 'I55', 'I58', 'I03', 'I12', 'I65', 'I66', 'I75', 'I38', 'I46', 'I20', 'I69'}
# TAG RECORDS :: [0] set()

# %% [markdown]
# # [ EXP DATA DICT ]

# %%
mitdb_ex = set([
            '102','104','107','217', # paced
            '207',   # VFlutter
            '212', '231',   # both N and BBB
            '108', # bad signal
            '202','203' # bad labeling
            ])
svdb_ex = set([])
incartdb_ex = set([])

#<<--------------------------------------------
std_mitdb.recs_tag = set.difference(std_mitdb.recs, mitdb_ex)
std_svdb.recs_tag = set.difference(std_svdb.recs, svdb_ex)
std_incartdb.recs_tag = set.difference(std_incartdb.recs, incartdb_ex)

#<<--------------------------------------------
std_db_msi = {}
std_db_msi['mitdb']=std_mitdb
std_db_msi['svdb']=std_svdb
std_db_msi['incartdb']=std_incartdb

#<<--------------------------------------------
std_db_ms = {}
std_db_ms['mitdb']=std_mitdb
std_db_ms['svdb']=std_svdb

#<<--------------------------------------------
std_db_mi = {}
std_db_mi['mitdb']=std_mitdb
std_db_mi['incartdb']=std_incartdb

#<<--------------------------------------------
std_db_si = {}
std_db_si['svdb']=std_svdb
std_db_si['incartdb']=std_incartdb

#<<--------------------------------------------
std_db_m = {}
std_db_m['mitdb']=std_mitdb

#<<--------------------------------------------
std_db_s = {}
std_db_s['svdb']=std_svdb

#<<--------------------------------------------
std_db_i = {}
std_db_i['incartdb']=std_incartdb

#<<--------------------------------------------

f20_mitdb_recs = ['109', '115', '117', '119', '114', '105', '121', '123', '100', '103', '116', '113', '112', '122', '118', '101', '106', '124', '111']
r24_mitdb_recs = ['222', '202', '200', '217', '201', '234', '230', '213', '223', '231', '221', '203', '219', '208', '215', '205', '220', '210', '232', '209', '214', '228', '212', '233']
db_mf20 = {'mitdb':ecg_db('mitdb', f20_mitdb_recs)}
db_mr24 = {'mitdb':ecg_db('mitdb', r24_mitdb_recs)}
# Out:
# Initailze new ecg database ...
# DB NAME :: mitdb
# DATA DIR :: /content/drive/My Drive/Masters/workdir/ecg_data/db_npy/mitdb_npy
# RECORDS :: [48] {'207', '118', '233', '208', '201', '214', '220', '108', '205', '222', '105', '213', '209', '101', '104', '230', '228', '100', '106', '234', '115', '119', '231', '107', '210', '112', '221', '219', '117', '114', '121', '116', '122', '102', '223', '113', '124', '212', '232', '103', '203', '111', '109', '217', '200', '123', '202', '215'}
# TAG RECORDS :: [19] {'101', '114', '121', '118', '116', '122', '103', '100', '106', '111', '115', '119', '109', '113', '124', '123', '112', '105', '117'}
#
# Initailze new ecg database ...
# DB NAME :: mitdb
# DATA DIR :: /content/drive/My Drive/Masters/workdir/ecg_data/db_npy/mitdb_npy
# RECORDS :: [48] {'207', '118', '233', '208', '201', '214', '220', '108', '205', '222', '105', '213', '209', '101', '104', '230', '228', '100', '106', '234', '115', '119', '231', '107', '210', '112', '221', '219', '117', '114', '121', '116', '122', '102', '223', '113', '124', '212', '232', '103', '203', '111', '109', '217', '200', '123', '202', '215'}
# TAG RECORDS :: [24] {'233', '208', '201', '220', '214', '205', '222', '213', '209', '234', '230', '228', '231', '210', '221', '219', '223', '212', '232', '203', '217', '200', '202', '215'}

# %% [markdown]
# # [ --- EXP_3 : multiple --- ]

# %% [markdown]
# This experiment classifies beats into Normal or Abnormal category. Annotations used are N,S,V (F beats are included in V type) using CNN and variable beat length padded or truncated appropiately

# %% [markdown]
# # [ VIEW ANNOTATION MAPPERS ]

# %%
ls_ants = os.listdir(global_antdir)
ls_ants=np.sort(ls_ants)
print('Available annotation files ['+str(len(ls_ants))+']')
for ls_ant in ls_ants:
    print(ls_ant)
print('--------------------------')

# %% [markdown]
# # [ MAP ANNOTATIONS ]

# %%
# standard labels and mappings default_labels
sel_labels = os.path.join(global_antdir, 'nsv_labels.txt') 
sel_map = os.path.join(global_antdir, 'nsv_map.txt') 

# ----------------------------------------------------------------------
# ------ load standard labels ------------------------------------------
# ----------------------------------------------------------------------
sel_labels_data = np.loadtxt(sel_labels, dtype='str',delimiter="\t")
g_STD_LABELS={}
print('\nStandard Labels::')
for a in sel_labels_data:
    # a[0] =  # standard label (char)
    # a[1] =  # mapped color (str)
    # a[2]  = # description (str)
    g_STD_LABELS[a[0]]= a[1]
    print(a[0]+'\t'+a[1]+'\t'+a[2])

# ----------------------------------------------------------------------
# ------ load mapping data ---------------------------------------------
# ----------------------------------------------------------------------
ant_map_data = np.loadtxt(sel_map, dtype='str',delimiter="\t")
g_STD_NO_MAP = '_'
g_STD_LABELS[g_STD_NO_MAP]='black'
g_STD_MAP={}
print('\nMapping::')
for a in ant_map_data:
    # a[0] =  # orignal pysionet label (char)
    # a[1] =  # mapped standard label (char)
    # a[2]  = # description (str)
    g_STD_MAP[a[0]]= a[1] ##<<----------------mapping dictionary
    print(a[0]+'\t'+a[1]+'\t'+a[2])
print('\n',g_STD_MAP.keys())

#<<--------------------------------------------
N_Label, S_Label, V_Label, A_Label  = 'N', 'S', 'V', 'A'
gS_LABELS, gV_LABELS, gA_LABELS = [N_Label,S_Label], [N_Label,V_Label], [N_Label,A_Label]

NRB_DRR = 0.04
print('db_record\t#beats\t#_N_\t#NNN\t#ANA\t#NRB')
for idb in std_db_msi.keys():
    sel_db = std_db_msi[idb]
    for irec in sel_db.recs_tag:
        sel_rec = sel_db.get_record(irec)
        sel_info = sel_rec.read_binfo()
        sel_info.map_ants2int(g_STD_MAP)
        cB = sel_info.map_ants2int(g_STD_MAP)
        cNRB = sel_info.map_NRB(N_Label, NRB_DRR)
        print(sel_rec.name+'\t'+str(cB)+'\t'+str(len(sel_info.n_list))+'\t'+str(len(sel_info.nnn_list))+'\t'+str(len(sel_info.ana_list))+'\t'+str(cNRB))

for idb in db_mf20.keys():
    sel_db = db_mf20[idb]
    for irec in sel_db.recs_tag:
        sel_rec = sel_db.get_record(irec)
        sel_info = sel_rec.read_binfo()
        sel_info.map_ants2int(g_STD_MAP)
        cB = sel_info.map_ants2int(g_STD_MAP)
        cNRB = sel_info.map_NRB(N_Label, NRB_DRR)
        print(sel_rec.name+'\t'+str(cB)+'\t'+str(len(sel_info.n_list))+'\t'+str(len(sel_info.nnn_list))+'\t'+str(len(sel_info.ana_list))+'\t'+str(cNRB))

for idb in db_mr24.keys():
    sel_db = db_mr24[idb]
    for irec in sel_db.recs_tag:
        sel_rec = sel_db.get_record(irec)
        sel_info = sel_rec.read_binfo()
        sel_info.map_ants2int(g_STD_MAP)
        cB = sel_info.map_ants2int(g_STD_MAP)
        cNRB = sel_info.map_NRB(N_Label, NRB_DRR)
        print(sel_rec.name+'\t'+str(cB)+'\t'+str(len(sel_info.n_list))+'\t'+str(len(sel_info.nnn_list))+'\t'+str(len(sel_info.ana_list))+'\t'+str(cNRB))
# Out:
# Standard Labels::
# N	green	Normal
# S	red	Supraventricular Premature
# V	blue	Ventricular Premature
#
# Mapping::
# N	N	Normal beat
# L	N	Left bundle branch block beat
# R	N	Right bundle branch block beat
# B	N	Bundle branch block beat (unspecified)
# A	S	Atrial premature beat
# a	S	Aberrated atrial premature beat
# J	S	Nodal (junctional) premature beat
# S	S	Supraventricular premature or ectopic beat (atrial or nodal)
# V	V	Premature ventricular contraction
# r	V	R-on-T premature ventricular contraction
# F	V	Fusion of ventricular and normal beat
# e	_	Atrial escape beat
# j	_	Nodal (junctional) escape beat
# n	_	Supraventricular escape beat (atrial or nodal)
# E	_	Ventricular escape beat
# /	_	Paced beat
# f	_	Fusion of paced and normal beat
# Q	_	Unclassifiable
# ?	_	Beat not classified during learning
# [	_	Start of ventricular flutter/fibrillation
# !	_	Ventricular flutter wave
# ]	_	End of ventricular flutter/fibrillation
# x	_	Non-conducted P-wave (blocked APC)
# (	_	Waveform onset
# )	_	Waveform end
# p	_	Peak of P-wave
# t	_	Peak of T-wave
# u	_	Peak of U-wave
# `	_	PQ junction
# '	_	J-point
# ^	_	(Non-captured) pacemaker artifact
# |	_	Isolated QRS-like artifact [1]
# ~	_	Change in signal quality [1]
# +	_	Rhythm change [2]
# s	_	ST segment change [2]
# T	_	T-wave change [2]
# *	_	Systole
# D	_	Diastole
# =	_	Measurement annotation [2]
# "	_	Comment annotation [2]
# @	_	Link to external data [3]
#
#  dict_keys(['N', 'L', 'R', 'B', 'A', 'a', 'J', 'S', 'V', 'r', 'F', 'e', 'j', 'n', 'E', '/', 'f', 'Q', '?', '[', '!', ']', 'x', '(', ')', 'p', 't', 'u', '`', "'", '^', '|', '~', '+', 's', 'T', '*', 'D', '=', '"', '@'])
# db_record	#beats	#_N_	#NNN	#ANA	#NRB
# mitdb_118	None	2164	1957	207	1866
# mitdb_233	None	2229	895	1334	890
# mitdb_208	None	1585	242	1343	224
# mitdb_201	None	1623	1076	547	252
# mitdb_214	None	2001	1515	486	1056
# mitdb_220	None	1952	1832	120	1696
# mitdb_205	None	2569	2494	75	2485
# mitdb_222	None	2060	1819	241	603
# mitdb_105	None	2524	2432	92	2338
# mitdb_213	None	2639	1897	742	1844
# mitdb_209	None	2619	2360	259	2079
# mitdb_101	None	1858	1848	10	1327
# mitdb_230	None	2253	2251	2	1984
# mitdb_228	None	1686	1172	514	571
# mitdb_100	None	2237	2169	68	1914
# mitdb_106	None	1505	987	518	569
# mitdb_234	None	2698	2690	8	2670
# mitdb_115	None	1951	1951	0	918
# mitdb_119	None	1541	823	718	618
# mitdb_210	None	2421	2078	343	678
# mitdb_112	None	2535	2531	4	2498
# mitdb_221	None	2029	1261	768	347
# mitdb_219	None	2080	1942	138	429
# mitdb_117	None	1532	1530	2	1166
# mitdb_114	None	1818	1718	100	1125
# mitdb_121	None	1859	1856	3	1795
# mitdb_116	None	2300	2085	215	2063
# mitdb_122	None	2474	2474	0	2399
# mitdb_223	None	2027	1567	460	1490
# mitdb_113	None	1787	1775	12	681
# mitdb_124	None	1529	1488	41	997
# mitdb_232	None	396	31	365	4
# mitdb_103	None	2080	2076	4	1694
# mitdb_111	None	2121	2119	2	1705
# mitdb_109	None	2490	2410	80	2203
# mitdb_200	None	1742	793	949	467
# mitdb_123	None	1513	1507	6	490
# mitdb_215	None	3193	2908	285	2732
# svdb_874	None	2188	2103	85	2069
# svdb_827	None	1842	1808	34	1607
# svdb_872	None	1896	1730	166	1681
# svdb_802	None	1584	1535	49	1159
# svdb_848	None	4226	4164	62	3891
# svdb_894	None	2211	1956	255	1861
# svdb_869	None	1506	550	956	375
# svdb_805	None	2089	1676	413	1614
# svdb_807	None	1911	1873	38	1755
# svdb_846	None	1659	1649	10	1477
# svdb_844	None	1648	1570	78	1211
# svdb_889	None	1464	1076	388	790
# svdb_875	None	1944	1779	165	1757
# svdb_870	None	1785	574	1211	442
# svdb_854	None	1788	525	1263	303
# svdb_885	None	1504	684	820	574
# svdb_892	None	1740	265	1475	199
# svdb_841	None	1489	1061	428	746
# svdb_850	None	1829	1824	5	1748
# svdb_857	None	2400	2120	280	1981
# svdb_842	None	2392	2150	242	1726
# svdb_800	None	1844	1772	72	1432
# svdb_873	None	1624	1512	112	1353
# svdb_877	None	1839	1506	333	989
# svdb_849	None	2058	1952	106	1793
# svdb_883	None	1771	1686	85	1611
# svdb_865	None	1101	662	439	594
# svdb_829	None	1885	1730	155	1344
# svdb_806	None	2950	2830	120	2825
# svdb_825	None	2651	2361	290	2350
# svdb_822	None	1673	960	713	905
# svdb_893	None	2188	1533	655	618
# svdb_824	None	2214	1823	391	1634
# svdb_863	None	2560	1572	988	1441
# svdb_843	None	2647	2575	72	2559
# svdb_801	None	2173	1835	338	1687
# svdb_856	None	2810	2756	54	2747
# svdb_808	None	1744	1724	20	1691
# svdb_847	None	1665	1528	137	1401
# svdb_881	None	1323	370	953	238
# svdb_803	None	1922	1634	288	1609
# svdb_826	None	2579	2436	143	1248
# svdb_861	None	1873	912	961	558
# svdb_871	None	1774	1735	39	1430
# svdb_882	None	1887	1798	89	1738
# svdb_886	None	2168	2066	102	1976
# svdb_879	None	1470	652	818	557
# svdb_860	None	1672	241	1431	226
# svdb_880	None	3103	2478	625	2278
# svdb_851	None	2167	1366	801	1307
# svdb_852	None	2332	1854	478	1103
# svdb_804	None	2651	2355	296	665
# svdb_868	None	2553	1476	1077	771
# svdb_888	None	2189	1952	237	1935
# svdb_840	None	2339	2329	10	2089
# svdb_811	None	1404	1380	24	753
# svdb_867	None	2787	2523	264	1571
# svdb_855	None	2034	1237	797	660
# svdb_884	None	2484	1750	734	1707
# svdb_878	None	1589	998	591	837
# svdb_891	None	2120	1289	831	1232
# svdb_821	None	2480	1297	1183	1000
# svdb_845	None	2826	2732	94	2324
# svdb_876	None	2004	1741	263	931
# svdb_890	None	2001	1684	317	1672
# svdb_864	None	1742	1582	160	1534
# svdb_820	None	2161	1785	376	1777
# svdb_823	None	2477	1894	583	1781
# svdb_859	None	3007	2210	797	1431
# svdb_810	None	1837	1726	111	1662
# svdb_858	None	2167	2165	2	2133
# svdb_866	None	2050	1218	832	809
# svdb_809	None	2430	2421	9	2412
# svdb_828	None	1755	1482	273	1274
# svdb_862	None	2132	2047	85	1901
# svdb_812	None	1756	1616	140	1529
# svdb_887	None	2352	1741	611	1713
# svdb_853	None	2105	1876	229	1560
# incartdb_I72	None	1873	1113	760	1095
# incartdb_I71	None	1633	1574	59	1120
# incartdb_I25	None	1703	1698	5	1416
# incartdb_I21	None	2070	1868	202	1588
# incartdb_I51	None	1969	1095	874	1021
# incartdb_I04	None	2267	2020	247	1901
# incartdb_I63	None	1845	1660	185	1563
# incartdb_I60	None	2422	2418	4	2181
# incartdb_I08	None	1776	1348	428	1232
# incartdb_I28	None	1711	1703	8	719
# incartdb_I07	None	2638	2517	121	2270
# incartdb_I10	None	3597	3431	166	3425
# incartdb_I11	None	2076	2027	49	1263
# incartdb_I13	None	1791	1332	459	1037
# incartdb_I73	None	1888	1704	184	1680
# incartdb_I26	None	1496	1487	9	1069
# incartdb_I30	None	1705	786	919	595
# incartdb_I22	None	2814	2238	576	2090
# incartdb_I39	None	1460	925	535	761
# incartdb_I64	None	1885	1849	36	1762
# incartdb_I02	None	2443	1991	452	1943
# incartdb_I18	None	2660	1823	837	1733
# incartdb_I29	None	1835	904	931	728
# incartdb_I54	None	2338	2302	36	2254
# incartdb_I52	None	1608	1469	139	977
# incartdb_I34	None	1427	478	949	343
# incartdb_I19	None	1212	82	1130	34
# incartdb_I16	None	1518	1514	4	1055
# incartdb_I68	None	2479	2155	324	2145
# incartdb_I09	None	2946	2853	93	2479
# incartdb_I06	None	2434	2320	114	1967
# incartdb_I31	None	1843	466	1377	428
# incartdb_I56	None	1670	1604	66	1324
# incartdb_I55	None	2146	2118	28	2098
# incartdb_I58	None	2311	2291	20	2275
# incartdb_I03	None	2323	2102	221	2016
# incartdb_I65	None	2271	1521	750	1412
# incartdb_I66	None	2137	1744	393	1635
# incartdb_I75	None	1482	326	1156	324
# incartdb_I38	None	2153	1240	913	1235
# incartdb_I46	None	2230	1379	851	1342
# incartdb_I15	None	2630	2624	6	2533
# incartdb_I37	None	2007	1273	734	1229
# incartdb_I35	None	3198	2387	811	2337
# incartdb_I36	None	3447	2739	708	2667
# incartdb_I41	None	1622	1612	10	568
# incartdb_I70	None	1538	1286	252	1254
# incartdb_I49	None	2118	2064	54	1177
# incartdb_I42	None	1544	98	1446	85
# incartdb_I74	None	2080	1567	513	1400
# incartdb_I57	None	2839	2784	55	2778
# incartdb_I40	None	2566	2462	104	2430
# incartdb_I50	None	2992	2984	8	1588
# incartdb_I62	None	1451	1387	64	1138
# incartdb_I59	None	2024	1938	86	1343
# incartdb_I45	None	1435	456	979	378
# incartdb_I17	None	1643	1590	53	1445
# incartdb_I01	None	2411	1732	679	1708
# incartdb_I43	None	1085	0	1085	0
# incartdb_I67	None	2436	1388	1048	1270
# incartdb_I27	None	1884	477	1407	457
# incartdb_I47	None	1857	1681	176	713
# incartdb_I14	None	1800	1672	128	1317
# incartdb_I05	None	1518	1302	216	1198
# incartdb_I24	None	2563	2551	12	2426
# incartdb_I48	None	2117	1653	464	994
# incartdb_I23	None	2190	2166	24	2021
# incartdb_I32	None	1560	1477	83	904
# incartdb_I33	None	1245	273	972	117
# incartdb_I53	None	1150	29	1121	21
# incartdb_I44	None	1801	436	1365	433
# incartdb_I61	None	1451	1449	2	532
# incartdb_I12	None	2798	2784	14	2746
# incartdb_I20	None	2360	1856	504	1706
# incartdb_I69	None	1998	1663	335	1653
# mitdb_101	None	1858	1848	10	1327
# mitdb_114	None	1818	1718	100	1125
# mitdb_121	None	1859	1856	3	1795
# mitdb_118	None	2164	1957	207	1866
# mitdb_116	None	2300	2085	215	2063
# mitdb_122	None	2474	2474	0	2399
# mitdb_103	None	2080	2076	4	1694
# mitdb_100	None	2237	2169	68	1914
# mitdb_106	None	1505	987	518	569
# mitdb_111	None	2121	2119	2	1705
# mitdb_115	None	1951	1951	0	918
# mitdb_119	None	1541	823	718	618
# mitdb_109	None	2490	2410	80	2203
# mitdb_113	None	1787	1775	12	681
# mitdb_124	None	1529	1488	41	997
# mitdb_123	None	1513	1507	6	490
# mitdb_112	None	2535	2531	4	2498
# mitdb_105	None	2524	2432	92	2338
# mitdb_117	None	1532	1530	2	1166
# mitdb_233	None	2229	895	1334	890
# mitdb_208	None	1585	242	1343	224
# mitdb_201	None	1623	1076	547	252
# mitdb_220	None	1952	1832	120	1696
# mitdb_214	None	2001	1515	486	1056
# mitdb_205	None	2569	2494	75	2485
# mitdb_222	None	2060	1819	241	603
# mitdb_213	None	2639	1897	742	1844
# mitdb_209	None	2619	2360	259	2079
# mitdb_234	None	2698	2690	8	2670
# mitdb_230	None	2253	2251	2	1984
# mitdb_228	None	1686	1172	514	571
# mitdb_231	None	1566	1563	3	842
# mitdb_210	None	2421	2078	343	678
# mitdb_221	None	2029	1261	768	347
# mitdb_219	None	2080	1942	138	429
# mitdb_223	None	2027	1567	460	1490
# mitdb_212	None	2746	2746	0	2478
# mitdb_232	None	396	31	365	4
# mitdb_203	None	2527	1931	596	348
# mitdb_217	None	244	99	145	47
# mitdb_200	None	1742	793	949	467
# mitdb_202	None	2059	1963	96	953
# mitdb_215	None	3193	2908	285	2732

# %% [markdown]
# # [ NRB MEDIAN ]

# %%
# for each record, divide NRBs into 10 bins with limited duration range

def select_NRB_Bin(nBin, sel_info, ordered):
    res = []
    if sel_info.NRBc==0:
        return res

    dNRB = sel_info.dNRB
    
    if len(dNRB)==0:
        return res

    dLow, dHigh = sel_info.dLow ,sel_info.dHigh

    bDelta = (dHigh-dLow)/nBin
    bins = np.hstack((np.arange(dLow,dHigh,bDelta),np.array([dHigh+0.01])))
    
    #print(bins)
    #print(bins.shape)
    #dsum = 0
    dBCont1 = []
    dBLens = []

    for i in range(0,nBin):
        this_bin = list(np.where( (dNRB>=bins[i]) & (dNRB<bins[i+1]) )[0])
        if len(this_bin)!=0:
            # select one from this bin
            dBCont1.append(this_bin)
            dBLens.append(len(this_bin))
            
    #print('lens:',dBLens)
    dBLena =  np.flip( np.argsort( np.array(dBLens), axis=0) )
    #print('indices acess',dBLena)

    dBCont=[]
    #print(len(dBCont))
    for i in range(0, len(dBLena)):
        #print(type(dBLena[i]),dBLena[i])
        #print(type(dBCont1[dBLena[i]]),dBCont1[dBLena[i]] )

        dBCont.append( dBCont1[dBLena[i]] )
        

    i = 0
    while True:
        #print(len(dBCont))
        if len(res)==nBin or len(dBCont)==0:
            break
        ldbc = len(dBCont[i])
        #print(type(dBCont[i]),dBCont[i] )
        if ldbc>0:
            if ldbc==1:
                res.append(  sel_info.NRBi[ dBCont[i].pop(0) ]   )
                dBCont.pop(i)
            else:
                if ordered:
                    res.append(  sel_info.NRBi[ dBCont[i].pop(0) ]   )
                else:
                    res.append(  sel_info.NRBi[ dBCont[i].pop( random.randint(0,ldbc-1) ) ]   )
                i+=1
            if i>= len(dBCont):
                i=0
        else:
            print('Impossibruuu!!!')

    return res

# %% [markdown]
# # [ PARAMS ]

# %%
#dataparams (self, vdim_sec, peak_ratio, pad_value, sLsamp, sRsamp):
print('\nS-Params')
S_DP = data_params(3, 0.85, 0, 12, 12)
print('\nV-Params')
V_DP = data_params(3, 0.10, 0, 24, 24)
# Out:
# S-Params
# Vector Dimension: 384
# Peak Ratio: 0.85 [ 326 , 58 ]
# Padding Value: 0
# Suppress Peaks: 12 12
#
# V-Params
# Vector Dimension: 384
# Peak Ratio: 0.1 [ 38 , 346 ]
# Padding Value: 0
# Suppress Peaks: 24 24

# %% [markdown]
# # [ ~List models and datasets ]

# %%
print(global_dsdir)
ls_ants = os.listdir(global_dsdir)
ls_ants=np.sort(ls_ants)
print('Available datasets ['+str(len(ls_ants))+']')
for ls_ant in ls_ants:
    print(ls_ant)
print('--------------------------')
print(global_modeldir)
ls_ants = os.listdir(global_modeldir)
ls_ants=np.sort(ls_ants)
print('Available Models ['+str(len(ls_ants))+']')
for ls_ant in ls_ants:
    print(ls_ant)
print('--------------------------')
# Out:
# /content/drive/My Drive/Masters/workdir/ecg_data/db_dataset
# Available datasets [80]
# S_i_1_test.npy
# S_i_25_1.npy
# S_i_25_2.npy
# S_i_50_1.npy
# S_i_50_2.npy
# S_i_75_1.npy
# S_i_75_2.npy
# S_m_1_test.npy
# S_m_25_1.npy
# S_m_25_1f20.npy
# S_m_25_2.npy
# S_m_50_1.npy
# S_m_50_1f20.npy
# S_m_50_2.npy
# S_m_75_1.npy
# S_m_75_2.npy
# S_msi_100_1.npy
# S_msi_100_2.npy
# S_msi_100_3.npy
# S_msi_150_1.npy
# S_msi_150_2.npy
# S_msi_200_1.npy
# S_msi_200_2.npy
# S_msi_25_1.npy
# S_msi_25_2.npy
# S_msi_25_3.npy
# S_msi_50_1.npy
# S_msi_50_2.npy
# S_msi_50_3.npy
# S_msi_5_val.npy
# S_msi_75_1.npy
# S_msi_75_2.npy
# S_msi_75_3.npy
# S_s_1_test.npy
# S_s_25_1.npy
# S_s_25_2.npy
# S_s_50_1.npy
# S_s_50_2.npy
# S_s_75_1.npy
# S_s_75_2.npy
# V_i_1_test.npy
# V_i_25_1.npy
# V_i_25_2.npy
# V_i_50_1.npy
# V_i_50_2.npy
# V_i_75_1.npy
# V_i_75_2.npy
# V_m_1_test.npy
# V_m_25_1.npy
# V_m_25_1f20.npy
# V_m_25_2.npy
# V_m_50_1.npy
# V_m_50_1f20.npy
# V_m_50_2.npy
# V_m_75_1.npy
# V_m_75_2.npy
# V_msi_100_1.npy
# V_msi_100_2.npy
# V_msi_100_3.npy
# V_msi_150_1.npy
# V_msi_150_2.npy
# V_msi_200_1.npy
# V_msi_200_2.npy
# V_msi_25_1.npy
# V_msi_25_2.npy
# V_msi_25_3.npy
# V_msi_50_1.npy
# V_msi_50_2.npy
# V_msi_50_3.npy
# V_msi_5_val.npy
# V_msi_75_1.npy
# V_msi_75_2.npy
# V_msi_75_3.npy
# V_s_1_test.npy
# V_s_25_1.npy
# V_s_25_2.npy
# V_s_50_1.npy
# V_s_50_2.npy
# V_s_75_1.npy
# V_s_75_2.npy
# --------------------------
# /content/drive/My Drive/Masters/workdir/ecg_data/db_model
# Available Models [82]
# M_S_i_50_2.h5
# M_S_i_50_2_S_s_50_2.h5
# M_S_i_75_1.h5
# M_S_i_75_1_S_s_75_1.h5
# M_S_m_25_1f20.h5
# M_S_m_25_1f20NRS.h5
# M_S_m_50_1f20.h5
# M_S_m_50_1f20NRS.h5
# M_S_m_50_2.h5
# M_S_m_50_2_S_i_50_2.h5
# M_S_m_50_2_S_s_50_2.h5
# M_S_m_75_1.h5
# M_S_m_75_1_S_i_75_1.h5
# M_S_m_75_1_S_s_75_1.h5
# M_S_m_75_1_S_s_75_1_S_i_75_1.h5
# M_S_m_75_1_S_s_75_1_S_i_75_1NRB.h5
# M_S_m_75_2_S_s_75_2_S_i_75_2.h5
# M_S_m_75_2_S_s_75_2_S_i_75_2NRB.h5
# M_S_s_50_2.h5
# M_S_s_75_1.h5
# M_V_i_50_2.h5
# M_V_i_50_2_V_s_50_2.h5
# M_V_i_75_1.h5
# M_V_i_75_1_V_s_75_1.h5
# M_V_m_25_1f20.h5
# M_V_m_25_1f20NRS.h5
# M_V_m_50_1f20.h5
# M_V_m_50_1f20NRS.h5
# M_V_m_50_2.h5
# M_V_m_50_2_V_i_50_2.h5
# M_V_m_50_2_V_s_50_2.h5
# M_V_m_75_1.h5
# M_V_m_75_1_V_i_75_1.h5
# M_V_m_75_1_V_s_75_1.h5
# M_V_m_75_1_V_s_75_1_V_i_75_1.h5
# M_V_m_75_1_V_s_75_1_V_i_75_1NRB.h5
# M_V_m_75_2_V_s_75_2_V_i_75_2.h5
# M_V_m_75_2_V_s_75_2_V_i_75_2NRB.h5
# M_V_s_50_2.h5
# M_V_s_75_1.h5
# Q_S_i_50_2.h5
# Q_S_i_50_2NRS.h5
# Q_S_i_50_2_S_s_50_2.h5
# Q_S_i_75_1.h5
# Q_S_i_75_1NRS.h5
# Q_S_i_75_1_S_s_75_1.h5
# Q_S_m_25_1f20NRS.h5
# Q_S_m_50_2.h5
# Q_S_m_50_2NRS.h5
# Q_S_m_50_2_S_i_50_2.h5
# Q_S_m_50_2_S_s_50_2.h5
# Q_S_m_75_1.h5
# Q_S_m_75_1NRS.h5
# Q_S_m_75_1_S_i_75_1.h5
# Q_S_m_75_1_S_s_75_1.h5
# Q_S_m_75_1_S_s_75_1_S_i_75_1.h5
# Q_S_m_75_2_S_s_75_2_S_i_75_2.h5
# Q_S_s_50_2.h5
# Q_S_s_50_2NRS.h5
# Q_S_s_75_1.h5
# Q_S_s_75_1NRS.h5
# Q_V_i_50_2.h5
# Q_V_i_50_2NRS.h5
# Q_V_i_50_2_V_s_50_2.h5
# Q_V_i_75_1.h5
# Q_V_i_75_1NRS.h5
# Q_V_i_75_1_V_s_75_1.h5
# Q_V_m_50_2.h5
# Q_V_m_50_2NRS.h5
# Q_V_m_50_2_V_i_50_2.h5
# Q_V_m_50_2_V_s_50_2.h5
# Q_V_m_75_1.h5
# Q_V_m_75_1NRS.h5
# Q_V_m_75_1_V_i_75_1.h5
# Q_V_m_75_1_V_s_75_1.h5
# Q_V_m_75_1_V_s_75_1_V_i_75_1.h5
# Q_V_m_75_2_V_s_75_2_V_i_75_2.h5
# Q_V_s_50_2.h5
# Q_V_s_50_2NRS.h5
# Q_V_s_75_1.h5
# Q_V_s_75_1NRS.h5
# model_[12]
# --------------------------

# %% [markdown]
# # [ DATASET FUNCTIONS ]

# %%
def repeat_array(A, max_len, shuffle):
    lenA = len(A)
    if lenA==0 or lenA==max_len:
        return A
    if lenA>max_len:
        a = np.random.choice(A, size=max_len, replace=False, p=None)
    else:
        req_n = max_len - lenA
        req_m = int(req_n/lenA)
        req_r = req_n % lenA
        a = np.random.choice(A, size=req_r, replace=False, p=None)
        for i in range(0,req_m+1):
            a = np.hstack((a,A))
    for i in range(0,shuffle):
        np.random.shuffle(a)
    return a
#<<-----------------------------------------------#<<-----------------------------------------------
#<<-----------------------------------------------#<<-----------------------------------------------
def get_normal_selection(binfo, selc, NC_statergy, shuffle):
    nnn_q = binfo.nnn_list
    ana_q = binfo.ana_list
    n_q= binfo.n_list

    nnn_c = len(nnn_q)
    ana_c = len(ana_q)
    n_c = len(n_q)

    selF = int(selc/2)
    selL = selc - selF
    rN3 = int(selc*nnn_c/n_c) 
    rNA = selc - rN3
    
    #print(nnn_c,ana_c,n_c)

    if NC_statergy == 'pure':
        nc_ind = repeat_array(nnn_q,selc,shuffle)  
    elif NC_statergy == 'semi':
        nc_ind = np.hstack((repeat_array(nnn_q,selF,shuffle),repeat_array(ana_q,selL,shuffle)))
    elif NC_statergy == 'dynamic':
        nc_ind = np.hstack((repeat_array(nnn_q,rN3,shuffle),repeat_array(ana_q,rNA,shuffle)))
    elif NC_statergy == 'random':
        nc_ind = repeat_array(n_q,selc,shuffle)
    else:
        print('Invalid NC_Statergy')
        nc_ind = np.array([0])
    
    return nc_ind
#<<-----------------------------------------------#<<-----------------------------------------------
#<<-----------------------------------------------#<<-----------------------------------------------

def generate_dataset_train(work_db, ex_limL, ex_limU, rli_ALabel,  NC_statergy, shuffle, nrb_bin_ordered ):
    nos_records=[]
    ds_selected = np.zeros((0,5), dtype='U10') # [db,rec,nr,c]
    for idb in work_db.keys():
        #<<--------------------
        sel_db = work_db[idb]
        for irec in sel_db.recs_tag:
            #<<--------------------
            sel_rec = sel_db.get_record(irec)
            #print('\n'+sel_rec.name)
            sbi = sel_rec.read_binfo()

            # find out all Abnormal beats
            a_query = ((sbi.rli_curr==rli_ALabel))
            a_indices = np.where(a_query)[0]
            a_count = len(a_indices)
            # limit A-type beats
            sela = 0
            if a_count<ex_limL:
                sela=0
            elif a_count>ex_limU:
                sela=ex_limU
            else:
                sela=a_count
    #<<-----------------------------------------------
            if sela==0:
                #print(sel_rec.name, '_')
                continue
    #<<-----------------------------------------------
            nr_indices = repeat_array( select_NRB_Bin(sela ,sbi,nrb_bin_ordered ), sela, shuffle, )
            nr_count = len(nr_indices)
            nc_indices = get_normal_selection(sbi, sela,  NC_statergy, shuffle)
            nc_count = len(nc_indices)
            if nr_count!=nc_count:
                print('Error: SEL-NR-NC count mismatch for ', sel_rec.name,sela, nr_count, nc_count, '..skip')
                continue

            nos_records.append(sel_rec.name)    
            for i in range(0,sela):
                tn = np.array([idb,irec,str(nr_indices[i]),str(nc_indices[i]),'0'])
                ta = np.array([idb,irec,str(nr_indices[i]),str(a_indices[i]),'1'])
                ds_selected = np.vstack((ds_selected,tn,ta))
    return ds_selected, nos_records
#<<-----------------------------------------------#<<-----------------------------------------------
#<<-----------------------------------------------#<<-----------------------------------------------

def pad_or_truncate(d_Sigo, d_Peak, dparam ):
    vL = dparam.fix_left
    vR = dparam.fix_right
    pad_value = dparam.pad_value
    supL, supR = dparam.supL, dparam.supR
    d_Sig = np.copy(d_Sigo)

    d_Sig[0:supL]=pad_value
    if supR>0:
        d_Sig[-supR:]=pad_value
    
    d_SigL = d_Sig[0:d_Peak]
    d_SigR = d_Sig[d_Peak:]
    
    deltaL = vL - len(d_SigL)
    if deltaL>0:
        # need to pad
        d_SigL = np.hstack((np.zeros(deltaL)+pad_value,d_SigL))
    elif deltaL<0:
        # need to truncate
        d_SigL = d_SigL[-deltaL:]
    else:
        pass
        
    deltaR = vR - len(d_SigR)
    if deltaR>0:
        # need to pad
        d_SigR = np.hstack((d_SigR,np.zeros(deltaR)+pad_value))
    elif deltaR<0:
        # need to truncate
        d_SigR = d_SigR[0:(len(d_SigR)+deltaR)]
    else:
        pass

    return np.hstack((d_SigL,d_SigR))

def load_beat_segment2(ds_str, work_db, dparam, supress_NR=False): # string list of samples as input ('databse','record','NR','CR', 'Label')
    ds_selected = np.zeros((0,dparam.vdim,2),dtype='float')
    #ds_selectedL = np.zeros((0),dtype='float')
    
    for i in range(0,len(ds_str)):
        d = ds_str[i]
        d_db = d[0]
        d_rec = d[1]
        d_NRi = int(d[2])
        d_CRi = int(d[3])
        #d_L = np.array([int(d[4])])

        sel_rec = work_db[d_db].get_record(d_rec)
        sel_info = sel_rec.read_binfo()

        if supress_NR:
            d_NR = np.zeros(dparam.vdim)
        else:
            d_NR,dpk,_= sel_info.get_signal_data_var(d_NRi)
            d_NR=pad_or_truncate(d_NR, dpk, dparam)

        d_CR,cpk,_ = sel_info.get_signal_data_var(d_CRi)
        d_CR = pad_or_truncate(d_CR, cpk, dparam)

        d_data = np.expand_dims(np.transpose(np.vstack((
            d_NR,
            d_CR
        ))),axis=0)
        ds_selected = np.vstack((ds_selected,d_data))
    
    return ds_selected

# %% [markdown]
# ### [ generate training dataset ]

# %%
#for training
ds_genparams =  [ # [postfix ,abL, train_db, exlimL, exlimu, NCs, ]
#---------------------------------------------------------------------------------1
                 ['1', S_Label,std_db_msi,12,25,'dynamic'],
                 ['2', S_Label,std_db_msi,12,25,'dynamic'],
                 ['3', S_Label,std_db_msi,12,25,'dynamic'],

                 ['1', V_Label,std_db_msi,12,25,'dynamic'],
                 ['2', V_Label,std_db_msi,12,25,'dynamic'],
                 ['3', V_Label,std_db_msi,12,25,'dynamic'],
#---------------------------------------------------------------------------------2
                 ['1', S_Label,std_db_msi,12,50,'dynamic'],
                 ['2', S_Label,std_db_msi,12,50,'dynamic'],
                 ['3', S_Label,std_db_msi,12,50,'dynamic'],

                 ['1', V_Label,std_db_msi,12,50,'dynamic'],
                 ['2', V_Label,std_db_msi,12,50,'dynamic'],
                 ['3', V_Label,std_db_msi,12,50,'dynamic'],
#---------------------------------------------------------------------------------3
                 ['1', S_Label,std_db_msi,12,75,'dynamic'],
                 ['2', S_Label,std_db_msi,12,75,'dynamic'],
                 ['3', S_Label,std_db_msi,12,75,'dynamic'],

                 ['1', V_Label,std_db_msi,12,75,'dynamic'],
                 ['2', V_Label,std_db_msi,12,75,'dynamic'],
                 ['3', V_Label,std_db_msi,12,75,'dynamic'],
#---------------------------------------------------------------------------------4
                 ['1', S_Label,std_db_msi,12,100,'dynamic'],
                 ['2', S_Label,std_db_msi,12,100,'dynamic'],
                 ['3', S_Label,std_db_msi,12,100,'dynamic'],

                 ['1', V_Label,std_db_msi,12,100,'dynamic'],
                 ['2', V_Label,std_db_msi,12,100,'dynamic'],
                 ['3', V_Label,std_db_msi,12,100,'dynamic'],
#---------------------------------------------------------------------------------5
                 ['1', S_Label,std_db_msi,12,150,'dynamic'],
                 ['2', S_Label,std_db_msi,12,150,'dynamic'],

                 ['1', V_Label,std_db_msi,12,150,'dynamic'],
                 ['2', V_Label,std_db_msi,12,150,'dynamic'],
#---------------------------------------------------------------------------------6
                 ['1', S_Label,std_db_msi,12,200,'dynamic'],
                 ['2', S_Label,std_db_msi,12,200,'dynamic'],

                 ['1', V_Label,std_db_msi,12,200,'dynamic'],
                 ['2', V_Label,std_db_msi,12,200,'dynamic'],
#---------------------------------------------------------------------------------7
                 ]

# %%
#for training
ds_genparams =  [ # [postfix ,abL, train_db, exlimL, exlimu, NCs, ]
#---------------------------------------------------------------------------------1
                 ['1', S_Label,std_db_m,12,25,'dynamic'],
                 ['1', S_Label,std_db_m,12,50,'dynamic'],
                 ['1', S_Label,std_db_m,12,75,'dynamic'],
                 ['2', S_Label,std_db_m,12,25,'dynamic'],
                 ['2', S_Label,std_db_m,12,50,'dynamic'],
                 ['2', S_Label,std_db_m,12,75,'dynamic'],

                 ['1', V_Label,std_db_m,12,25,'dynamic'],
                 ['1', V_Label,std_db_m,12,50,'dynamic'],
                 ['1', V_Label,std_db_m,12,75,'dynamic'],
                 ['2', V_Label,std_db_m,12,25,'dynamic'],
                 ['2', V_Label,std_db_m,12,50,'dynamic'],
                 ['2', V_Label,std_db_m,12,75,'dynamic'],                
#---------------------------------------------------------------------------------2
                 ['1', S_Label,std_db_s,12,25,'dynamic'],
                 ['1', S_Label,std_db_s,12,50,'dynamic'],
                 ['1', S_Label,std_db_s,12,75,'dynamic'],
                 ['2', S_Label,std_db_s,12,25,'dynamic'],
                 ['2', S_Label,std_db_s,12,50,'dynamic'],
                 ['2', S_Label,std_db_s,12,75,'dynamic'],

                 ['1', V_Label,std_db_s,12,25,'dynamic'],
                 ['1', V_Label,std_db_s,12,50,'dynamic'],
                 ['1', V_Label,std_db_s,12,75,'dynamic'],
                 ['2', V_Label,std_db_s,12,25,'dynamic'],
                 ['2', V_Label,std_db_s,12,50,'dynamic'],
                 ['2', V_Label,std_db_s,12,75,'dynamic'],                 
#---------------------------------------------------------------------------------3
                 ['1', S_Label,std_db_i,12,25,'dynamic'],
                 ['1', S_Label,std_db_i,12,50,'dynamic'],
                 ['1', S_Label,std_db_i,12,75,'dynamic'],
                 ['2', S_Label,std_db_i,12,25,'dynamic'],
                 ['2', S_Label,std_db_i,12,50,'dynamic'],
                 ['2', S_Label,std_db_i,12,75,'dynamic'],

                 ['1', V_Label,std_db_i,12,25,'dynamic'],
                 ['1', V_Label,std_db_i,12,50,'dynamic'],
                 ['1', V_Label,std_db_i,12,75,'dynamic'],
                 ['2', V_Label,std_db_i,12,25,'dynamic'],
                 ['2', V_Label,std_db_i,12,50,'dynamic'],
                 ['2', V_Label,std_db_i,12,75,'dynamic'],
                 ]

# %%
#for training
ds_genparams =  [ # [postfix ,abL, train_db, exlimL, exlimu, NCs, ]
#---------------------------------------------------------------------------------1
                 ['1f20', S_Label,db_mf20,12,25,'dynamic'],
                 ['1f20', S_Label,db_mf20,12,50,'dynamic'],
                 #['1f20', S_Label,db_mf20,12,75,'dynamic'],
                 #['2r24', S_Label,db_mr24,12,25,'dynamic'],
                 #['2r24', S_Label,db_mr24,12,50,'dynamic'],
                 #['2r24', S_Label,db_mr24,12,75,'dynamic'],

                 ['1f20', V_Label,db_mf20,12,25,'dynamic'],
                 ['1f20', V_Label,db_mf20,12,50,'dynamic'],
                 #['1f20', V_Label,db_mf20,12,75,'dynamic'],
                 #['2r24', V_Label,db_mr24,12,25,'dynamic'],
                 #['2r24', V_Label,db_mr24,12,50,'dynamic'],
                 #['2r24', V_Label,db_mr24,12,75,'dynamic'],                
                 ]

# %%
# for validation
ds_genparams =  [ # [id ,abL, train_db, exlimL, exlimu, NCs, ]
                 ['test', S_Label,std_db_m,1,1,'dynamic'],
                 ['test', V_Label,std_db_m,1,1,'dynamic'],
                ['test', S_Label,std_db_s,1,1,'dynamic'],
                 ['test', V_Label,std_db_s,1,1,'dynamic'],
                ['test', S_Label,std_db_i,1,1,'dynamic'],
                 ['test', V_Label,std_db_i,1,1,'dynamic'],
                 ]

# %%
do_shuffle = 1
nrb_bin_ordered = False
#<<-----------------------------------------------
timestamp_start = datetime.datetime.now()
#<<-----------------------------------------------
for dspr in ds_genparams:
    abL = dspr[1]                       # S_Label V_Label
    train_db = dspr[2]                  # combination of mitdb, svdb and/or incartdb
    ex_limL, ex_limU = dspr[3],dspr[4]  # limit to beats to be selected
    use_NCstatergy = dspr[5]            # pure semi dynamic random

    ds_name = abL+'_'
    for kk in train_db.keys():
        ds_name += kk[0]
    ds_name+='_'+str(ex_limU)+'_'+str(dspr[0])
    ds_path = os.path.join(global_dsdir,ds_name+'.npy') 

    #<<------------------------------------------------------------
    print('Database ID:', ds_name)
    print('Abnormal label:', abL)
    print('Training databases:', train_db.keys())
    print('Selection Limits:', ex_limL, ex_limU)
    print('NC_Statergy:', use_NCstatergy)
    #<<-----------------------------------------------

    ds_selected, nos_records = generate_dataset_train(train_db, ex_limL,ex_limU, 
                                                    abL,  use_NCstatergy, do_shuffle, nrb_bin_ordered )
    #<<-----------------------------------------------

    print('Selected beats:',ds_selected.shape)
    print('Used records:','[',len(nos_records),']',nos_records,)
    np.save(ds_path,ds_selected)
    print('saved at', ds_path)
    #<<-----------------------------------------------
    print('===================================\n')
timestamp_dur = datetime.datetime.now() - timestamp_start
print('Elapsed time = ' + str(timestamp_dur))
# Out:
# Database ID: S_m_25_1f20
# Abnormal label: S
# Training databases: dict_keys(['mitdb'])
# Selection Limits: 12 25
# NC_Statergy: dynamic
# Selected beats: (174, 5)
# Used records: [ 4 ] ['mitdb_114', 'mitdb_118', 'mitdb_100', 'mitdb_124']
# saved at /content/drive/My Drive/Masters/workdir/ecg_data/db_dataset/S_m_25_1f20.npy
# ===================================
#
# Database ID: S_m_50_1f20
# Abnormal label: S
# Training databases: dict_keys(['mitdb'])
# Selection Limits: 12 50
# NC_Statergy: dynamic
# Selected beats: (252, 5)
# Used records: [ 4 ] ['mitdb_114', 'mitdb_118', 'mitdb_100', 'mitdb_124']
# saved at /content/drive/My Drive/Masters/workdir/ecg_data/db_dataset/S_m_50_1f20.npy
# ===================================
#
# Database ID: S_m_25_2r24
# Abnormal label: S
# Training databases: dict_keys(['mitdb'])
# Selection Limits: 12 25
# NC_Statergy: dynamic
# Selected beats: (544, 5)
# Used records: [ 11 ] ['mitdb_222', 'mitdb_202', 'mitdb_200', 'mitdb_201', 'mitdb_234', 'mitdb_213', 'mitdb_223', 'mitdb_220', 'mitdb_210', 'mitdb_209', 'mitdb_232']
# saved at /content/drive/My Drive/Masters/workdir/ecg_data/db_dataset/S_m_25_2r24.npy
# ===================================
#
# Database ID: S_m_50_2r24
# Abnormal label: S
# Training databases: dict_keys(['mitdb'])
# Selection Limits: 12 50
# NC_Statergy: dynamic
# Selected beats: (960, 5)
# Used records: [ 11 ] ['mitdb_222', 'mitdb_202', 'mitdb_200', 'mitdb_201', 'mitdb_234', 'mitdb_213', 'mitdb_223', 'mitdb_220', 'mitdb_210', 'mitdb_209', 'mitdb_232']
# saved at /content/drive/My Drive/Masters/workdir/ecg_data/db_dataset/S_m_50_2r24.npy
# ===================================
#
# Database ID: V_m_25_1f20
# Abnormal label: V
# Training databases: dict_keys(['mitdb'])
# Selection Limits: 12 25
# NC_Statergy: dynamic
# Selected beats: (382, 5)
# Used records: [ 8 ] ['mitdb_119', 'mitdb_114', 'mitdb_105', 'mitdb_109', 'mitdb_118', 'mitdb_106', 'mitdb_124', 'mitdb_116']
# saved at /content/drive/My Drive/Masters/workdir/ecg_data/db_dataset/V_m_25_1f20.npy
# ===================================
#
# Database ID: V_m_50_1f20
# Abnormal label: V
# Training databases: dict_keys(['mitdb'])
# Selection Limits: 12 50
# NC_Statergy: dynamic
# Selected beats: (688, 5)
# Used records: [ 8 ] ['mitdb_119', 'mitdb_114', 'mitdb_105', 'mitdb_109', 'mitdb_118', 'mitdb_106', 'mitdb_124', 'mitdb_116']
# saved at /content/drive/My Drive/Masters/workdir/ecg_data/db_dataset/V_m_50_1f20.npy
# ===================================
#
# Database ID: V_m_25_2r24
# Abnormal label: V
# Training databases: dict_keys(['mitdb'])
# Selection Limits: 12 25
# NC_Statergy: dynamic
# Selected beats: (790, 5)
# Used records: [ 16 ] ['mitdb_202', 'mitdb_200', 'mitdb_217', 'mitdb_201', 'mitdb_213', 'mitdb_223', 'mitdb_221', 'mitdb_203', 'mitdb_219', 'mitdb_208', 'mitdb_215', 'mitdb_205', 'mitdb_210', 'mitdb_214', 'mitdb_228', 'mitdb_233']
# saved at /content/drive/My Drive/Masters/workdir/ecg_data/db_dataset/V_m_25_2r24.npy
# ===================================
#
# Database ID: V_m_50_2r24
# Abnormal label: V
# Training databases: dict_keys(['mitdb'])
# Selection Limits: 12 50
# NC_Statergy: dynamic
# Selected beats: (1540, 5)
# Used records: [ 16 ] ['mitdb_202', 'mitdb_200', 'mitdb_217', 'mitdb_201', 'mitdb_213', 'mitdb_223', 'mitdb_221', 'mitdb_203', 'mitdb_219', 'mitdb_208', 'mitdb_215', 'mitdb_205', 'mitdb_210', 'mitdb_214', 'mitdb_228', 'mitdb_233']
# saved at /content/drive/My Drive/Masters/workdir/ecg_data/db_dataset/V_m_50_2r24.npy
# ===================================
#
# Elapsed time = 0:00:02.632243

# %% [markdown]
# # TRAINING

# %%
def prepare_training_data(abnormal_label, ds_list, ds_list_val, work_db, data_DP, sup_NR):
    #ds_listS = ['S_in_e1','S_mit_e1','S_sv_e1']
    #ds_listS_val = ['s_mitdb_val','s_svdb_val','s_indb_val']

    print(abnormal_label+'-datasets(training):',ds_list)
    ds_str = np.zeros((0,5),dtype='U10')
    for ds_name in ds_list:
        ds_path = os.path.join(global_dsdir,ds_name+'.npy') 
        ds_this = np.load(ds_path)
        print('loaded:',ds_this.shape, ds_path)
        ds_str=np.vstack((ds_str,ds_this))
    print(abnormal_label+'-beats(training):',ds_str.shape )


    print(abnormal_label+'-datasets(validation):',ds_list_val)
    ds_str_val = np.zeros((0,5),dtype='U10')
    for ds_name in ds_list_val:
        ds_path = os.path.join(global_dsdir,ds_name+'.npy') 
        ds_this = np.load(ds_path)
        print('loaded:',ds_this.shape, ds_path)
        ds_str_val=np.vstack((ds_str_val,ds_this))
    print(abnormal_label+'-beats(validation):',ds_str_val.shape )

    #======================================================================
    #work_db = std_db_msi
    #======================================================================

    timestamp_start = datetime.datetime.now()

    ds_selected = load_beat_segment2(ds_str, work_db, data_DP, supress_NR=sup_NR)
    data_x = ds_selected
    data_y = ds_str[:,4].astype('int')
    print(abnormal_label+'_training:',data_x.shape,data_y.shape)

    ds_selected_val = load_beat_segment2(ds_str_val, work_db, data_DP, supress_NR=sup_NR)
    data_x_val = ds_selected_val
    data_y_val = ds_str_val[:,4].astype('int')
    print(abnormal_label+'_validation:',data_x_val.shape,data_y_val.shape)


    timestamp_dur = datetime.datetime.now() - timestamp_start
    print('Elapsed time = ' + str(timestamp_dur))

    return data_x, data_y, data_x_val, data_y_val, ds_str

def get_random_sample(ds_str, data_x, data_y, data_DP):
    #======================================================================
    dssN = np.random.choice(np.where(data_y==0)[0],size=1)
    dssA = np.random.choice(np.where(data_y==1)[0],size=1)
    fig,ax = plt.subplots(2,2)
    fig.set_size_inches(12,6)

    print('Sample N',dssN,'of',len(data_x))
    print(ds_str[dssN])
    ax[0,0].set_ylim(-2.5,3.5)
    ax[0,0].plot(data_x[dssN[0]][:,0],color='tab:green')
    ax[0,0].vlines(data_DP.fix_left,-2.5,3.5,linewidth=0.3,color='black')
    ax[0,1].set_ylim(-2.5,3.5)
    ax[0,1].plot(data_x[dssN[0]][:,1],color='tab:purple')
    ax[0,1].vlines(data_DP.fix_left,-2.5,3.5,linewidth=0.3,color='black')

    print('Sample A',dssA,'of',len(data_x))
    print(ds_str[dssA])
    ax[1,0].set_ylim(-2.5,3.5)
    ax[1,0].plot(data_x[dssA[0]][:,0],color='tab:green')
    ax[1,0].vlines(data_DP.fix_left,-2.5,3.5,linewidth=0.3,color='black')
    ax[1,1].set_ylim(-2.5,3.5)
    ax[1,1].plot(data_x[dssA[0]][:,1],color='tab:red')
    ax[1,1].vlines(data_DP.fix_left,-2.5,3.5,linewidth=0.3,color='black')
    #======================================================================

def train_save_model(ds_list, model, data_x, data_y, data_x_val, data_y_val, verbo, do_plot, do_save, save_postfix ):
    timestamp_start = datetime.datetime.now()
    # Start Training---------------------------------------------------------
    print('Training model '+model.name+':', 'on',ds_list)
    history = model.fit(
                        data_x, data_y,
                        #batch_size=1000,
                        epochs=300,
                        callbacks=cb_listr,
                        validation_data= (data_x_val, data_y_val),
                        shuffle=True,
                        verbose=verbo)
    # End Training---------------------------------------------------------
    timestamp_dur = datetime.datetime.now() - timestamp_start
    print('Elapsed time = ' + str(timestamp_dur))

    if do_plot:
        fig,ax = plt.subplots(2,2)
        fig.set_size_inches(12,12)
        ax[0,0].set_title('ACC')
        ax[0,0].set_ylim(0,1)
        ax[0,0].plot(history.history['accuracy'],color='green')
        ax[0,1].set_title('LOSS')
        ax[0,1].set_ylim(0,4)
        ax[0,1].plot(history.history['loss'],color='red')

        ax[1,0].set_title('VAL_ACC')
        ax[1,0].set_ylim(0,1)
        ax[1,0].plot(history.history['val_accuracy'],color='green')
        ax[1,1].set_title('VAL_LOSS')
        ax[1,1].set_ylim(0,4)
        ax[1,1].plot(history.history['val_loss'],color='red')
        fig.show()
    
    if do_save:
        # save this model
        model_path = os.path.join(global_modeldir, model.name+save_postfix+'.h5')
        model.save_weights(model_path)
        print('Saved Model Weights '+model.name+' at : '+ str(model_path))
        
    return history

# %% [markdown]
# ## [ preview samples ]

# %%
AX_Label = S_Label
Data_DP = S_DP
ds_list=['S_m_1_test']
supress_NRB=False
data_x, data_y, data_x_val, data_y_val, ds_str  = prepare_training_data(
                                                            AX_Label, 
                                                            ds_list, 
                                                            ds_list, 
                                                            std_db_msi,
                                                            Data_DP, supress_NRB)
# Out:
# S-datasets(training): ['S_m_1_test']
# loaded: (54, 5) /content/drive/My Drive/Masters/workdir/ecg_data/db_dataset/S_m_1_test.npy
# S-beats(training): (54, 5)
# S-datasets(validation): ['S_m_1_test']
# loaded: (54, 5) /content/drive/My Drive/Masters/workdir/ecg_data/db_dataset/S_m_1_test.npy
# S-beats(validation): (54, 5)
# S_training: (54, 384, 2) (54,)
# S_validation: (54, 384, 2) (54,)
# Elapsed time = 0:00:32.345954

# %%
get_random_sample(ds_str, data_x, data_y, Data_DP)
# Out:
# Sample N [30] of 54
# [['mitdb' '234' '125' '1580' '0']]
# Sample A [47] of 54
# [['mitdb' '201' '1917' '71' '1']]

# %% [markdown]
# ## mega training [S]

# %%
ds_listLS = [
            #['S_m_25_1f20'], ['S_m_50_1f20']
# mitdb,svdb, incartdb
#['S_m_75_1', 'S_s_75_1', 'S_i_75_1'],
#['S_m_75_2', 'S_s_75_2', 'S_i_75_2'],
#['S_msi_25_3']
['S_m_75_1']

# mitdb,svdb
#['S_m_75_1', 'S_s_75_1'],
#['S_m_50_2', 'S_s_50_2'],

# mitdb, incartdb
#['S_m_75_1', 'S_i_75_1'],
#['S_m_50_2', 'S_i_50_2'],

# incartdb,  svdb
#['S_i_75_1', 'S_s_75_1'],
#['S_i_50_2', 'S_s_50_2'],

# mitdb
#['S_m_75_1'],
#['S_m_50_2'],

#svdb
#['S_s_75_1'],
#['S_s_50_2'],

#incartdb
#['S_i_75_1'],
#['S_i_50_2'],

]


ds_list_val =   ['S_s_1_test']
AX_Label =      S_Label
Data_DP =       S_DP
supress_NRB =   True
save_postfix = '_NRS'
for ids in ds_listLS:
    print('=======================================')
    ds_list =       ids
    data_x, data_y, data_x_val, data_y_val, ds_str  = prepare_training_data(
                                                            AX_Label, 
                                                            ds_list, 
                                                            ds_list_val, 
                                                            std_db_msi,
                                                            Data_DP, supress_NRB)

    dstr = 'M'
    for i in ds_list:
        dstr+='_'+i
    ds_model_1D  = dstr
    model_1D = get_modelCNN_1D(False, Data_DP.vdim, ds_model_1D)
    train_save_model(ds_list, model_1D, data_x, data_y, data_x_val, data_y_val, 0, False, True, save_postfix )
# Out:
# =======================================
# S-datasets(training): ['S_m_75_1']
# loaded: (1458, 5) /content/drive/My Drive/Masters/workdir/ecg_data/db_dataset/S_m_75_1.npy
# S-beats(training): (1458, 5)
# S-datasets(validation): ['S_s_1_test']
# loaded: (146, 5) /content/drive/My Drive/Masters/workdir/ecg_data/db_dataset/S_s_1_test.npy
# S-beats(validation): (146, 5)
# S_training: (1458, 384, 2) (1458,)
# S_validation: (146, 384, 2) (146,)
# Elapsed time = 0:01:11.775102
# Training model M_S_m_75_1: on ['S_m_75_1']
# Elapsed time = 0:00:36.133610
# Saved Model Weights M_S_m_75_1 at : /content/drive/My Drive/Masters/workdir/ecg_data/db_model/M_S_m_75_1_NRS.h5

# %% [markdown]
# ## mega training [V]

# %%
ds_listLV = [
             #['V_m_25_1f20'], ['V_m_50_1f20']
# mitdb,svdb, incartdb
#['V_m_75_1', 'V_s_75_1', 'V_i_75_1'],
#['V_m_75_2', 'V_s_75_2', 'V_i_75_2'],
#['V_msi_25_3']
['V_m_75_1']

# mitdb,svdb
#['V_m_75_1', 'V_s_75_1'],
#['V_m_50_2', 'V_s_50_2'],

# mitdb, incartdb
#['V_m_75_1', 'V_i_75_1'],
#['V_m_50_2', 'V_i_50_2'],

# incartdb,  svdb
#['V_i_75_1', 'V_s_75_1'],
#['V_i_50_2', 'V_s_50_2'],

# mitdb
#['V_m_75_1'],
#['V_m_50_2'],

#svdb
#['V_s_75_1'],
#['V_s_50_2'],

#incartdb
#['V_i_75_1'],
#['V_i_50_2'],

]


ds_list_val =   ['V_i_1_test']
AX_Label =      V_Label
Data_DP =       V_DP
supress_NRB =   True
save_postfix = '_NRS'
for ids in ds_listLV:
    print('=======================================')
    ds_list =       ids
    data_x, data_y, data_x_val, data_y_val, ds_str  = prepare_training_data(
                                                            AX_Label, 
                                                            ds_list, 
                                                            ds_list_val, 
                                                            std_db_msi,
                                                            Data_DP, supress_NRB)

    dstr = 'M'
    for i in ds_list:
        dstr+='_'+i
    ds_model_1D  = dstr
    model_1D = get_modelCNN_1D(False, Data_DP.vdim, ds_model_1D)
    train_save_model(ds_list, model_1D, data_x, data_y, data_x_val, data_y_val, 0, False, True, save_postfix)
# Out:
# =======================================
# V-datasets(training): ['V_m_75_1']
# loaded: (2772, 5) /content/drive/My Drive/Masters/workdir/ecg_data/db_dataset/V_m_75_1.npy
# V-beats(training): (2772, 5)
# V-datasets(validation): ['V_i_1_test']
# loaded: (138, 5) /content/drive/My Drive/Masters/workdir/ecg_data/db_dataset/V_i_1_test.npy
# V-beats(validation): (138, 5)
# V_training: (2772, 384, 2) (2772,)
# V_validation: (138, 384, 2) (138,)
# Elapsed time = 0:01:19.891607
# Training model M_V_m_75_1: on ['V_m_75_1']
# Elapsed time = 0:01:09.109424
# Saved Model Weights M_V_m_75_1 at : /content/drive/My Drive/Masters/workdir/ecg_data/db_model/M_V_m_75_1_NRS.h5

# %% [markdown]
# # [ TESTING ]

# %%
def perform_record_test(modelA, A_DP, glabels, sel_rec, sbi, sel_NR_count, nr_supress, NRB_bins, nrb_bin_ordered, return_NRBs, verbose=1):
    #gS_LABELS, gV_LABELS, gA_LABELS = [N_Label,S_Label], [N_Label,V_Label], [N_Label,A_Label]
    abnlabel = glabels[1]
    print('==============================================')
    print(sel_rec.name)
    print('==============================================')
    #print('==============================================')
    #<<----------------------------------------------- Select Normal Rhythm
    if NRB_bins:
        nr_indices = repeat_array( select_NRB_Bin(sel_NR_count ,sbi,nrb_bin_ordered ), sel_NR_count, 0)
    else:
        nr_indices =  repeat_array(sbi.NRBi, sel_NR_count, 0)

    nr_count = len(nr_indices)
    if nr_count!=sel_NR_count:
        print('WARNING: count NR mismatch.... using',nr_count)        

    if nr_count==0:
        print('ERROR: No NR beat ....skip') 
        return [],[], [],[], [],[], []
        #pred_res_S, conf_matrix_S, 
    else:
        #<<----------------------------------------------- Examine NR supress
        if nr_supress:
             #<<----------------------------------------------- NR is zero
            sig_NRA = np.zeros((nr_count,A_DP.vdim),dtype='float')
        else:
            #<<----------------------------------------------- Extract Record NR
            sig_NRA = np.zeros((0,A_DP.vdim),dtype='float')
            for i in range(0,nr_count):
                d_NR,dpk,_= sbi.get_signal_data_var(nr_indices[i])
                d_NR = pad_or_truncate(d_NR,dpk,A_DP)
                sig_NRA = np.vstack((sig_NRA,d_NR))
        #<<------------------------------------------------------------ generate record data S type
        data_x = np.zeros((0,A_DP.vdim,2))
        nrc = 0
        for i in range(0,sbi.rp_count):
            d_CR,dpk,_= sbi.get_signal_data_var(i)
            d_CR = pad_or_truncate(d_CR,dpk,A_DP)
            d_NR = sig_NRA[nrc%nr_count]
            d_data = np.expand_dims(np.transpose(np.vstack((d_NR,d_CR))),axis=0)
            data_x = np.vstack((data_x,d_data))
            nrc+=1
        #------------------------------------------------------------ format record data

        data_y = (sbi.rli_curr!=N_Label).astype('int') # all non-N are abnormal

        #------------------------------------------------------------ manual prediction S
        print('[All Samples]:',len(data_y))
        predx = modelA.predict( data_x ) # - each row is a prediction of a sample
        pred_res = predx.argmax(axis=1)
        conf_matrix = np.zeros((2,2),dtype='int32')
        conf_matrix[0,0] = len(np.where((data_y==0)&(pred_res==0))[0])
        conf_matrix[0,1] = len(np.where((data_y==0)&(pred_res==1))[0])
        conf_matrix[1,0] = len(np.where((data_y==1)&(pred_res==0))[0])
        conf_matrix[1,1] = len(np.where((data_y==1)&(pred_res==1))[0])

        if verbose==1:
            print_All_Performance(conf_matrix, '', gA_LABELS, get_performance(conf_matrix))
        else:
            print('\tConfusion Matrix [N/A]') # all non-N are abnormal
            print(print_conf_matrix( conf_matrix,'', gA_LABELS)) 
            print_performance( get_performance(conf_matrix) ,gA_LABELS ) 
        
        #------------------------------------------------------------ manual prediction Not N
        iact = np.where((sbi.rli_curr==abnlabel)|(sbi.rli_curr==N_Label))[0]
        data_yC =  data_y[iact] # only abn are abnormal
        pred_resC = pred_res[iact]
        print('[Class Samples]:',len(data_yC))
        conf_matrix_C = np.zeros((2,2),dtype='int32')
        conf_matrix_C[0,0] = len(np.where((data_yC==0)&(pred_resC==0))[0])
        conf_matrix_C[0,1] = len(np.where((data_yC==0)&(pred_resC==1))[0])
        conf_matrix_C[1,0] = len(np.where((data_yC==1)&(pred_resC==0))[0])
        conf_matrix_C[1,1] = len(np.where((data_yC==1)&(pred_resC==1))[0])    
        if verbose==1:
            print_All_Performance(conf_matrix, '', gA_LABELS, get_performance(conf_matrix))       
        else:  
            print('\tConfusion Matrix [N/'+abnlabel+']')
            print(print_conf_matrix( conf_matrix_C,'', glabels)) #logit('\t'+str(cmx))
            print_performance( get_performance(conf_matrix_C) , glabels ) 

    if return_NRBs:
        nrbs_res = sig_NRA
    else:
        nrbs_res = []
    return pred_res, pred_resC, conf_matrix, conf_matrix_C, data_y, data_yC, nrbs_res

# %% [markdown]
# ## [ S ] - Load Model

# %%
ds_modelS = 'M_S_m_75_1'       # SELECT MODEL WEIGHTS TO TEST UPON

model_pathS = os.path.join(global_modeldir, ds_modelS +'.h5')
modelS=get_modelCNN_1D(False,S_DP.vdim,ds_modelS)
modelS.load_weights(model_pathS)
print('Loaded Model weights '+ str(model_pathS))
# Out:
# Loaded Model weights /content/drive/My Drive/Masters/workdir/ecg_data/db_model/M_S_m_75_1.h5

# %% [markdown]
# ## [ S ] - Test DB

# %%
##<----------------------------------------------
work_dbS = std_db_i
##<----------------------------------------------
##<----------------------------------------------
sel_NR_count = 30
nrb_from_bins = False
nrb_bin_ordered = False
nr_supress=False
nrb_return = False
print('Testing database:',work_dbS.keys(),'on model:', modelS.name)
print('NR_Count:', sel_NR_count)

conf_matrix_gAS = np.zeros((2,2),dtype='int32') # confusion matrix S
conf_matrix_gCS = np.zeros((2,2),dtype='int32') # confusion matrix Combined
pred_dictS = {}  # predection results dictionary
#<<----------------------------------------
timestamp_start = datetime.datetime.now()
#<<----------------------------------------

for idb in work_dbS.keys():
    #<<--------------------
    sel_db = work_dbS[idb]
    for irec in sel_db.recs_tag:
        #<<--------------------
        sel_rec = sel_db.get_record(irec)
        #print(sel_rec.name)
        sbi = sel_rec.read_binfo()
        prAS,prCS,cmAS,cmCS,truthAS,_,_ = perform_record_test(modelS, S_DP, gS_LABELS, sel_rec, sbi, sel_NR_count, nr_supress, nrb_from_bins,nrb_bin_ordered,nrb_return  )
        pred_dictS[sel_rec.name] = [prAS,truthAS]
        if len(cmAS)!=0 and len(cmCS)!=0 :
            conf_matrix_gAS += cmAS
            conf_matrix_gCS += cmCS
    # end loop
print('\n==============================================')
print('\tGlobal Confusion Matrix [All]')
print(print_conf_matrix( conf_matrix_gAS,'', gA_LABELS)) #logit('\t'+str(cmx))
print_performance( get_performance(conf_matrix_gAS) ,gA_LABELS ) 

print('\n==============================================')
print('\tGlobal Confusion Matrix [Class]')
print(print_conf_matrix( conf_matrix_gCS,'', gS_LABELS)) #logit('\t'+str(cmx))
print_performance( get_performance(conf_matrix_gCS) ,gS_LABELS ) 

#------------------------------------------------------------
print('\n==============================================')
timestamp_dur = datetime.datetime.now() - timestamp_start
print('Elapsed time = ' + str(timestamp_dur))
# Out:
# Testing database: dict_keys(['incartdb']) on model: M_S_m_75_1
# NR_Count: 30
# ==============================================
# incartdb_I04
# ==============================================
# [All Samples]: 2421
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2132	135	0.93	0.98	0.94	0.79
# A	33	121	0.93	0.47	0.79	0.94
#
# [Class Samples]: 2283
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2132	135	0.93	0.98	0.94	0.79
# A	33	121	0.93	0.47	0.79	0.94
#
# ==============================================
# incartdb_I01
# ==============================================
# [All Samples]: 2755
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1759	652	0.74	0.97	0.73	0.85
# A	53	291	0.74	0.31	0.85	0.73
#
# [Class Samples]: 2411
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1759	652	0.74	0.97	0.73	0.85
# A	53	291	0.74	0.31	0.85	0.73
#
# ==============================================
# incartdb_I33
# ==============================================
# [All Samples]: 1835
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1193	52	0.94	0.96	0.96	0.91
# A	55	535	0.94	0.91	0.91	0.96
#
# [Class Samples]: 1834
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1193	52	0.94	0.96	0.96	0.91
# A	55	535	0.94	0.91	0.91	0.96
#
# ==============================================
# incartdb_I03
# ==============================================
# [All Samples]: 2450
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2295	28	0.99	1.0	0.99	0.98
# A	3	124	0.99	0.82	0.98	0.99
#
# [Class Samples]: 2325
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2295	28	0.99	1.0	0.99	0.98
# A	3	124	0.99	0.82	0.98	0.99
#
# ==============================================
# incartdb_I12
# ==============================================
# [All Samples]: 2807
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2220	578	0.79	1.0	0.79	1.0
# A	0	9	0.79	0.02	1.0	0.79
#
# [Class Samples]: 2799
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2220	578	0.79	1.0	0.79	1.0
# A	0	9	0.79	0.02	1.0	0.79
#
# ==============================================
# incartdb_I65
# ==============================================
# [All Samples]: 2662
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1973	298	0.88	0.99	0.87	0.94
# A	25	366	0.88	0.55	0.94	0.87
#
# [Class Samples]: 2276
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1973	298	0.88	0.99	0.87	0.94
# A	25	366	0.88	0.55	0.94	0.87
#
# ==============================================
# incartdb_I02
# ==============================================
# [All Samples]: 2672
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2049	394	0.85	1.0	0.84	0.96
# A	10	219	0.85	0.36	0.96	0.84
#
# [Class Samples]: 2443
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2049	394	0.85	1.0	0.84	0.96
# A	10	219	0.85	0.36	0.96	0.84
#
# ==============================================
# incartdb_I20
# ==============================================
# [All Samples]: 2650
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1981	379	0.85	1.0	0.84	0.98
# A	7	283	0.85	0.43	0.98	0.84
#
# [Class Samples]: 2539
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1981	379	0.85	1.0	0.84	0.98
# A	7	283	0.85	0.43	0.98	0.84
#
# ==============================================
# incartdb_I61
# ==============================================
# [All Samples]: 1452
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1451	0	1.0	1.0	1.0	0.0
# A	1	0	1.0	nan	0.0	1.0
#
# [Class Samples]: 1452
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1451	0	1.0	1.0	1.0	0.0
# A	1	0	1.0	nan	0.0	1.0
#
# ==============================================
# incartdb_I26
# ==============================================
# [All Samples]: 1507
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1494	2	1.0	1.0	1.0	0.91
# A	1	10	1.0	0.83	0.91	1.0
#
# [Class Samples]: 1503
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1494	2	1.0	1.0	1.0	0.91
# A	1	10	1.0	0.83	0.91	1.0
#
# ==============================================
# incartdb_I37
# ==============================================
# [All Samples]: 2459
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1997	10	1.0	1.0	1.0	1.0
# A	0	452	1.0	0.98	1.0	1.0
#
# [Class Samples]: 2007
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1997	10	1.0	1.0	1.0	1.0
# A	0	452	1.0	0.98	1.0	1.0
#
# ==============================================
# incartdb_I29
# ==============================================
# [All Samples]: 2619
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1634	201	0.9	0.96	0.89	0.91
# A	72	712	0.9	0.78	0.91	0.89
#
# [Class Samples]: 1835
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1634	201	0.9	0.96	0.89	0.91
# A	72	712	0.9	0.78	0.91	0.89
#
# ==============================================
# incartdb_I13
# ==============================================
# [All Samples]: 2021
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1777	14	0.99	1.0	0.99	1.0
# A	0	230	0.99	0.94	1.0	0.99
#
# [Class Samples]: 1791
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1777	14	0.99	1.0	0.99	1.0
# A	0	230	0.99	0.94	1.0	0.99
#
# ==============================================
# incartdb_I45
# ==============================================
# [All Samples]: 1926
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1428	7	1.0	1.0	1.0	1.0
# A	0	491	1.0	0.99	1.0	1.0
#
# [Class Samples]: 1435
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1428	7	1.0	1.0	1.0	1.0
# A	0	491	1.0	0.99	1.0	1.0
#
# ==============================================
# incartdb_I63
# ==============================================
# [All Samples]: 1992
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1844	1	0.97	0.97	1.0	0.63
# A	54	93	0.97	0.99	0.63	1.0
#
# [Class Samples]: 1846
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1844	1	0.97	0.97	1.0	0.63
# A	54	93	0.97	0.99	0.63	1.0
#
# ==============================================
# incartdb_I28
# ==============================================
# [All Samples]: 1715
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1681	30	0.98	1.0	0.98	1.0
# A	0	4	0.98	0.12	1.0	0.98
#
# [Class Samples]: 1711
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1681	30	0.98	1.0	0.98	1.0
# A	0	4	0.98	0.12	1.0	0.98
#
# ==============================================
# incartdb_I16
# ==============================================
# [All Samples]: 1520
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1503	15	0.99	1.0	0.99	1.0
# A	0	2	0.99	0.12	1.0	0.99
#
# [Class Samples]: 1518
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1503	15	0.99	1.0	0.99	1.0
# A	0	2	0.99	0.12	1.0	0.99
#
# ==============================================
# incartdb_I19
# ==============================================
# [All Samples]: 2061
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1110	102	0.95	1.0	0.92	1.0
# A	1	848	0.95	0.89	1.0	0.92
#
# [Class Samples]: 1212
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1110	102	0.95	1.0	0.92	1.0
# A	1	848	0.95	0.89	1.0	0.92
#
# ==============================================
# incartdb_I57
# ==============================================
# [All Samples]: 2868
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1825	1014	0.64	0.99	0.64	0.62
# A	11	18	0.64	0.02	0.62	0.64
#
# [Class Samples]: 2842
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1825	1014	0.64	0.99	0.64	0.62
# A	11	18	0.64	0.02	0.62	0.64
#
# ==============================================
# incartdb_I67
# ==============================================
# [All Samples]: 2973
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2242	194	0.93	1.0	0.92	0.99
# A	7	530	0.93	0.73	0.99	0.92
#
# [Class Samples]: 2441
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2242	194	0.93	1.0	0.92	0.99
# A	7	530	0.93	0.73	0.99	0.92
#
# ==============================================
# incartdb_I17
# ==============================================
# [All Samples]: 1670
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1621	22	0.99	1.0	0.99	1.0
# A	0	27	0.99	0.55	1.0	0.99
#
# [Class Samples]: 1643
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1621	22	0.99	1.0	0.99	1.0
# A	0	27	0.99	0.55	1.0	0.99
#
# ==============================================
# incartdb_I54
# ==============================================
# [All Samples]: 2361
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1787	551	0.76	1.0	0.76	0.74
# A	6	17	0.76	0.03	0.74	0.76
#
# [Class Samples]: 2339
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1787	551	0.76	1.0	0.76	0.74
# A	6	17	0.76	0.03	0.74	0.76
#
# ==============================================
# incartdb_I49
# ==============================================
# [All Samples]: 2145
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1881	237	0.89	1.0	0.89	0.85
# A	4	23	0.89	0.09	0.85	0.89
#
# [Class Samples]: 2118
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1881	237	0.89	1.0	0.89	0.85
# A	4	23	0.89	0.09	0.85	0.89
#
# ==============================================
# incartdb_I51
# ==============================================
# [All Samples]: 2775
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1541	428	0.85	1.0	0.78	1.0
# A	1	805	0.85	0.65	1.0	0.78
#
# [Class Samples]: 1972
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1541	428	0.85	1.0	0.78	1.0
# A	1	805	0.85	0.65	1.0	0.78
#
# ==============================================
# incartdb_I40
# ==============================================
# [All Samples]: 2664
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1759	807	0.69	0.99	0.69	0.73
# A	26	72	0.69	0.08	0.73	0.69
#
# [Class Samples]: 2572
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1759	807	0.69	0.99	0.69	0.73
# A	26	72	0.69	0.08	0.73	0.69
#
# ==============================================
# incartdb_I70
# ==============================================
# [All Samples]: 1664
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1533	5	1.0	1.0	1.0	1.0
# A	0	126	1.0	0.96	1.0	1.0
#
# [Class Samples]: 1664
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1533	5	1.0	1.0	1.0	1.0
# A	0	126	1.0	0.96	1.0	1.0
#
# ==============================================
# incartdb_I36
# ==============================================
# [All Samples]: 3909
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1672	1775	0.54	0.98	0.49	0.93
# A	33	429	0.54	0.19	0.93	0.49
#
# [Class Samples]: 3447
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1672	1775	0.54	0.98	0.49	0.93
# A	33	429	0.54	0.19	0.93	0.49
#
# ==============================================
# incartdb_I30
# ==============================================
# [All Samples]: 2460
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1583	122	0.94	0.98	0.93	0.96
# A	33	722	0.94	0.86	0.96	0.93
#
# [Class Samples]: 1705
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1583	122	0.94	0.98	0.93	0.96
# A	33	722	0.94	0.86	0.96	0.93
#
# ==============================================
# incartdb_I60
# ==============================================
# [All Samples]: 2473
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2162	260	0.87	0.98	0.89	0.0
# A	51	0	0.87	0.0	0.0	0.89
#
# [Class Samples]: 2422
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2162	260	0.87	0.98	0.89	0.0
# A	51	0	0.87	0.0	0.0	0.89
#
# ==============================================
# incartdb_I50
# ==============================================
# [All Samples]: 2996
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2361	631	0.79	1.0	0.79	1.0
# A	0	4	0.79	0.01	1.0	0.79
#
# [Class Samples]: 2992
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2361	631	0.79	1.0	0.79	1.0
# A	0	4	0.79	0.01	1.0	0.79
#
# ==============================================
# incartdb_I44
# ==============================================
# [All Samples]: 2492
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1767	34	0.99	1.0	0.98	1.0
# A	2	689	0.99	0.95	1.0	0.98
#
# [Class Samples]: 1809
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1767	34	0.99	1.0	0.98	1.0
# A	2	689	0.99	0.95	1.0	0.98
#
# ==============================================
# incartdb_I75
# ==============================================
# [All Samples]: 2101
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1481	1	0.99	0.99	1.0	0.98
# A	14	605	0.99	1.0	0.98	1.0
#
# [Class Samples]: 1482
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1481	1	0.99	0.99	1.0	0.98
# A	14	605	0.99	1.0	0.98	1.0
#
# ==============================================
# incartdb_I46
# ==============================================
# [All Samples]: 2656
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2072	158	0.94	1.0	0.93	1.0
# A	0	426	0.94	0.73	1.0	0.93
#
# [Class Samples]: 2231
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2072	158	0.94	1.0	0.93	1.0
# A	0	426	0.94	0.73	1.0	0.93
#
# ==============================================
# incartdb_I14
# ==============================================
# [All Samples]: 1864
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1755	45	0.98	1.0	0.98	1.0
# A	0	64	0.98	0.59	1.0	0.98
#
# [Class Samples]: 1800
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1755	45	0.98	1.0	0.98	1.0
# A	0	64	0.98	0.59	1.0	0.98
#
# ==============================================
# incartdb_I55
# ==============================================
# [All Samples]: 2164
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2094	52	0.97	1.0	0.98	0.72
# A	5	13	0.97	0.2	0.72	0.98
#
# [Class Samples]: 2147
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2094	52	0.97	1.0	0.98	0.72
# A	5	13	0.97	0.2	0.72	0.98
#
# ==============================================
# incartdb_I09
# ==============================================
# [All Samples]: 2995
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1976	970	0.67	1.0	0.67	0.92
# A	4	45	0.67	0.04	0.92	0.67
#
# [Class Samples]: 2946
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1976	970	0.67	1.0	0.67	0.92
# A	4	45	0.67	0.04	0.92	0.67
#
# ==============================================
# incartdb_I27
# ==============================================
# [All Samples]: 2603
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1855	29	0.99	1.0	0.98	1.0
# A	0	719	0.99	0.96	1.0	0.98
#
# [Class Samples]: 1884
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1855	29	0.99	1.0	0.98	1.0
# A	0	719	0.99	0.96	1.0	0.98
#
# ==============================================
# incartdb_I66
# ==============================================
# [All Samples]: 2338
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2029	108	0.95	1.0	0.95	0.99
# A	2	199	0.95	0.65	0.99	0.95
#
# [Class Samples]: 2138
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2029	108	0.95	1.0	0.95	0.99
# A	2	199	0.95	0.65	0.99	0.95
#
# ==============================================
# incartdb_I58
# ==============================================
# [All Samples]: 2323
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2171	140	0.94	1.0	0.94	1.0
# A	0	12	0.94	0.08	1.0	0.94
#
# [Class Samples]: 2311
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2171	140	0.94	1.0	0.94	1.0
# A	0	12	0.94	0.08	1.0	0.94
#
# ==============================================
# incartdb_I47
# ==============================================
# [All Samples]: 1951
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1724	133	0.93	1.0	0.93	0.99
# A	1	93	0.93	0.41	0.99	0.93
#
# [Class Samples]: 1858
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1724	133	0.93	1.0	0.93	0.99
# A	1	93	0.93	0.41	0.99	0.93
#
# ==============================================
# incartdb_I41
# ==============================================
# [All Samples]: 1628
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1450	172	0.89	1.0	0.89	0.5
# A	3	3	0.89	0.02	0.5	0.89
#
# [Class Samples]: 1627
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1450	172	0.89	1.0	0.89	0.5
# A	3	3	0.89	0.02	0.5	0.89
#
# ==============================================
# incartdb_I38
# ==============================================
# [All Samples]: 2697
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2130	23	0.99	1.0	0.99	1.0
# A	1	543	0.99	0.96	1.0	0.99
#
# [Class Samples]: 2153
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2130	23	0.99	1.0	0.99	1.0
# A	1	543	0.99	0.96	1.0	0.99
#
# ==============================================
# incartdb_I32
# ==============================================
# [All Samples]: 1617
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1544	16	0.99	1.0	0.99	0.96
# A	2	55	0.99	0.77	0.96	0.99
#
# [Class Samples]: 1560
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1544	16	0.99	1.0	0.99	0.96
# A	2	55	0.99	0.77	0.96	0.99
#
# ==============================================
# incartdb_I34
# ==============================================
# [All Samples]: 1963
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1397	30	0.97	0.98	0.98	0.95
# A	27	509	0.97	0.94	0.95	0.98
#
# [Class Samples]: 1963
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1397	30	0.97	0.98	0.98	0.95
# A	27	509	0.97	0.94	0.95	0.98
#
# ==============================================
# incartdb_I74
# ==============================================
# [All Samples]: 2402
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1910	170	0.91	0.98	0.92	0.88
# A	38	284	0.91	0.63	0.88	0.92
#
# [Class Samples]: 2080
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1910	170	0.91	0.98	0.92	0.88
# A	38	284	0.91	0.63	0.88	0.92
#
# ==============================================
# incartdb_I11
# ==============================================
# [All Samples]: 2104
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2015	61	0.96	0.99	0.97	0.25
# A	21	7	0.96	0.1	0.25	0.97
#
# [Class Samples]: 2076
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2015	61	0.96	0.99	0.97	0.25
# A	21	7	0.96	0.1	0.25	0.97
#
# ==============================================
# incartdb_I39
# ==============================================
# [All Samples]: 1773
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1431	29	0.98	1.0	0.98	0.99
# A	2	311	0.98	0.91	0.99	0.98
#
# [Class Samples]: 1460
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1431	29	0.98	1.0	0.98	0.99
# A	2	311	0.98	0.91	0.99	0.98
#
# ==============================================
# incartdb_I42
# ==============================================
# [All Samples]: 3107
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1491	53	0.98	1.0	0.97	1.0
# A	1	1562	0.98	0.97	1.0	0.97
#
# [Class Samples]: 1544
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1491	53	0.98	1.0	0.97	1.0
# A	1	1562	0.98	0.97	1.0	0.97
#
# ==============================================
# incartdb_I52
# ==============================================
# [All Samples]: 1745
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1606	2	1.0	1.0	1.0	1.0
# A	0	137	1.0	0.99	1.0	1.0
#
# [Class Samples]: 1608
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1606	2	1.0	1.0	1.0	1.0
# A	0	137	1.0	0.99	1.0	1.0
#
# ==============================================
# incartdb_I59
# ==============================================
# [All Samples]: 2146
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1907	117	0.93	0.98	0.94	0.65
# A	43	79	0.93	0.4	0.65	0.94
#
# [Class Samples]: 2024
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1907	117	0.93	0.98	0.94	0.65
# A	43	79	0.93	0.4	0.65	0.94
#
# ==============================================
# incartdb_I08
# ==============================================
# [All Samples]: 2129
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1613	163	0.91	0.98	0.91	0.92
# A	28	325	0.91	0.67	0.92	0.91
#
# [Class Samples]: 1778
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1613	163	0.91	0.98	0.91	0.92
# A	28	325	0.91	0.67	0.92	0.91
#
# ==============================================
# incartdb_I53
# ==============================================
# [All Samples]: 2260
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1146	4	1.0	1.0	1.0	1.0
# A	0	1110	1.0	1.0	1.0	1.0
#
# [Class Samples]: 1150
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1146	4	1.0	1.0	1.0	1.0
# A	0	1110	1.0	1.0	1.0	1.0
#
# ==============================================
# incartdb_I69
# ==============================================
# [All Samples]: 2167
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1923	75	0.96	1.0	0.96	0.99
# A	1	168	0.96	0.69	0.99	0.96
#
# [Class Samples]: 1999
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1923	75	0.96	1.0	0.96	0.99
# A	1	168	0.96	0.69	0.99	0.96
#
# ==============================================
# incartdb_I68
# ==============================================
# [All Samples]: 2642
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2347	132	0.95	1.0	0.95	0.99
# A	2	161	0.95	0.55	0.99	0.95
#
# [Class Samples]: 2481
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2347	132	0.95	1.0	0.95	0.99
# A	2	161	0.95	0.55	0.99	0.95
#
# ==============================================
# incartdb_I24
# ==============================================
# [All Samples]: 2569
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2203	360	0.86	1.0	0.86	1.0
# A	0	6	0.86	0.02	1.0	0.86
#
# [Class Samples]: 2563
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2203	360	0.86	1.0	0.86	1.0
# A	0	6	0.86	0.02	1.0	0.86
#
# ==============================================
# incartdb_I15
# ==============================================
# [All Samples]: 2633
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2606	24	0.99	1.0	0.99	1.0
# A	0	3	0.99	0.11	1.0	0.99
#
# [Class Samples]: 2630
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2606	24	0.99	1.0	0.99	1.0
# A	0	3	0.99	0.11	1.0	0.99
#
# ==============================================
# incartdb_I25
# ==============================================
# [All Samples]: 1710
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1663	40	0.98	1.0	0.98	0.86
# A	1	6	0.98	0.13	0.86	0.98
#
# [Class Samples]: 1705
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1663	40	0.98	1.0	0.98	0.86
# A	1	6	0.98	0.13	0.86	0.98
#
# ==============================================
# incartdb_I43
# ==============================================
# WARNING: count NR mismatch.... using 0
# ERROR: No NR beat ....skip
# ==============================================
# incartdb_I56
# ==============================================
# [All Samples]: 1703
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1644	26	0.98	0.99	0.98	0.64
# A	12	21	0.98	0.45	0.64	0.98
#
# [Class Samples]: 1696
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1644	26	0.98	0.99	0.98	0.64
# A	12	21	0.98	0.45	0.64	0.98
#
# ==============================================
# incartdb_I64
# ==============================================
# [All Samples]: 1911
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1885	0	0.99	0.99	1.0	0.58
# A	11	15	0.99	1.0	0.58	1.0
#
# [Class Samples]: 1885
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1885	0	0.99	0.99	1.0	0.58
# A	11	15	0.99	1.0	0.58	1.0
#
# ==============================================
# incartdb_I21
# ==============================================
# [All Samples]: 2182
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1532	538	0.75	1.0	0.74	1.0
# A	0	112	0.75	0.17	1.0	0.74
#
# [Class Samples]: 2174
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1532	538	0.75	1.0	0.74	1.0
# A	0	112	0.75	0.17	1.0	0.74
#
# ==============================================
# incartdb_I71
# ==============================================
# [All Samples]: 1668
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1496	137	0.92	1.0	0.92	0.97
# A	1	34	0.92	0.2	0.97	0.92
#
# [Class Samples]: 1668
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1496	137	0.92	1.0	0.92	0.97
# A	1	34	0.92	0.2	0.97	0.92
#
# ==============================================
# incartdb_I06
# ==============================================
# [All Samples]: 2491
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2317	117	0.95	0.99	0.95	0.7
# A	17	40	0.95	0.25	0.7	0.95
#
# [Class Samples]: 2482
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2317	117	0.95	0.99	0.95	0.7
# A	17	40	0.95	0.25	0.7	0.95
#
# ==============================================
# incartdb_I35
# ==============================================
# [All Samples]: 3673
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1283	1915	0.47	0.97	0.4	0.92
# A	40	435	0.47	0.19	0.92	0.4
#
# [Class Samples]: 3198
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1283	1915	0.47	0.97	0.4	0.92
# A	40	435	0.47	0.19	0.92	0.4
#
# ==============================================
# incartdb_I07
# ==============================================
# [All Samples]: 2704
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2480	158	0.94	1.0	0.94	0.86
# A	9	57	0.94	0.27	0.86	0.94
#
# [Class Samples]: 2703
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2480	158	0.94	1.0	0.94	0.86
# A	9	57	0.94	0.27	0.86	0.94
#
# ==============================================
# incartdb_I72
# ==============================================
# [All Samples]: 2267
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1253	620	0.72	0.99	0.67	0.98
# A	7	387	0.72	0.38	0.98	0.67
#
# [Class Samples]: 1881
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1253	620	0.72	0.99	0.67	0.98
# A	7	387	0.72	0.38	0.98	0.67
#
# ==============================================
# incartdb_I22
# ==============================================
# [All Samples]: 3124
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1863	951	0.69	0.99	0.66	0.95
# A	15	295	0.69	0.24	0.95	0.66
#
# [Class Samples]: 2938
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1863	951	0.69	0.99	0.66	0.95
# A	15	295	0.69	0.24	0.95	0.66
#
# ==============================================
# incartdb_I05
# ==============================================
# [All Samples]: 1774
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1513	5	0.95	0.95	1.0	0.7
# A	78	178	0.95	0.97	0.7	1.0
#
# [Class Samples]: 1518
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1513	5	0.95	0.95	1.0	0.7
# A	78	178	0.95	0.97	0.7	1.0
#
# ==============================================
# incartdb_I48
# ==============================================
# [All Samples]: 2355
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2036	81	0.96	1.0	0.96	0.99
# A	2	236	0.96	0.74	0.99	0.96
#
# [Class Samples]: 2119
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2036	81	0.96	1.0	0.96	0.99
# A	2	236	0.96	0.74	0.99	0.96
#
# ==============================================
# incartdb_I18
# ==============================================
# [All Samples]: 3082
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2022	638	0.79	0.99	0.76	0.97
# A	14	408	0.79	0.39	0.97	0.76
#
# [Class Samples]: 2660
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2022	638	0.79	0.99	0.76	0.97
# A	14	408	0.79	0.39	0.97	0.76
#
# ==============================================
# incartdb_I31
# ==============================================
# [All Samples]: 3208
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1389	454	0.8	0.88	0.75	0.86
# A	192	1173	0.8	0.72	0.86	0.75
#
# [Class Samples]: 1843
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1389	454	0.8	0.88	0.75	0.86
# A	192	1173	0.8	0.72	0.86	0.75
#
# ==============================================
# incartdb_I62
# ==============================================
# [All Samples]: 2267
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1252	199	0.82	0.85	0.86	0.74
# A	215	601	0.82	0.75	0.74	0.86
#
# [Class Samples]: 1460
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1252	199	0.82	0.85	0.86	0.74
# A	215	601	0.82	0.75	0.74	0.86
#
# ==============================================
# incartdb_I23
# ==============================================
# [All Samples]: 2203
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2079	111	0.95	1.0	0.95	1.0
# A	0	13	0.95	0.1	1.0	0.95
#
# [Class Samples]: 2190
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2079	111	0.95	1.0	0.95	1.0
# A	0	13	0.95	0.1	1.0	0.95
#
# ==============================================
# incartdb_I73
# ==============================================
# [All Samples]: 1990
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1841	47	0.97	1.0	0.98	0.97
# A	3	99	0.97	0.68	0.97	0.98
#
# [Class Samples]: 1920
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1841	47	0.97	1.0	0.98	0.97
# A	3	99	0.97	0.68	0.97	0.98
#
# ==============================================
# incartdb_I10
# ==============================================
# [All Samples]: 3680
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2035	1562	0.57	0.99	0.57	0.69
# A	26	57	0.57	0.04	0.69	0.57
#
# [Class Samples]: 3597
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2035	1562	0.57	0.99	0.57	0.69
# A	26	57	0.57	0.04	0.69	0.57
#
#
# ==============================================
# 	Global Confusion Matrix [All]
# A\P	N	A
# N	132714	19644
# A	1327	19858
#
# Performance for 2 classes
# Class	ACC	PRE	SEN	SPF
# N	0.88	0.99	0.87	0.94
# A	0.88	0.5	0.94	0.87
#
# ==============================================
# 	Global Confusion Matrix [Class]
# A\P	N	S
# N	132714	19644
# S	161	1797
#
# Performance for 2 classes
# Class	ACC	PRE	SEN	SPF
# N	0.87	1.0	0.87	0.92
# S	0.87	0.08	0.92	0.87
#
# ==============================================
# Elapsed time = 0:08:07.713079

# %% [markdown]
# ## [ V ] - Load Model

# %%
ds_modelV = 'M_V_m_75_1'       # SELECT MODEL WEIGHTS TO TEST UPON

model_pathV = os.path.join(global_modeldir, ds_modelV +'.h5')
modelV=get_modelCNN_1D(False,V_DP.vdim,ds_modelV)
modelV.load_weights(model_pathV)
print('Loaded Model weights '+ str(model_pathV))
# Out:
# Loaded Model weights /content/drive/My Drive/Masters/workdir/ecg_data/db_model/M_V_m_75_1.h5

# %% [markdown]
# ## [ V ] - Test DB

# %%
##<----------------------------------------------
work_dbV = std_db_i
##<----------------------------------------------
##<----------------------------------------------
sel_NR_count = 30
nr_supress=False
nrb_from_bins=False
nrb_bin_ordered = False
nrb_return = False
print('Testing database:',work_dbV.keys(),'on model:', modelV.name)
print('NR_Count:', sel_NR_count)

conf_matrix_gAV = np.zeros((2,2),dtype='int32') # confusion matrix S
conf_matrix_gCV = np.zeros((2,2),dtype='int32') # confusion matrix Combined
pred_dictV = {}  # predection results dictionary
#<<----------------------------------------
timestamp_start = datetime.datetime.now()
#<<----------------------------------------
print('\n----------------------------------------')

for idb in work_dbV.keys():
    #<<--------------------
    sel_db = work_dbV[idb]
    for irec in sel_db.recs_tag:
        #<<--------------------
        sel_rec = sel_db.get_record(irec)
        #print(sel_rec.name)
        sbi = sel_rec.read_binfo()
        prAV,prCV,cmAV,cmCV,truthAV,_,_ = perform_record_test(modelV, V_DP, gV_LABELS, sel_rec, sbi, sel_NR_count, nr_supress ,nrb_from_bins, nrb_bin_ordered ,nrb_return)
        pred_dictV[sel_rec.name] = [prAV,truthAV]
        if len(cmAV)!=0 and len(cmCV)!=0 :
            conf_matrix_gAV += cmAV
            conf_matrix_gCV += cmCV
    # end loop
print('\n==============================================')
print('\tGlobal Confusion Matrix [All]')
print(print_conf_matrix( conf_matrix_gAV,'', gA_LABELS)) #logit('\t'+str(cmx))
print_performance( get_performance(conf_matrix_gAV) ,gA_LABELS ) 

print('\n==============================================')
print('\tGlobal Confusion Matrix [Class]')
print(print_conf_matrix( conf_matrix_gCV,'', gV_LABELS)) #logit('\t'+str(cmx))
print_performance( get_performance(conf_matrix_gCV) ,gV_LABELS ) 

#------------------------------------------------------------
print('\n==============================================')
timestamp_dur = datetime.datetime.now() - timestamp_start
print('Elapsed time = ' + str(timestamp_dur))
# Out:
# Testing database: dict_keys(['incartdb']) on model: M_V_m_75_1
# NR_Count: 30
#
# ----------------------------------------
# ==============================================
# incartdb_I04
# ==============================================
# [All Samples]: 2421
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2261	6	0.99	0.99	1.0	0.82
# A	27	127	0.99	0.95	0.82	1.0
#
# [Class Samples]: 2405
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2261	6	0.99	0.99	1.0	0.82
# A	27	127	0.99	0.95	0.82	1.0
#
# ==============================================
# incartdb_I01
# ==============================================
# [All Samples]: 2755
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1732	679	0.73	0.97	0.72	0.83
# A	60	284	0.73	0.29	0.83	0.72
#
# [Class Samples]: 2755
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1732	679	0.73	0.97	0.72	0.83
# A	60	284	0.73	0.29	0.83	0.72
#
# ==============================================
# incartdb_I33
# ==============================================
# [All Samples]: 1835
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1244	1	0.79	0.77	1.0	0.36
# A	377	213	0.79	1.0	0.36	1.0
#
# [Class Samples]: 1246
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1244	1	0.79	0.77	1.0	0.36
# A	377	213	0.79	1.0	0.36	1.0
#
# ==============================================
# incartdb_I03
# ==============================================
# [All Samples]: 2450
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2323	0	1.0	1.0	1.0	0.91
# A	11	116	1.0	1.0	0.91	1.0
#
# [Class Samples]: 2448
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2323	0	1.0	1.0	1.0	0.91
# A	11	116	1.0	1.0	0.91	1.0
#
# ==============================================
# incartdb_I12
# ==============================================
# [All Samples]: 2807
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2561	237	0.91	1.0	0.92	0.67
# A	3	6	0.91	0.02	0.67	0.92
#
# [Class Samples]: 2806
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2561	237	0.91	1.0	0.92	0.67
# A	3	6	0.91	0.02	0.67	0.92
#
# ==============================================
# incartdb_I65
# ==============================================
# [All Samples]: 2662
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2154	117	0.95	1.0	0.95	0.99
# A	5	386	0.95	0.77	0.99	0.95
#
# [Class Samples]: 2657
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2154	117	0.95	1.0	0.95	0.99
# A	5	386	0.95	0.77	0.99	0.95
#
# ==============================================
# incartdb_I02
# ==============================================
# [All Samples]: 2672
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2165	278	0.89	0.99	0.89	0.92
# A	18	211	0.89	0.43	0.92	0.89
#
# [Class Samples]: 2672
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2165	278	0.89	0.99	0.89	0.92
# A	18	211	0.89	0.43	0.92	0.89
#
# ==============================================
# incartdb_I20
# ==============================================
# [All Samples]: 2650
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2324	36	0.91	0.92	0.98	0.3
# A	204	86	0.91	0.7	0.3	0.98
#
# [Class Samples]: 2471
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2324	36	0.91	0.92	0.98	0.3
# A	204	86	0.91	0.7	0.3	0.98
#
# ==============================================
# incartdb_I61
# ==============================================
# [All Samples]: 1452
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1451	0	1.0	1.0	1.0	0.0
# A	1	0	1.0	nan	0.0	1.0
#
# [Class Samples]: 1451
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1451	0	1.0	1.0	1.0	0.0
# A	1	0	1.0	nan	0.0	1.0
#
# ==============================================
# incartdb_I26
# ==============================================
# [All Samples]: 1507
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1496	0	1.0	1.0	1.0	0.36
# A	7	4	1.0	1.0	0.36	1.0
#
# [Class Samples]: 1500
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1496	0	1.0	1.0	1.0	0.36
# A	7	4	1.0	1.0	0.36	1.0
#
# ==============================================
# incartdb_I37
# ==============================================
# [All Samples]: 2459
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2004	3	1.0	1.0	1.0	1.0
# A	0	452	1.0	0.99	1.0	1.0
#
# [Class Samples]: 2459
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2004	3	1.0	1.0	1.0	1.0
# A	0	452	1.0	0.99	1.0	1.0
#
# ==============================================
# incartdb_I29
# ==============================================
# [All Samples]: 2619
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1554	281	0.84	0.91	0.85	0.82
# A	145	639	0.84	0.69	0.82	0.85
#
# [Class Samples]: 2618
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1554	281	0.84	0.91	0.85	0.82
# A	145	639	0.84	0.69	0.82	0.85
#
# ==============================================
# incartdb_I13
# ==============================================
# [All Samples]: 2021
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1788	3	1.0	1.0	1.0	1.0
# A	0	230	1.0	0.99	1.0	1.0
#
# [Class Samples]: 2021
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1788	3	1.0	1.0	1.0	1.0
# A	0	230	1.0	0.99	1.0	1.0
#
# ==============================================
# incartdb_I45
# ==============================================
# [All Samples]: 1926
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1434	1	1.0	1.0	1.0	1.0
# A	0	491	1.0	1.0	1.0	1.0
#
# [Class Samples]: 1926
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1434	1	1.0	1.0	1.0	1.0
# A	0	491	1.0	1.0	1.0	1.0
#
# ==============================================
# incartdb_I63
# ==============================================
# [All Samples]: 1992
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1842	3	1.0	1.0	1.0	0.97
# A	4	143	1.0	0.98	0.97	1.0
#
# [Class Samples]: 1991
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1842	3	1.0	1.0	1.0	0.97
# A	4	143	1.0	0.98	0.97	1.0
#
# ==============================================
# incartdb_I28
# ==============================================
# [All Samples]: 1715
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1674	37	0.98	1.0	0.98	1.0
# A	0	4	0.98	0.1	1.0	0.98
#
# [Class Samples]: 1715
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1674	37	0.98	1.0	0.98	1.0
# A	0	4	0.98	0.1	1.0	0.98
#
# ==============================================
# incartdb_I16
# ==============================================
# [All Samples]: 1520
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1513	5	1.0	1.0	1.0	0.5
# A	1	1	1.0	0.17	0.5	1.0
#
# [Class Samples]: 1520
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1513	5	1.0	1.0	1.0	0.5
# A	1	1	1.0	0.17	0.5	1.0
#
# ==============================================
# incartdb_I19
# ==============================================
# [All Samples]: 2061
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1202	10	0.97	0.97	0.99	0.95
# A	43	806	0.97	0.99	0.95	0.99
#
# [Class Samples]: 2061
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1202	10	0.97	0.97	0.99	0.95
# A	43	806	0.97	0.99	0.95	0.99
#
# ==============================================
# incartdb_I57
# ==============================================
# [All Samples]: 2868
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2470	369	0.87	1.0	0.87	0.93
# A	2	27	0.87	0.07	0.93	0.87
#
# [Class Samples]: 2863
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2470	369	0.87	1.0	0.87	0.93
# A	2	27	0.87	0.07	0.93	0.87
#
# ==============================================
# incartdb_I67
# ==============================================
# [All Samples]: 2973
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2332	104	0.96	1.0	0.96	0.99
# A	5	532	0.96	0.84	0.99	0.96
#
# [Class Samples]: 2968
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2332	104	0.96	1.0	0.96	0.99
# A	5	532	0.96	0.84	0.99	0.96
#
# ==============================================
# incartdb_I17
# ==============================================
# [All Samples]: 1670
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1636	7	1.0	1.0	1.0	0.96
# A	1	26	1.0	0.79	0.96	1.0
#
# [Class Samples]: 1670
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1636	7	1.0	1.0	1.0	0.96
# A	1	26	1.0	0.79	0.96	1.0
#
# ==============================================
# incartdb_I54
# ==============================================
# [All Samples]: 2361
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1726	612	0.74	1.0	0.74	0.74
# A	6	17	0.74	0.03	0.74	0.74
#
# [Class Samples]: 2360
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1726	612	0.74	1.0	0.74	0.74
# A	6	17	0.74	0.03	0.74	0.74
#
# ==============================================
# incartdb_I49
# ==============================================
# [All Samples]: 2145
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2114	4	1.0	1.0	1.0	1.0
# A	0	27	1.0	0.87	1.0	1.0
#
# [Class Samples]: 2145
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2114	4	1.0	1.0	1.0	1.0
# A	0	27	1.0	0.87	1.0	1.0
#
# ==============================================
# incartdb_I51
# ==============================================
# [All Samples]: 2775
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1475	494	0.82	1.0	0.75	1.0
# A	3	803	0.82	0.62	1.0	0.75
#
# [Class Samples]: 2772
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1475	494	0.82	1.0	0.75	1.0
# A	3	803	0.82	0.62	1.0	0.75
#
# ==============================================
# incartdb_I40
# ==============================================
# [All Samples]: 2664
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2096	470	0.82	1.0	0.82	0.97
# A	3	95	0.82	0.17	0.97	0.82
#
# [Class Samples]: 2658
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2096	470	0.82	1.0	0.82	0.97
# A	3	95	0.82	0.17	0.97	0.82
#
# ==============================================
# incartdb_I70
# ==============================================
# [All Samples]: 1664
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1538	0	0.93	0.93	1.0	0.06
# A	118	8	0.93	1.0	0.06	1.0
#
# [Class Samples]: 1538
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1538	0	0.93	0.93	1.0	0.06
# A	118	8	0.93	1.0	0.06	1.0
#
# ==============================================
# incartdb_I36
# ==============================================
# [All Samples]: 3909
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2571	876	0.77	1.0	0.75	0.99
# A	6	456	0.77	0.34	0.99	0.75
#
# [Class Samples]: 3909
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2571	876	0.77	1.0	0.75	0.99
# A	6	456	0.77	0.34	0.99	0.75
#
# ==============================================
# incartdb_I30
# ==============================================
# [All Samples]: 2460
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1522	183	0.87	0.92	0.89	0.83
# A	127	628	0.87	0.77	0.83	0.89
#
# [Class Samples]: 2460
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1522	183	0.87	0.92	0.89	0.83
# A	127	628	0.87	0.77	0.83	0.89
#
# ==============================================
# incartdb_I60
# ==============================================
# [All Samples]: 2473
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2272	150	0.92	0.98	0.94	0.08
# A	47	4	0.92	0.03	0.08	0.94
#
# [Class Samples]: 2422
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2272	150	0.92	0.98	0.94	0.08
# A	47	4	0.92	0.03	0.08	0.94
#
# ==============================================
# incartdb_I50
# ==============================================
# [All Samples]: 2996
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2896	96	0.97	1.0	0.97	1.0
# A	0	4	0.97	0.04	1.0	0.97
#
# [Class Samples]: 2996
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2896	96	0.97	1.0	0.97	1.0
# A	0	4	0.97	0.04	1.0	0.97
#
# ==============================================
# incartdb_I44
# ==============================================
# [All Samples]: 2492
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1713	88	0.96	1.0	0.95	0.99
# A	7	684	0.96	0.89	0.99	0.95
#
# [Class Samples]: 2484
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1713	88	0.96	1.0	0.95	0.99
# A	7	684	0.96	0.89	0.99	0.95
#
# ==============================================
# incartdb_I75
# ==============================================
# [All Samples]: 2101
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1482	0	1.0	1.0	1.0	1.0
# A	0	619	1.0	1.0	1.0	1.0
#
# [Class Samples]: 2101
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1482	0	1.0	1.0	1.0	1.0
# A	0	619	1.0	1.0	1.0	1.0
#
# ==============================================
# incartdb_I46
# ==============================================
# [All Samples]: 2656
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1771	459	0.83	1.0	0.79	1.0
# A	1	425	0.83	0.48	1.0	0.79
#
# [Class Samples]: 2655
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1771	459	0.83	1.0	0.79	1.0
# A	1	425	0.83	0.48	1.0	0.79
#
# ==============================================
# incartdb_I14
# ==============================================
# [All Samples]: 1864
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1799	1	1.0	1.0	1.0	1.0
# A	0	64	1.0	0.98	1.0	1.0
#
# [Class Samples]: 1864
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1799	1	1.0	1.0	1.0	1.0
# A	0	64	1.0	0.98	1.0	1.0
#
# ==============================================
# incartdb_I55
# ==============================================
# [All Samples]: 2164
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1668	478	0.78	1.0	0.78	1.0
# A	0	18	0.78	0.04	1.0	0.78
#
# [Class Samples]: 2163
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1668	478	0.78	1.0	0.78	1.0
# A	0	18	0.78	0.04	1.0	0.78
#
# ==============================================
# incartdb_I09
# ==============================================
# [All Samples]: 2995
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2514	432	0.85	1.0	0.85	0.86
# A	7	42	0.85	0.09	0.86	0.85
#
# [Class Samples]: 2987
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2514	432	0.85	1.0	0.85	0.86
# A	7	42	0.85	0.09	0.86	0.85
#
# ==============================================
# incartdb_I27
# ==============================================
# [All Samples]: 2603
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1814	70	0.97	1.0	0.96	1.0
# A	0	719	0.97	0.91	1.0	0.96
#
# [Class Samples]: 2603
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1814	70	0.97	1.0	0.96	1.0
# A	0	719	0.97	0.91	1.0	0.96
#
# ==============================================
# incartdb_I66
# ==============================================
# [All Samples]: 2338
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2118	19	0.99	1.0	0.99	1.0
# A	1	200	0.99	0.91	1.0	0.99
#
# [Class Samples]: 2337
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2118	19	0.99	1.0	0.99	1.0
# A	1	200	0.99	0.91	1.0	0.99
#
# ==============================================
# incartdb_I58
# ==============================================
# [All Samples]: 2323
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2258	53	0.98	1.0	0.98	1.0
# A	0	12	0.98	0.18	1.0	0.98
#
# [Class Samples]: 2323
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2258	53	0.98	1.0	0.98	1.0
# A	0	12	0.98	0.18	1.0	0.98
#
# ==============================================
# incartdb_I47
# ==============================================
# [All Samples]: 1951
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1760	97	0.95	1.0	0.95	0.99
# A	1	93	0.95	0.49	0.99	0.95
#
# [Class Samples]: 1950
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1760	97	0.95	1.0	0.95	0.99
# A	1	93	0.95	0.49	0.99	0.95
#
# ==============================================
# incartdb_I41
# ==============================================
# [All Samples]: 1628
# A\P	N	A	ACC	PRE	SEN	SPF
# N	637	985	0.39	1.0	0.39	0.83
# A	1	5	0.39	0.01	0.83	0.39
#
# [Class Samples]: 1623
# A\P	N	A	ACC	PRE	SEN	SPF
# N	637	985	0.39	1.0	0.39	0.83
# A	1	5	0.39	0.01	0.83	0.39
#
# ==============================================
# incartdb_I38
# ==============================================
# [All Samples]: 2697
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2034	119	0.95	1.0	0.94	0.98
# A	9	535	0.95	0.82	0.98	0.94
#
# [Class Samples]: 2696
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2034	119	0.95	1.0	0.94	0.98
# A	9	535	0.95	0.82	0.98	0.94
#
# ==============================================
# incartdb_I32
# ==============================================
# [All Samples]: 1617
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1553	7	0.99	1.0	1.0	0.95
# A	3	54	0.99	0.89	0.95	1.0
#
# [Class Samples]: 1617
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1553	7	0.99	1.0	1.0	0.95
# A	3	54	0.99	0.89	0.95	1.0
#
# ==============================================
# incartdb_I34
# ==============================================
# [All Samples]: 1963
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1424	3	0.79	0.78	1.0	0.23
# A	412	124	0.79	0.98	0.23	1.0
#
# [Class Samples]: 1427
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1424	3	0.79	0.78	1.0	0.23
# A	412	124	0.79	0.98	0.23	1.0
#
# ==============================================
# incartdb_I74
# ==============================================
# [All Samples]: 2402
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1995	85	0.96	1.0	0.96	1.0
# A	0	322	0.96	0.79	1.0	0.96
#
# [Class Samples]: 2402
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1995	85	0.96	1.0	0.96	1.0
# A	0	322	0.96	0.79	1.0	0.96
#
# ==============================================
# incartdb_I11
# ==============================================
# [All Samples]: 2104
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2074	2	0.99	0.99	1.0	0.18
# A	23	5	0.99	0.71	0.18	1.0
#
# [Class Samples]: 2080
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2074	2	0.99	0.99	1.0	0.18
# A	23	5	0.99	0.71	0.18	1.0
#
# ==============================================
# incartdb_I39
# ==============================================
# [All Samples]: 1773
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1444	16	0.99	1.0	0.99	0.99
# A	4	309	0.99	0.95	0.99	0.99
#
# [Class Samples]: 1773
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1444	16	0.99	1.0	0.99	0.99
# A	4	309	0.99	0.95	0.99	0.99
#
# ==============================================
# incartdb_I42
# ==============================================
# [All Samples]: 3107
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1247	297	0.9	1.0	0.81	1.0
# A	4	1559	0.9	0.84	1.0	0.81
#
# [Class Samples]: 3107
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1247	297	0.9	1.0	0.81	1.0
# A	4	1559	0.9	0.84	1.0	0.81
#
# ==============================================
# incartdb_I52
# ==============================================
# [All Samples]: 1745
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1606	2	1.0	1.0	1.0	1.0
# A	0	137	1.0	0.99	1.0	1.0
#
# [Class Samples]: 1745
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1606	2	1.0	1.0	1.0	1.0
# A	0	137	1.0	0.99	1.0	1.0
#
# ==============================================
# incartdb_I59
# ==============================================
# [All Samples]: 2146
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1942	82	0.95	0.98	0.96	0.75
# A	31	91	0.95	0.53	0.75	0.96
#
# [Class Samples]: 2105
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1942	82	0.95	0.98	0.96	0.75
# A	31	91	0.95	0.53	0.75	0.96
#
# ==============================================
# incartdb_I08
# ==============================================
# [All Samples]: 2129
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1673	103	0.95	0.99	0.94	0.97
# A	12	341	0.95	0.77	0.97	0.94
#
# [Class Samples]: 2126
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1673	103	0.95	0.99	0.94	0.97
# A	12	341	0.95	0.77	0.97	0.94
#
# ==============================================
# incartdb_I53
# ==============================================
# [All Samples]: 2260
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1117	33	0.99	1.0	0.97	1.0
# A	0	1110	0.99	0.97	1.0	0.97
#
# [Class Samples]: 2260
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1117	33	0.99	1.0	0.97	1.0
# A	0	1110	0.99	0.97	1.0	0.97
#
# ==============================================
# incartdb_I69
# ==============================================
# [All Samples]: 2167
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1991	7	1.0	1.0	1.0	1.0
# A	0	169	1.0	0.96	1.0	1.0
#
# [Class Samples]: 2166
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1991	7	1.0	1.0	1.0	1.0
# A	0	169	1.0	0.96	1.0	1.0
#
# ==============================================
# incartdb_I68
# ==============================================
# [All Samples]: 2642
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2394	85	0.97	1.0	0.97	0.98
# A	3	160	0.97	0.65	0.98	0.97
#
# [Class Samples]: 2640
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2394	85	0.97	1.0	0.97	0.98
# A	3	160	0.97	0.65	0.98	0.97
#
# ==============================================
# incartdb_I24
# ==============================================
# [All Samples]: 2569
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2384	179	0.93	1.0	0.93	1.0
# A	0	6	0.93	0.03	1.0	0.93
#
# [Class Samples]: 2569
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2384	179	0.93	1.0	0.93	1.0
# A	0	6	0.93	0.03	1.0	0.93
#
# ==============================================
# incartdb_I15
# ==============================================
# [All Samples]: 2633
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2624	6	1.0	1.0	1.0	0.67
# A	1	2	1.0	0.25	0.67	1.0
#
# [Class Samples]: 2633
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2624	6	1.0	1.0	1.0	0.67
# A	1	2	1.0	0.25	0.67	1.0
#
# ==============================================
# incartdb_I25
# ==============================================
# [All Samples]: 1710
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1690	13	0.99	1.0	0.99	0.14
# A	6	1	0.99	0.07	0.14	0.99
#
# [Class Samples]: 1708
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1690	13	0.99	1.0	0.99	0.14
# A	6	1	0.99	0.07	0.14	0.99
#
# ==============================================
# incartdb_I43
# ==============================================
# WARNING: count NR mismatch.... using 0
# ERROR: No NR beat ....skip
# ==============================================
# incartdb_I56
# ==============================================
# [All Samples]: 1703
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1569	101	0.93	0.99	0.94	0.48
# A	17	16	0.93	0.14	0.48	0.94
#
# [Class Samples]: 1677
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1569	101	0.93	0.99	0.94	0.48
# A	17	16	0.93	0.14	0.48	0.94
#
# ==============================================
# incartdb_I64
# ==============================================
# [All Samples]: 1911
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1880	5	1.0	1.0	1.0	0.92
# A	2	24	1.0	0.83	0.92	1.0
#
# [Class Samples]: 1911
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1880	5	1.0	1.0	1.0	0.92
# A	2	24	1.0	0.83	0.92	1.0
#
# ==============================================
# incartdb_I21
# ==============================================
# [All Samples]: 2182
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2064	6	0.95	0.95	1.0	0.07
# A	104	8	0.95	0.57	0.07	1.0
#
# [Class Samples]: 2078
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2064	6	0.95	0.95	1.0	0.07
# A	104	8	0.95	0.57	0.07	1.0
#
# ==============================================
# incartdb_I71
# ==============================================
# [All Samples]: 1668
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1619	14	0.98	0.99	0.99	0.31
# A	24	11	0.98	0.44	0.31	0.99
#
# [Class Samples]: 1633
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1619	14	0.98	0.99	0.99	0.31
# A	24	11	0.98	0.44	0.31	0.99
#
# ==============================================
# incartdb_I06
# ==============================================
# [All Samples]: 2491
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2347	87	0.95	0.99	0.96	0.39
# A	35	22	0.95	0.2	0.39	0.96
#
# [Class Samples]: 2443
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2347	87	0.95	0.99	0.96	0.39
# A	35	22	0.95	0.2	0.39	0.96
#
# ==============================================
# incartdb_I35
# ==============================================
# [All Samples]: 3673
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2643	555	0.85	1.0	0.83	0.99
# A	6	469	0.85	0.46	0.99	0.83
#
# [Class Samples]: 3673
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2643	555	0.85	1.0	0.83	0.99
# A	6	469	0.85	0.46	0.99	0.83
#
# ==============================================
# incartdb_I07
# ==============================================
# [All Samples]: 2704
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2359	279	0.88	0.98	0.89	0.39
# A	40	26	0.88	0.09	0.39	0.89
#
# [Class Samples]: 2639
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2359	279	0.88	0.98	0.89	0.39
# A	40	26	0.88	0.09	0.39	0.89
#
# ==============================================
# incartdb_I72
# ==============================================
# [All Samples]: 2267
# A\P	N	A	ACC	PRE	SEN	SPF
# N	898	975	0.57	1.0	0.48	1.0
# A	1	393	0.57	0.29	1.0	0.48
#
# [Class Samples]: 2259
# A\P	N	A	ACC	PRE	SEN	SPF
# N	898	975	0.57	1.0	0.48	1.0
# A	1	393	0.57	0.29	1.0	0.48
#
# ==============================================
# incartdb_I22
# ==============================================
# [All Samples]: 3124
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2751	63	0.94	0.95	0.98	0.56
# A	135	175	0.94	0.74	0.56	0.98
#
# [Class Samples]: 3000
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2751	63	0.94	0.95	0.98	0.56
# A	135	175	0.94	0.74	0.56	0.98
#
# ==============================================
# incartdb_I05
# ==============================================
# [All Samples]: 1774
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1516	2	0.99	0.99	1.0	0.91
# A	23	233	0.99	0.99	0.91	1.0
#
# [Class Samples]: 1774
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1516	2	0.99	0.99	1.0	0.91
# A	23	233	0.99	0.99	0.91	1.0
#
# ==============================================
# incartdb_I48
# ==============================================
# [All Samples]: 2355
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1991	126	0.95	1.0	0.94	1.0
# A	1	237	0.95	0.65	1.0	0.94
#
# [Class Samples]: 2353
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1991	126	0.95	1.0	0.94	1.0
# A	1	237	0.95	0.65	1.0	0.94
#
# ==============================================
# incartdb_I18
# ==============================================
# [All Samples]: 3082
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2352	308	0.9	1.0	0.88	0.99
# A	5	417	0.9	0.58	0.99	0.88
#
# [Class Samples]: 3082
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2352	308	0.9	1.0	0.88	0.99
# A	5	417	0.9	0.58	0.99	0.88
#
# ==============================================
# incartdb_I31
# ==============================================
# [All Samples]: 3208
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1322	521	0.75	0.83	0.72	0.79
# A	280	1085	0.75	0.68	0.79	0.72
#
# [Class Samples]: 3207
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1322	521	0.75	0.83	0.72	0.79
# A	280	1085	0.75	0.68	0.79	0.72
#
# ==============================================
# incartdb_I62
# ==============================================
# [All Samples]: 2267
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1329	122	0.92	0.95	0.92	0.92
# A	69	747	0.92	0.86	0.92	0.92
#
# [Class Samples]: 2258
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1329	122	0.92	0.95	0.92	0.92
# A	69	747	0.92	0.86	0.92	0.92
#
# ==============================================
# incartdb_I23
# ==============================================
# [All Samples]: 2203
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2102	88	0.96	1.0	0.96	1.0
# A	0	13	0.96	0.13	1.0	0.96
#
# [Class Samples]: 2203
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2102	88	0.96	1.0	0.96	1.0
# A	0	13	0.96	0.13	1.0	0.96
#
# ==============================================
# incartdb_I73
# ==============================================
# [All Samples]: 1990
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1639	249	0.87	1.0	0.87	0.98
# A	2	100	0.87	0.29	0.98	0.87
#
# [Class Samples]: 1958
# A\P	N	A	ACC	PRE	SEN	SPF
# N	1639	249	0.87	1.0	0.87	0.98
# A	2	100	0.87	0.29	0.98	0.87
#
# ==============================================
# incartdb_I10
# ==============================================
# [All Samples]: 3680
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2136	1461	0.6	1.0	0.59	1.0
# A	0	83	0.6	0.05	1.0	0.59
#
# [Class Samples]: 3680
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2136	1461	0.6	1.0	0.59	1.0
# A	0	83	0.6	0.05	1.0	0.59
#
#
# ==============================================
# 	Global Confusion Matrix [All]
# A\P	N	A
# N	138613	13745
# A	2494	18691
#
# Performance for 2 classes
# Class	ACC	PRE	SEN	SPF
# N	0.91	0.98	0.91	0.88
# A	0.91	0.58	0.88	0.91
#
# ==============================================
# 	Global Confusion Matrix [Class]
# A\P	N	V
# N	138613	13745
# V	903	18194
#
# Performance for 2 classes
# Class	ACC	PRE	SEN	SPF
# N	0.91	0.99	0.91	0.95
# V	0.91	0.57	0.95	0.91
#
# ==============================================
# Elapsed time = 0:08:09.716758

# %% [markdown]
# ## [ Comined Performance ]

# %%
# >> must be tested on same database <<
conf_matrix_gC = np.zeros((2,2),dtype='int32') # confusion matrix combined
# use pred_dictV, pred_dictV
pdkV = np.sort(np.array( list(pred_dictV.keys()) ))
pdkS = np.sort(np.array( list(pred_dictS.keys()) ))
mismatch = np.where(pdkV!=pdkS)[0]
if len(mismatch)==0:
    for ir in pdkS:
        prAS,data_yS = pred_dictS[ir][0],pred_dictS[ir][1]
        prAV,data_yV = pred_dictV[ir][0],pred_dictV[ir][1]

        prx = np.logical_or(prAS,prAV)
        daty = np.logical_or(data_yS,data_yV) 

        print('\n'+ir+'[Combined]:',len(daty))
        conf_matrix = np.zeros((2,2),dtype='int32')
        conf_matrix[0,0] = len(np.where((daty==0)&(prx==0))[0])
        conf_matrix[0,1] = len(np.where((daty==0)&(prx==1))[0])
        conf_matrix[1,0] = len(np.where((daty==1)&(prx==0))[0])
        conf_matrix[1,1] = len(np.where((daty==1)&(prx==1))[0])
        print('\tConfusion Matrix [N/A]') # all non-N are abnormal
        print(print_conf_matrix( conf_matrix,'', gA_LABELS)) 
        print_performance( get_performance(conf_matrix) ,gA_LABELS ) 
        conf_matrix_gC+=conf_matrix
        print('------------------------------------------\n')
    print('\n=====================================')
    print('\t GLOBAL Confusion Matrix [N/A]') # all non-N are abnormal
    print(print_conf_matrix( conf_matrix_gC,'', gA_LABELS)) 
    print_performance( get_performance(conf_matrix_gC) ,gA_LABELS ) 
else:
    print ('>> must be tested on same database <<')
# Out:
# incartdb_I01[Combined]: 2755
# 	Confusion Matrix [N/A]
# A\P	N	A
# N	1343	1068
# A	13	331
#
# Performance for 2 classes
# Class	ACC	PRE	SEN	SPF
# N	0.61	0.99	0.56	0.96
# A	0.61	0.24	0.96	0.56
# ------------------------------------------
#
#
# incartdb_I02[Combined]: 2672
# 	Confusion Matrix [N/A]
# A\P	N	A
# N	1872	571
# A	0	229
#
# Performance for 2 classes
# Class	ACC	PRE	SEN	SPF
# N	0.79	1.0	0.77	1.0
# A	0.79	0.29	1.0	0.77
# ------------------------------------------
#
#
# incartdb_I03[Combined]: 2450
# 	Confusion Matrix [N/A]
# A\P	N	A
# N	2295	28
# A	2	125
#
# Performance for 2 classes
# Class	ACC	PRE	SEN	SPF
# N	0.99	1.0	0.99	0.98
# A	0.99	0.82	0.98	0.99
# ------------------------------------------
#
#
# incartdb_I04[Combined]: 2421
# 	Confusion Matrix [N/A]
# A\P	N	A
# N	2127	140
# A	12	142
#
# Performance for 2 classes
# Class	ACC	PRE	SEN	SPF
# N	0.94	0.99	0.94	0.92
# A	0.94	0.5	0.92	0.94
# ------------------------------------------
#
#
# incartdb_I05[Combined]: 1774
# 	Confusion Matrix [N/A]
# A\P	N	A
# N	1512	6
# A	17	239
#
# Performance for 2 classes
# Class	ACC	PRE	SEN	SPF
# N	0.99	0.99	1.0	0.93
# A	0.99	0.98	0.93	1.0
# ------------------------------------------
#
#
# incartdb_I06[Combined]: 2491
# 	Confusion Matrix [N/A]
# A\P	N	A
# N	2237	197
# A	15	42
#
# Performance for 2 classes
# Class	ACC	PRE	SEN	SPF
# N	0.91	0.99	0.92	0.74
# A	0.91	0.18	0.74	0.92
# ------------------------------------------
#
#
# incartdb_I07[Combined]: 2704
# 	Confusion Matrix [N/A]
# A\P	N	A
# N	2257	381
# A	8	58
#
# Performance for 2 classes
# Class	ACC	PRE	SEN	SPF
# N	0.86	1.0	0.86	0.88
# A	0.86	0.13	0.88	0.86
# ------------------------------------------
#
#
# incartdb_I08[Combined]: 2129
# 	Confusion Matrix [N/A]
# A\P	N	A
# N	1534	242
# A	1	352
#
# Performance for 2 classes
# Class	ACC	PRE	SEN	SPF
# N	0.89	1.0	0.86	1.0
# A	0.89	0.59	1.0	0.86
# ------------------------------------------
#
#
# incartdb_I09[Combined]: 2995
# 	Confusion Matrix [N/A]
# A\P	N	A
# N	1801	1145
# A	4	45
#
# Performance for 2 classes
# Class	ACC	PRE	SEN	SPF
# N	0.62	1.0	0.61	0.92
# A	0.62	0.04	0.92	0.61
# ------------------------------------------
#
#
# incartdb_I10[Combined]: 3680
# 	Confusion Matrix [N/A]
# A\P	N	A
# N	1463	2134
# A	0	83
#
# Performance for 2 classes
# Class	ACC	PRE	SEN	SPF
# N	0.42	1.0	0.41	1.0
# A	0.42	0.04	1.0	0.41
# ------------------------------------------
#
#
# incartdb_I11[Combined]: 2104
# 	Confusion Matrix [N/A]
# A\P	N	A
# N	2014	62
# A	20	8
#
# Performance for 2 classes
# Class	ACC	PRE	SEN	SPF
# N	0.96	0.99	0.97	0.29
# A	0.96	0.11	0.29	0.97
# ------------------------------------------
#
#
# incartdb_I12[Combined]: 2807
# 	Confusion Matrix [N/A]
# A\P	N	A
# N	2145	653
# A	0	9
#
# Performance for 2 classes
# Class	ACC	PRE	SEN	SPF
# N	0.77	1.0	0.77	1.0
# A	0.77	0.01	1.0	0.77
# ------------------------------------------
#
#
# incartdb_I13[Combined]: 2021
# 	Confusion Matrix [N/A]
# A\P	N	A
# N	1774	17
# A	0	230
#
# Performance for 2 classes
# Class	ACC	PRE	SEN	SPF
# N	0.99	1.0	0.99	1.0
# A	0.99	0.93	1.0	0.99
# ------------------------------------------
#
#
# incartdb_I14[Combined]: 1864
# 	Confusion Matrix [N/A]
# A\P	N	A
# N	1755	45
# A	0	64
#
# Performance for 2 classes
# Class	ACC	PRE	SEN	SPF
# N	0.98	1.0	0.98	1.0
# A	0.98	0.59	1.0	0.98
# ------------------------------------------
#
#
# incartdb_I15[Combined]: 2633
# 	Confusion Matrix [N/A]
# A\P	N	A
# N	2600	30
# A	0	3
#
# Performance for 2 classes
# Class	ACC	PRE	SEN	SPF
# N	0.99	1.0	0.99	1.0
# A	0.99	0.09	1.0	0.99
# ------------------------------------------
#
#
# incartdb_I16[Combined]: 1520
# 	Confusion Matrix [N/A]
# A\P	N	A
# N	1499	19
# A	0	2
#
# Performance for 2 classes
# Class	ACC	PRE	SEN	SPF
# N	0.99	1.0	0.99	1.0
# A	0.99	0.1	1.0	0.99
# ------------------------------------------
#
#
# incartdb_I17[Combined]: 1670
# 	Confusion Matrix [N/A]
# A\P	N	A
# N	1615	28
# A	0	27
#
# Performance for 2 classes
# Class	ACC	PRE	SEN	SPF
# N	0.98	1.0	0.98	1.0
# A	0.98	0.49	1.0	0.98
# ------------------------------------------
#
#
# incartdb_I18[Combined]: 3082
# 	Confusion Matrix [N/A]
# A\P	N	A
# N	1843	817
# A	3	419
#
# Performance for 2 classes
# Class	ACC	PRE	SEN	SPF
# N	0.73	1.0	0.69	0.99
# A	0.73	0.34	0.99	0.69
# ------------------------------------------
#
#
# incartdb_I19[Combined]: 2061
# 	Confusion Matrix [N/A]
# A\P	N	A
# N	1104	108
# A	1	848
#
# Performance for 2 classes
# Class	ACC	PRE	SEN	SPF
# N	0.95	1.0	0.91	1.0
# A	0.95	0.89	1.0	0.91
# ------------------------------------------
#
#
# incartdb_I20[Combined]: 2650
# 	Confusion Matrix [N/A]
# A\P	N	A
# N	1961	399
# A	7	283
#
# Performance for 2 classes
# Class	ACC	PRE	SEN	SPF
# N	0.85	1.0	0.83	0.98
# A	0.85	0.41	0.98	0.83
# ------------------------------------------
#
#
# incartdb_I21[Combined]: 2182
# 	Confusion Matrix [N/A]
# A\P	N	A
# N	1528	542
# A	0	112
#
# Performance for 2 classes
# Class	ACC	PRE	SEN	SPF
# N	0.75	1.0	0.74	1.0
# A	0.75	0.17	1.0	0.74
# ------------------------------------------
#
#
# incartdb_I22[Combined]: 3124
# 	Confusion Matrix [N/A]
# A\P	N	A
# N	1852	962
# A	11	299
#
# Performance for 2 classes
# Class	ACC	PRE	SEN	SPF
# N	0.69	0.99	0.66	0.96
# A	0.69	0.24	0.96	0.66
# ------------------------------------------
#
#
# incartdb_I23[Combined]: 2203
# 	Confusion Matrix [N/A]
# A\P	N	A
# N	2005	185
# A	0	13
#
# Performance for 2 classes
# Class	ACC	PRE	SEN	SPF
# N	0.92	1.0	0.92	1.0
# A	0.92	0.07	1.0	0.92
# ------------------------------------------
#
#
# incartdb_I24[Combined]: 2569
# 	Confusion Matrix [N/A]
# A\P	N	A
# N	2086	477
# A	0	6
#
# Performance for 2 classes
# Class	ACC	PRE	SEN	SPF
# N	0.81	1.0	0.81	1.0
# A	0.81	0.01	1.0	0.81
# ------------------------------------------
#
#
# incartdb_I25[Combined]: 1710
# 	Confusion Matrix [N/A]
# A\P	N	A
# N	1657	46
# A	1	6
#
# Performance for 2 classes
# Class	ACC	PRE	SEN	SPF
# N	0.97	1.0	0.97	0.86
# A	0.97	0.12	0.86	0.97
# ------------------------------------------
#
#
# incartdb_I26[Combined]: 1507
# 	Confusion Matrix [N/A]
# A\P	N	A
# N	1494	2
# A	1	10
#
# Performance for 2 classes
# Class	ACC	PRE	SEN	SPF
# N	1.0	1.0	1.0	0.91
# A	1.0	0.83	0.91	1.0
# ------------------------------------------
#
#
# incartdb_I27[Combined]: 2603
# 	Confusion Matrix [N/A]
# A\P	N	A
# N	1798	86
# A	0	719
#
# Performance for 2 classes
# Class	ACC	PRE	SEN	SPF
# N	0.97	1.0	0.95	1.0
# A	0.97	0.89	1.0	0.95
# ------------------------------------------
#
#
# incartdb_I28[Combined]: 1715
# 	Confusion Matrix [N/A]
# A\P	N	A
# N	1652	59
# A	0	4
#
# Performance for 2 classes
# Class	ACC	PRE	SEN	SPF
# N	0.97	1.0	0.97	1.0
# A	0.97	0.06	1.0	0.97
# ------------------------------------------
#
#
# incartdb_I29[Combined]: 2619
# 	Confusion Matrix [N/A]
# A\P	N	A
# N	1425	410
# A	33	751
#
# Performance for 2 classes
# Class	ACC	PRE	SEN	SPF
# N	0.83	0.98	0.78	0.96
# A	0.83	0.65	0.96	0.78
# ------------------------------------------
#
#
# incartdb_I30[Combined]: 2460
# 	Confusion Matrix [N/A]
# A\P	N	A
# N	1439	266
# A	12	743
#
# Performance for 2 classes
# Class	ACC	PRE	SEN	SPF
# N	0.89	0.99	0.84	0.98
# A	0.89	0.74	0.98	0.84
# ------------------------------------------
#
#
# incartdb_I31[Combined]: 3208
# 	Confusion Matrix [N/A]
# A\P	N	A
# N	1085	758
# A	90	1275
#
# Performance for 2 classes
# Class	ACC	PRE	SEN	SPF
# N	0.74	0.92	0.59	0.93
# A	0.74	0.63	0.93	0.59
# ------------------------------------------
#
#
# incartdb_I32[Combined]: 1617
# 	Confusion Matrix [N/A]
# A\P	N	A
# N	1540	20
# A	2	55
#
# Performance for 2 classes
# Class	ACC	PRE	SEN	SPF
# N	0.99	1.0	0.99	0.96
# A	0.99	0.73	0.96	0.99
# ------------------------------------------
#
#
# incartdb_I33[Combined]: 1835
# 	Confusion Matrix [N/A]
# A\P	N	A
# N	1192	53
# A	55	535
#
# Performance for 2 classes
# Class	ACC	PRE	SEN	SPF
# N	0.94	0.96	0.96	0.91
# A	0.94	0.91	0.91	0.96
# ------------------------------------------
#
#
# incartdb_I34[Combined]: 1963
# 	Confusion Matrix [N/A]
# A\P	N	A
# N	1396	31
# A	27	509
#
# Performance for 2 classes
# Class	ACC	PRE	SEN	SPF
# N	0.97	0.98	0.98	0.95
# A	0.97	0.94	0.95	0.98
# ------------------------------------------
#
#
# incartdb_I35[Combined]: 3673
# 	Confusion Matrix [N/A]
# A\P	N	A
# N	1172	2026
# A	4	471
#
# Performance for 2 classes
# Class	ACC	PRE	SEN	SPF
# N	0.45	1.0	0.37	0.99
# A	0.45	0.19	0.99	0.37
# ------------------------------------------
#
#
# incartdb_I36[Combined]: 3909
# 	Confusion Matrix [N/A]
# A\P	N	A
# N	1414	2033
# A	5	457
#
# Performance for 2 classes
# Class	ACC	PRE	SEN	SPF
# N	0.48	1.0	0.41	0.99
# A	0.48	0.18	0.99	0.41
# ------------------------------------------
#
#
# incartdb_I37[Combined]: 2459
# 	Confusion Matrix [N/A]
# A\P	N	A
# N	1996	11
# A	0	452
#
# Performance for 2 classes
# Class	ACC	PRE	SEN	SPF
# N	1.0	1.0	0.99	1.0
# A	1.0	0.98	1.0	0.99
# ------------------------------------------
#
#
# incartdb_I38[Combined]: 2697
# 	Confusion Matrix [N/A]
# A\P	N	A
# N	2017	136
# A	0	544
#
# Performance for 2 classes
# Class	ACC	PRE	SEN	SPF
# N	0.95	1.0	0.94	1.0
# A	0.95	0.8	1.0	0.94
# ------------------------------------------
#
#
# incartdb_I39[Combined]: 1773
# 	Confusion Matrix [N/A]
# A\P	N	A
# N	1416	44
# A	0	313
#
# Performance for 2 classes
# Class	ACC	PRE	SEN	SPF
# N	0.98	1.0	0.97	1.0
# A	0.98	0.88	1.0	0.97
# ------------------------------------------
#
#
# incartdb_I40[Combined]: 2664
# 	Confusion Matrix [N/A]
# A\P	N	A
# N	1496	1070
# A	1	97
#
# Performance for 2 classes
# Class	ACC	PRE	SEN	SPF
# N	0.6	1.0	0.58	0.99
# A	0.6	0.08	0.99	0.58
# ------------------------------------------
#
#
# incartdb_I41[Combined]: 1628
# 	Confusion Matrix [N/A]
# A\P	N	A
# N	594	1028
# A	1	5
#
# Performance for 2 classes
# Class	ACC	PRE	SEN	SPF
# N	0.37	1.0	0.37	0.83
# A	0.37	0.0	0.83	0.37
# ------------------------------------------
#
#
# incartdb_I42[Combined]: 3107
# 	Confusion Matrix [N/A]
# A\P	N	A
# N	1217	327
# A	1	1562
#
# Performance for 2 classes
# Class	ACC	PRE	SEN	SPF
# N	0.89	1.0	0.79	1.0
# A	0.89	0.83	1.0	0.79
# ------------------------------------------
#
#
# incartdb_I43[Combined]: 0
# 	Confusion Matrix [N/A]
# A\P	N	A
# N	0	0
# A	0	0
#
# Performance for 2 classes
# Class	ACC	PRE	SEN	SPF
# N	nan	nan	nan	nan
# A	nan	nan	nan	nan
# ------------------------------------------
#
#
# incartdb_I44[Combined]: 2492
# 	Confusion Matrix [N/A]
# A\P	N	A
# N	1687	114
# A	1	690
#
# Performance for 2 classes
# Class	ACC	PRE	SEN	SPF
# N	0.95	1.0	0.94	1.0
# A	0.95	0.86	1.0	0.94
# ------------------------------------------
#
#
# incartdb_I45[Combined]: 1926
# 	Confusion Matrix [N/A]
# A\P	N	A
# N	1427	8
# A	0	491
#
# Performance for 2 classes
# Class	ACC	PRE	SEN	SPF
# N	1.0	1.0	0.99	1.0
# A	1.0	0.98	1.0	0.99
# ------------------------------------------
#
#
# incartdb_I46[Combined]: 2656
# 	Confusion Matrix [N/A]
# A\P	N	A
# N	1692	538
# A	0	426
#
# Performance for 2 classes
# Class	ACC	PRE	SEN	SPF
# N	0.8	1.0	0.76	1.0
# A	0.8	0.44	1.0	0.76
# ------------------------------------------
#
#
# incartdb_I47[Combined]: 1951
# 	Confusion Matrix [N/A]
# A\P	N	A
# N	1666	191
# A	1	93
#
# Performance for 2 classes
# Class	ACC	PRE	SEN	SPF
# N	0.9	1.0	0.9	0.99
# A	0.9	0.33	0.99	0.9
# ------------------------------------------
#
#
# incartdb_I48[Combined]: 2355
# 	Confusion Matrix [N/A]
# A\P	N	A
# N	1929	188
# A	1	237
#
# Performance for 2 classes
# Class	ACC	PRE	SEN	SPF
# N	0.92	1.0	0.91	1.0
# A	0.92	0.56	1.0	0.91
# ------------------------------------------
#
#
# incartdb_I49[Combined]: 2145
# 	Confusion Matrix [N/A]
# A\P	N	A
# N	1877	241
# A	0	27
#
# Performance for 2 classes
# Class	ACC	PRE	SEN	SPF
# N	0.89	1.0	0.89	1.0
# A	0.89	0.1	1.0	0.89
# ------------------------------------------
#
#
# incartdb_I50[Combined]: 2996
# 	Confusion Matrix [N/A]
# A\P	N	A
# N	2307	685
# A	0	4
#
# Performance for 2 classes
# Class	ACC	PRE	SEN	SPF
# N	0.77	1.0	0.77	1.0
# A	0.77	0.01	1.0	0.77
# ------------------------------------------
#
#
# incartdb_I51[Combined]: 2775
# 	Confusion Matrix [N/A]
# A\P	N	A
# N	1139	830
# A	1	805
#
# Performance for 2 classes
# Class	ACC	PRE	SEN	SPF
# N	0.7	1.0	0.58	1.0
# A	0.7	0.49	1.0	0.58
# ------------------------------------------
#
#
# incartdb_I52[Combined]: 1745
# 	Confusion Matrix [N/A]
# A\P	N	A
# N	1604	4
# A	0	137
#
# Performance for 2 classes
# Class	ACC	PRE	SEN	SPF
# N	1.0	1.0	1.0	1.0
# A	1.0	0.97	1.0	1.0
# ------------------------------------------
#
#
# incartdb_I53[Combined]: 2260
# 	Confusion Matrix [N/A]
# A\P	N	A
# N	1116	34
# A	0	1110
#
# Performance for 2 classes
# Class	ACC	PRE	SEN	SPF
# N	0.98	1.0	0.97	1.0
# A	0.98	0.97	1.0	0.97
# ------------------------------------------
#
#
# incartdb_I54[Combined]: 2361
# 	Confusion Matrix [N/A]
# A\P	N	A
# N	1412	926
# A	3	20
#
# Performance for 2 classes
# Class	ACC	PRE	SEN	SPF
# N	0.61	1.0	0.6	0.87
# A	0.61	0.02	0.87	0.6
# ------------------------------------------
#
#
# incartdb_I55[Combined]: 2164
# 	Confusion Matrix [N/A]
# A\P	N	A
# N	1643	503
# A	0	18
#
# Performance for 2 classes
# Class	ACC	PRE	SEN	SPF
# N	0.77	1.0	0.77	1.0
# A	0.77	0.03	1.0	0.77
# ------------------------------------------
#
#
# incartdb_I56[Combined]: 1703
# 	Confusion Matrix [N/A]
# A\P	N	A
# N	1550	120
# A	7	26
#
# Performance for 2 classes
# Class	ACC	PRE	SEN	SPF
# N	0.93	1.0	0.93	0.79
# A	0.93	0.18	0.79	0.93
# ------------------------------------------
#
#
# incartdb_I57[Combined]: 2868
# 	Confusion Matrix [N/A]
# A\P	N	A
# N	1697	1142
# A	0	29
#
# Performance for 2 classes
# Class	ACC	PRE	SEN	SPF
# N	0.6	1.0	0.6	1.0
# A	0.6	0.02	1.0	0.6
# ------------------------------------------
#
#
# incartdb_I58[Combined]: 2323
# 	Confusion Matrix [N/A]
# A\P	N	A
# N	2133	178
# A	0	12
#
# Performance for 2 classes
# Class	ACC	PRE	SEN	SPF
# N	0.92	1.0	0.92	1.0
# A	0.92	0.06	1.0	0.92
# ------------------------------------------
#
#
# incartdb_I59[Combined]: 2146
# 	Confusion Matrix [N/A]
# A\P	N	A
# N	1857	167
# A	31	91
#
# Performance for 2 classes
# Class	ACC	PRE	SEN	SPF
# N	0.91	0.98	0.92	0.75
# A	0.91	0.35	0.75	0.92
# ------------------------------------------
#
#
# incartdb_I60[Combined]: 2473
# 	Confusion Matrix [N/A]
# A\P	N	A
# N	2044	378
# A	47	4
#
# Performance for 2 classes
# Class	ACC	PRE	SEN	SPF
# N	0.83	0.98	0.84	0.08
# A	0.83	0.01	0.08	0.84
# ------------------------------------------
#
#
# incartdb_I61[Combined]: 1452
# 	Confusion Matrix [N/A]
# A\P	N	A
# N	1451	0
# A	1	0
#
# Performance for 2 classes
# Class	ACC	PRE	SEN	SPF
# N	1.0	1.0	1.0	0.0
# A	1.0	nan	0.0	1.0
# ------------------------------------------
#
#
# incartdb_I62[Combined]: 2267
# 	Confusion Matrix [N/A]
# A\P	N	A
# N	1139	312
# A	18	798
#
# Performance for 2 classes
# Class	ACC	PRE	SEN	SPF
# N	0.85	0.98	0.78	0.98
# A	0.85	0.72	0.98	0.78
# ------------------------------------------
#
#
# incartdb_I63[Combined]: 1992
# 	Confusion Matrix [N/A]
# A\P	N	A
# N	1841	4
# A	2	145
#
# Performance for 2 classes
# Class	ACC	PRE	SEN	SPF
# N	1.0	1.0	1.0	0.99
# A	1.0	0.97	0.99	1.0
# ------------------------------------------
#
#
# incartdb_I64[Combined]: 1911
# 	Confusion Matrix [N/A]
# A\P	N	A
# N	1880	5
# A	2	24
#
# Performance for 2 classes
# Class	ACC	PRE	SEN	SPF
# N	1.0	1.0	1.0	0.92
# A	1.0	0.83	0.92	1.0
# ------------------------------------------
#
#
# incartdb_I65[Combined]: 2662
# 	Confusion Matrix [N/A]
# A\P	N	A
# N	1882	389
# A	2	389
#
# Performance for 2 classes
# Class	ACC	PRE	SEN	SPF
# N	0.85	1.0	0.83	0.99
# A	0.85	0.5	0.99	0.83
# ------------------------------------------
#
#
# incartdb_I66[Combined]: 2338
# 	Confusion Matrix [N/A]
# A\P	N	A
# N	2015	122
# A	1	200
#
# Performance for 2 classes
# Class	ACC	PRE	SEN	SPF
# N	0.95	1.0	0.94	1.0
# A	0.95	0.62	1.0	0.94
# ------------------------------------------
#
#
# incartdb_I67[Combined]: 2973
# 	Confusion Matrix [N/A]
# A\P	N	A
# N	2163	273
# A	3	534
#
# Performance for 2 classes
# Class	ACC	PRE	SEN	SPF
# N	0.91	1.0	0.89	0.99
# A	0.91	0.66	0.99	0.89
# ------------------------------------------
#
#
# incartdb_I68[Combined]: 2642
# 	Confusion Matrix [N/A]
# A\P	N	A
# N	2287	192
# A	2	161
#
# Performance for 2 classes
# Class	ACC	PRE	SEN	SPF
# N	0.93	1.0	0.92	0.99
# A	0.93	0.46	0.99	0.92
# ------------------------------------------
#
#
# incartdb_I69[Combined]: 2167
# 	Confusion Matrix [N/A]
# A\P	N	A
# N	1918	80
# A	0	169
#
# Performance for 2 classes
# Class	ACC	PRE	SEN	SPF
# N	0.96	1.0	0.96	1.0
# A	0.96	0.68	1.0	0.96
# ------------------------------------------
#
#
# incartdb_I70[Combined]: 1664
# 	Confusion Matrix [N/A]
# A\P	N	A
# N	1533	5
# A	0	126
#
# Performance for 2 classes
# Class	ACC	PRE	SEN	SPF
# N	1.0	1.0	1.0	1.0
# A	1.0	0.96	1.0	1.0
# ------------------------------------------
#
#
# incartdb_I71[Combined]: 1668
# 	Confusion Matrix [N/A]
# A\P	N	A
# N	1491	142
# A	1	34
#
# Performance for 2 classes
# Class	ACC	PRE	SEN	SPF
# N	0.91	1.0	0.91	0.97
# A	0.91	0.19	0.97	0.91
# ------------------------------------------
#
#
# incartdb_I72[Combined]: 2267
# 	Confusion Matrix [N/A]
# A\P	N	A
# N	642	1231
# A	0	394
#
# Performance for 2 classes
# Class	ACC	PRE	SEN	SPF
# N	0.46	1.0	0.34	1.0
# A	0.46	0.24	1.0	0.34
# ------------------------------------------
#
#
# incartdb_I73[Combined]: 1990
# 	Confusion Matrix [N/A]
# A\P	N	A
# N	1594	294
# A	0	102
#
# Performance for 2 classes
# Class	ACC	PRE	SEN	SPF
# N	0.85	1.0	0.84	1.0
# A	0.85	0.26	1.0	0.84
# ------------------------------------------
#
#
# incartdb_I74[Combined]: 2402
# 	Confusion Matrix [N/A]
# A\P	N	A
# N	1858	222
# A	0	322
#
# Performance for 2 classes
# Class	ACC	PRE	SEN	SPF
# N	0.91	1.0	0.89	1.0
# A	0.91	0.59	1.0	0.89
# ------------------------------------------
#
#
# incartdb_I75[Combined]: 2101
# 	Confusion Matrix [N/A]
# A\P	N	A
# N	1481	1
# A	0	619
#
# Performance for 2 classes
# Class	ACC	PRE	SEN	SPF
# N	1.0	1.0	1.0	1.0
# A	1.0	1.0	1.0	1.0
# ------------------------------------------
#
#
# =====================================
# 	 GLOBAL Confusion Matrix [N/A]
# A\P	N	A
# N	124177	28181
# A	471	20714
#
# Performance for 2 classes
# Class	ACC	PRE	SEN	SPF
# N	0.83	1.0	0.82	0.98
# A	0.83	0.42	0.98	0.82

# %% [markdown]
# ## [ TEST RECORD ]

# %% [markdown]
# ### [ select record ]

# %%
sel_db = std_incartdb
sel_rec = sel_db.get_record('I55') # incartdb_I54 I55 svdb_825 s= 859, 861
ds_name = sel_rec.name
#<<-----------------------------------------------
sbi = sel_rec.read_binfo()
sbi.map_ants2int(g_STD_MAP)
sel_signal = sel_rec.read_data(g_SIG2)
print(sel_rec.name)
# Out:
# incartdb_I55

# %% [markdown]
# ### [ S test  ]

# %%
sel_NR_count = 1
nr_supress=False
nrb_from_bins=False
nrb_bin_ordered = False
nrb_return = True
print('Testing record:',sel_rec.name)
print('NR_Count:', sel_NR_count)
print('Model:', modelS.name)
#<<-----------------------------------------------
timestamp_start = datetime.datetime.now()
#<<-----------------------------------------------
prAS,prCS,cmAS,cmCS,data_yS,_,sel_nrb = perform_record_test(modelS, S_DP, gS_LABELS, sel_rec, sbi, sel_NR_count, nr_supress, nrb_from_bins,nrb_bin_ordered,nrb_return )
#<<-----------------------------------------------
timestamp_dur = datetime.datetime.now() - timestamp_start
print('\nElapsed time = ' + str(timestamp_dur))

plot_nrb = True
if plot_nrb:
    for i in range(0,len(sel_nrb)):
        #sig_nrb,_,_ = sbi.get_signal_data_var(sel_nrb[i])
        sig_nrb = sel_nrb[i]
        plt.figure('nrb')
        plt.ylim(-2.5,3.5)
        _=plt.plot(sig_nrb)
        #plt.title('NRB@'+str(sel_nrb[i])+' '+ sbi.rl_curr[sel_nrb[i]]+ ' dur:'+str( round(sbi.rri_dur[sel_nrb[i]],2)  )  )
# Out:
# Testing record: incartdb_I55
# NR_Count: 1
# Model: M_S_m_75_1
# ==============================================
# incartdb_I55
# ==============================================
# [All Samples]: 2164
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2118	28	0.98	1.0	0.99	0.61
# A	7	11	0.98	0.28	0.61	0.99
#
# [Class Samples]: 2147
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2118	28	0.98	1.0	0.99	0.61
# A	7	11	0.98	0.28	0.61	0.99
#
#
# Elapsed time = 0:00:03.683651

# %% [markdown]
# ### [ V test ]

# %%
sel_NR_count = 1
nr_supress=False
nrb_from_bins=False
nrb_bin_ordered = False
nrb_return = True
print('Testing record:',sel_rec.name)
print('NR_Count:', sel_NR_count)
print('Model:', modelV.name)
#<<-----------------------------------------------
timestamp_start = datetime.datetime.now()
#<<-----------------------------------------------
prAV,prCV,cmAV,cmCV,data_yV,_,sel_nrb = perform_record_test(modelV, V_DP, gV_LABELS, sel_rec, sbi, sel_NR_count, nr_supress, nrb_from_bins, nrb_bin_ordered, nrb_return)
#<<-----------------------------------------------
timestamp_dur = datetime.datetime.now() - timestamp_start
print('\nElapsed time = ' + str(timestamp_dur))

plot_nrb = True
if plot_nrb:
    for i in range(0,len(sel_nrb)):
        #sig_nrb,_,_ = sbi.get_signal_data_var(sel_nrb[i])
        sig_nrb = sel_nrb[i]
        plt.figure('nrb')
        plt.ylim(-2.5,3.5)
        _=plt.plot(sig_nrb)
        #plt.title('NRB@'+str(sel_nrb[i])+' '+ sbi.rl_curr[sel_nrb[i]]+ ' dur:'+str( round(sbi.rri_dur[sel_nrb[i]],2)  )  )
# Out:
# Testing record: incartdb_I55
# NR_Count: 1
# Model: M_V_m_75_1
# ==============================================
# incartdb_I55
# ==============================================
# [All Samples]: 2164
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2000	146	0.93	1.0	0.93	1.0
# A	0	18	0.93	0.11	1.0	0.93
#
# [Class Samples]: 2163
# A\P	N	A	ACC	PRE	SEN	SPF
# N	2000	146	0.93	1.0	0.93	1.0
# A	0	18	0.93	0.11	1.0	0.93
#
#
# Elapsed time = 0:00:03.814915

# %% [markdown]
# ### [ combined performance ]

# %%
prx = np.logical_or(prAS,prAV)
daty = np.logical_or(data_yS,data_yV) 

print('\n[Combined]:',len(daty))
conf_matrix = np.zeros((2,2),dtype='int32')
conf_matrix[0,0] = len(np.where((daty==0)&(prx==0))[0])
conf_matrix[0,1] = len(np.where((daty==0)&(prx==1))[0])
conf_matrix[1,0] = len(np.where((daty==1)&(prx==0))[0])
conf_matrix[1,1] = len(np.where((daty==1)&(prx==1))[0])
print('\tConfusion Matrix [N/A]') # all non-N are abnormal
print(print_conf_matrix( conf_matrix,'', gA_LABELS)) 
print_performance( get_performance(conf_matrix) ,gA_LABELS )
# Out:
# [Combined]: 2164
# 	Confusion Matrix [N/A]
# A\P	N	A
# N	1994	152
# A	0	18
#
# Performance for 2 classes
# Class	ACC	PRE	SEN	SPF
# N	0.93	1.0	0.93	1.0
# A	0.93	0.11	1.0	0.93

# %% [markdown]
# ### [ plot predictions ]

# %%
#<<--------------------------------------------------------------------
x_scale = 25 * 0.0393701 # mm/sec -> inches/sec
y_scale = 10 * 0.0393701 # mm/mV -> inches/sec
y_low = -2.5
y_high = 3.5
#------------------------------------------------------------

ff=250
tt=ff+17
sgv,_,_=plot_ecg_segment(sbi, sel_signal, 
                 ff, tt, 
                 x_scale, y_scale, y_low, y_high,
                 -2, False, 
                 [prAS,prAV, prx], 
                 [data_yS,data_yV, daty], 
                 ['tab:red','tab:blue', 'tab:orange'] ,
                 ['$S$','$V$','o'],
                 gain=1)
# Out:
# incartdb_I55
# Time Interval{17s}:[250:267]
# Beat Interval{22#}:[314:335]

# %% [markdown]
# ---
#
# EOE
#
# ---

# %% [markdown]
# # [ Kernel View ]

# %%
layername = 'conv_inorm_1' # conv_inorm_1 conv_inorm_3 conv_inorm_5
layerS = modelS.get_layer(name=layername)
layerV = modelV.get_layer(name=layername)

lwS=layerS.get_weights()[0]
lwV=layerV.get_weights()[0]
fig,ax = plt.subplots(lwS.shape[-1],4, sharey='all', sharex='all')
fig.set_size_inches(8,int(lwS.shape[-1]/2))
ax[0,0].set_yticklabels([])
ax[0,0].set_xticks(np.arange(0,lwS.shape[0]))
print(lwS.shape,lwV.shape)
for i in range(0,lwS.shape[-1]):
    f1S = np.expand_dims(lwS[:,0,i],axis=0)
    f2S = np.expand_dims(lwS[:,1,i],axis=0)
    f1V = np.expand_dims(lwV[:,0,i],axis=0)
    f2V = np.expand_dims(lwV[:,1,i],axis=0)

    ax[i,0].imshow(f1S,interpolation="nearest",cmap="Reds_r")
    ax[i,1].imshow(f2S,interpolation="nearest",cmap="Reds_r")
    ax[i,2].imshow(f1V,interpolation="nearest",cmap="Blues_r")
    ax[i,3].imshow(f2V,interpolation="nearest",cmap="Blues_r")
# Out:
# (7, 2, 64) (7, 2, 64)

# %% [markdown]
# ## [ sample activations ]

# %%
supress_NRB = False

# get a random NRB
rand_NRBi = sbi.NRBi[random.randint(0, sbi.NRBc-1)]
print('NRB@',rand_NRBi, sbi.rl_curr[rand_NRBi])
d_NR,dpk,_= sbi.get_signal_data_var(rand_NRBi)

# reshape NRB for each classifier
if supress_NRB:
    d_NRS = np.zeros(S_DP.vdim,dtype='float')
    d_NRV = np.zeros(V_DP.vdim,dtype='float')
else:
    d_NRS = pad_or_truncate(d_NR,dpk,S_DP)
    d_NRV = pad_or_truncate(d_NR,dpk,V_DP)

S_beat_ind = np.where(sbi.rli_curr==S_Label)[0]
if len(S_beat_ind)==0:
    d_CRS = np.zeros(S_DP.vdim,dtype='float')
    print('No S type beats found')
else:
    rand_CRiS = S_beat_ind[random.randint(0, len(S_beat_ind)-1)]
    print('CR-S-type@',rand_CRiS, sbi.rl_curr[rand_CRiS] )
    d_CRS,dpk,_= sbi.get_signal_data_var(rand_CRiS)
    d_CRS = pad_or_truncate(d_CRS,dpk,S_DP)
d_dataS = np.expand_dims(np.transpose(np.vstack((d_NRS,d_CRS))),axis=0)

V_beat_ind = np.where(sbi.rli_curr==V_Label)[0]
if len(V_beat_ind)==0:
    d_CRV = np.zeros(V_DP.vdim,dtype='float')
    print('No V type beats found')
else:
    rand_CRiV = V_beat_ind[random.randint(0, len(V_beat_ind)-1)]
    print('CR-V-type@',rand_CRiV, sbi.rl_curr[rand_CRiV] )
    d_CRV,dpk,_= sbi.get_signal_data_var(rand_CRiV)
    d_CRV = pad_or_truncate(d_CRV,dpk,V_DP)
d_dataV = np.expand_dims(np.transpose(np.vstack((d_NRV,d_CRV))),axis=0)

N_beat_ind = np.where(sbi.rli_curr==N_Label)[0]
if len(N_beat_ind)==0:
    d_CRNS = np.zeros(S_DP.vdim,dtype='float')
    d_CRNV = np.zeros(V_DP.vdim,dtype='float')
    print('No N type beats found')
else:
    rand_CRiN = N_beat_ind[random.randint(0, len(N_beat_ind)-1)]
    print('CR-N-type@',rand_CRiN, sbi.rl_curr[rand_CRiN] )
    d_CRVS,dpk,_= sbi.get_signal_data_var(rand_CRiN)
    d_CRVS = pad_or_truncate(d_CRVS,dpk,S_DP)
    d_CRVN,dpk,_= sbi.get_signal_data_var(rand_CRiN)
    d_CRVN = pad_or_truncate(d_CRVN,dpk,V_DP)

d_dataV = np.expand_dims(np.transpose(np.vstack((d_NRV,d_CRV))),axis=0)

d_dataSN = np.expand_dims(np.transpose(np.vstack((d_NRS,d_CRVS))),axis=0)
d_dataVN = np.expand_dims(np.transpose(np.vstack((d_NRV,d_CRVN))),axis=0)

fig, ax = plt.subplots(2,3, sharex='all',sharey='all' )
fig.set_size_inches(12,6)

ax[0,0].set_ylim(-2.5,3.5)
ax[0,0].plot(d_NRS, linewidth=0.7, color='tab:green')
ax[1,0].plot(d_NRV, linewidth=0.7, color='tab:green')
ax[0,1].plot(d_CRS, linewidth=0.7, color='tab:red')
ax[1,1].plot(d_CRV, linewidth=0.7, color='tab:blue')
ax[0,2].plot(d_CRVS, linewidth=0.7, color='tab:purple')
ax[1,2].plot(d_CRVN, linewidth=0.7, color='tab:purple')
# Out:
# NRB@ 1622 N
# CR-S-type@ 1787 A
# CR-V-type@ 1920 V
# CR-N-type@ 14 N

# %% [markdown]
# ## [ S ]

# %% [markdown]
# ### [ read activations ]

# %%
predres = modelS.predict(d_dataS) # d_dataS d_dataSN
print(predres)
activationsS = keract.get_activations(modelS, d_dataSN, auto_compile=True)
for k in activationsS.keys():
    print(k,'\t',activationsS[k].shape)
# Out:
# [[2.1013512e-11 1.0000000e+00]]
# input_norm_4 	 (1, 384, 2)
# conv_inorm_1_4 	 (1, 378, 64)
# conv_inorm_3_4 	 (1, 376, 40)
# conv_inorm_5_4 	 (1, 374, 20)
# flat_inorm_7_4 	 (1, 7480)
# DENSE_FC0_4 	 (1, 40)
# DENSE_FC1_4 	 (1, 20)
# OUTPUT_FC_4 	 (1, 2)

# %% [markdown]
# ### [ set layer names ]

# %%
layer1 = 'conv_inorm_1_4'
layer2 = 'conv_inorm_3_4'
layer3 = 'conv_inorm_5_4'

# %% [markdown]
# ### Layer 1

# %%
va1=activationsS[layer1]         # 30 378

rows,cols = 8,8
fig, axs = plt.subplots(rows, cols, figsize=(16,16),  constrained_layout=True) #sharex='all',sharey='all',
#fig.set_size_inches(12,6)
for ax in axs.flat:
    #ax.set_ylim(-2,3.5)
    ax.set_yticklabels([])    
    ax.set_xticklabels([])
    
i=0
for r in range(0,rows):
    for c in range(0,cols):
        axs[r, c].plot(va1[0][:,i],color='tab:red',linewidth=0.6)
        axs[r, c].set_title(str(i+1))
        axs[r, c].hlines(-.1,0,387,linewidth=0.1,color='red')
        axs[r, c].hlines(0,0,387,linewidth=0.3,color='black')
        axs[r, c].hlines(.1,0,387,linewidth=0.1,color='green')
        i+=1

plt.show()

# %% [markdown]
# ### Layer 2

# %%
va2=activationsS[layer2]         # 30 378

rows,cols = 5,8
fig, axs = plt.subplots(rows, cols, figsize=(16,10),  constrained_layout=True) #sharex='all',sharey='all',
#fig.set_size_inches(12,6)
for ax in axs.flat:
    #ax.set_ylim(-2,3.5)
    ax.set_yticklabels([])    
    ax.set_xticklabels([])
    
i=0
for r in range(0,rows):
    for c in range(0,cols):
        axs[r, c].plot(va2[0][:,i],color='tab:red',linewidth=0.6)
        axs[r, c].set_title(str(i+1))
        axs[r, c].hlines(-.1,0,387,linewidth=0.1,color='red')
        axs[r, c].hlines(0,0,387,linewidth=0.3,color='black')
        axs[r, c].hlines(.1,0,387,linewidth=0.1,color='green')
        i+=1

plt.show()

# %% [markdown]
# ### Layer 3

# %%
va3=activationsS[layer3]         # 30 378

rows,cols = 5,4
fig, axs = plt.subplots(rows, cols, figsize=(10,8),  constrained_layout=True) #sharex='all',sharey='all',
#fig.set_size_inches(12,6)
for ax in axs.flat:
    #ax.set_ylim(-2,3.5)
    ax.set_yticklabels([])    
    ax.set_xticklabels([])
    
i=0
for r in range(0,rows):
    for c in range(0,cols):
        axs[r, c].plot(va3[0][:,i],color='tab:red',linewidth=0.6)
        axs[r, c].set_title(str(i+1))
        axs[r, c].hlines(-.1,0,387,linewidth=0.1,color='red')
        axs[r, c].hlines(0,0,387,linewidth=0.3,color='black')
        axs[r, c].hlines(.1,0,387,linewidth=0.1,color='green')
        i+=1

plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ## [ V ]

# %% [markdown]
# ### [ read activations ]

# %%
predres = modelV.predict(d_dataV) # d_dataV d_dataVN
print(predres)
activationsV = keract.get_activations(modelV, d_dataVN, auto_compile=True)
for k in activationsV.keys():
    print(k,'\t',activationsV[k].shape)
# Out:
# [[1.4546448e-07 9.9999988e-01]]
# input_norm_5 	 (1, 384, 2)
# conv_inorm_1_5 	 (1, 378, 64)
# conv_inorm_3_5 	 (1, 376, 40)
# conv_inorm_5_5 	 (1, 374, 20)
# flat_inorm_7_5 	 (1, 7480)
# DENSE_FC0_5 	 (1, 40)
# DENSE_FC1_5 	 (1, 20)
# OUTPUT_FC_5 	 (1, 2)

# %% [markdown]
# ### [ set layer names ]

# %%
layer1 = 'conv_inorm_1_5'
layer2 = 'conv_inorm_3_5'
layer3 = 'conv_inorm_5_5'

# %% [markdown]
# ### Layer 1

# %%
va1=activationsV[layer1]         # 30 378

rows,cols = 8,8
fig, axs = plt.subplots(rows, cols, figsize=(16,16),  constrained_layout=True) #sharex='all',sharey='all',
#fig.set_size_inches(12,6)
for ax in axs.flat:
    #ax.set_ylim(-2,3.5)
    ax.set_yticklabels([])    
    ax.set_xticklabels([])
    
i=0
for r in range(0,rows):
    for c in range(0,cols):
        axs[r, c].plot(va1[0][:,i],color='tab:blue',linewidth=0.6)
        axs[r, c].set_title(str(i+1))
        axs[r, c].hlines(-.1,0,387,linewidth=0.1,color='red')
        axs[r, c].hlines(0,0,387,linewidth=0.3,color='black')
        axs[r, c].hlines(.1,0,387,linewidth=0.1,color='green')
        i+=1

plt.show()

# %% [markdown]
# ### Layer 2

# %%
va2=activationsV[layer2]         # 30 378

rows,cols = 5,8
fig, axs = plt.subplots(rows, cols, figsize=(16,10),  constrained_layout=True) #sharex='all',sharey='all',
#fig.set_size_inches(12,6)
for ax in axs.flat:
    #ax.set_ylim(-2,3.5)
    ax.set_yticklabels([])    
    ax.set_xticklabels([])
    
i=0
for r in range(0,rows):
    for c in range(0,cols):
        axs[r, c].plot(va2[0][:,i],color='tab:blue',linewidth=0.6)
        axs[r, c].set_title(str(i+1))
        axs[r, c].hlines(-.1,0,387,linewidth=0.1,color='red')
        axs[r, c].hlines(0,0,387,linewidth=0.3,color='black')
        axs[r, c].hlines(.1,0,387,linewidth=0.1,color='green')
        i+=1

plt.show()

# %% [markdown]
# ### Layer 3

# %%
va3=activationsV[layer3]         # 30 378

rows,cols = 5,4
fig, axs = plt.subplots(rows, cols, figsize=(10,8),  constrained_layout=True) #sharex='all',sharey='all',
#fig.set_size_inches(12,6)
for ax in axs.flat:
    #ax.set_ylim(-2,3.5)
    ax.set_yticklabels([])    
    ax.set_xticklabels([])
    
i=0
for r in range(0,rows):
    for c in range(0,cols):
        axs[r, c].plot(va3[0][:,i],color='tab:blue',linewidth=0.6)
        axs[r, c].set_title(str(i+1))
        axs[r, c].hlines(-.1,0,387,linewidth=0.1,color='red')
        axs[r, c].hlines(0,0,387,linewidth=0.3,color='black')
        axs[r, c].hlines(.1,0,387,linewidth=0.1,color='green')
        i+=1

plt.show()

# %% [markdown]
# ---
